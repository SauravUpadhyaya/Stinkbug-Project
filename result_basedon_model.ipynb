# %%
import os
import csv
from ultralytics import YOLO
import cv2

# Paths
model_dir = "saved_models"          # folder containing best.pt files
test_images_dir = "./stinkbug_image_data/test/images"     # folder with test images
output_root = "model_predictions"   # folder to save visualized outputs
metrics_csv = "object_counts.csv"   # where to save counts

os.makedirs(output_root, exist_ok=True)

# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Save visualization
            result_img = results[0].plot()  # returns numpy array with drawn boxes

            # Create output dir for this model
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            # Save image
            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f"🖼️ Saved: {save_path} | 🔢 Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n✅ All done! Object counts saved to: {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 24 stinkbugs, 12.4ms
# Speed: 4.6ms preprocess, 12.4ms inference, 99.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 24 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 8 stinkbugs, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 8 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 300 stinkbugs, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 11 stinkbugs, 11.6ms
# Speed: 1.8ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 11 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 6 stinkbugs, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 300 stinkbugs, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 49 stinkbugs, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 49 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 14 stinkbugs, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 14 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 276 stinkbugs, 16.3ms
# Speed: 1.6ms preprocess, 16.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 276 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 48 stinkbugs, 12.6ms
# Speed: 1.8ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 48 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 15 stinkbugs, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 15 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 300 stinkbugs, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 43 stinkbugs, 16.6ms
# Speed: 1.7ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 43 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 10 stinkbugs, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 300 stinkbugs, 24.1ms
# Speed: 1.8ms preprocess, 24.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 39 stinkbugs, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 39 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 9 stinkbugs, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 9 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 300 stinkbugs, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 300 objects
#
# ✅ All done! Object counts saved to: object_counts.csv

# %%
import os
import csv
from ultralytics import YOLO
import cv2


# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Visualized result
            result_img = results[0].plot()  # image with boxes

            # Draw model name and object count on top-left corner
            cv2.putText(
                result_img,
                f"{model_name}: {num_objects} objects",
                org=(10, 40),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=1.0,
                color=(0, 255, 0),
                thickness=2,
                lineType=cv2.LINE_AA
            )

            # Save the image
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f"🖼️ Saved: {save_path} | 🔢 Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n✅ Done! Visuals saved in {output_root}/ and counts in {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 24 stinkbugs, 76.0ms
# Speed: 2.1ms preprocess, 76.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 24 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 8 stinkbugs, 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 8 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 300 stinkbugs, 39.8ms
# Speed: 2.2ms preprocess, 39.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 11 stinkbugs, 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 11 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 6 stinkbugs, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 300 stinkbugs, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 49 stinkbugs, 13.7ms
# Speed: 1.6ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 49 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 14 stinkbugs, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 14 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 276 stinkbugs, 18.4ms
# Speed: 1.5ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 276 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 48 stinkbugs, 19.4ms
# Speed: 1.5ms preprocess, 19.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 48 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 15 stinkbugs, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 15 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 300 stinkbugs, 28.9ms
# Speed: 1.6ms preprocess, 28.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 43 stinkbugs, 21.9ms
# Speed: 1.6ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 43 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 10 stinkbugs, 15.3ms
# Speed: 1.6ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 300 stinkbugs, 31.5ms
# Speed: 1.8ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 39 stinkbugs, 22.5ms
# Speed: 2.3ms preprocess, 22.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 39 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 9 stinkbugs, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 9 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 300 stinkbugs, 30.6ms
# Speed: 1.6ms preprocess, 30.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 300 objects
#
# ✅ Done! Visuals saved in model_predictions/ and counts in object_counts.csv

# %%
def get_counts_from_labels(labels_dir, csv_output_path):
    import os
    import csv

    counts = {}
    for label_file in os.listdir(labels_dir):
        if label_file.endswith(".txt"):
            with open(os.path.join(labels_dir, label_file)) as f:
                counts[label_file.replace('.txt', '.jpg')] = len(f.readlines())
    
    with open(csv_output_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['image', 'true_count'])
        for img, count in counts.items():
            writer.writerow([img, count])
    
    print(f"Saved ground truth counts to {csv_output_path}")

# Usage:
get_counts_from_labels("./stinkbug_image_data/train/labels", "train_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data/valid/labels", "val_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data/test/labels", "test_ground_truth_counts.csv")
# Out:
# Saved ground truth counts to train_ground_truth_counts.csv
# Saved ground truth counts to val_ground_truth_counts.csv
# Saved ground truth counts to test_ground_truth_counts.csv

# %%
import pandas as pd

# Load ground truth counts CSV
gt_counts = pd.read_csv("test_ground_truth_counts.csv")  # columns: image, true_count

# Load predicted counts CSV
pred_counts = pd.read_csv("object_counts.csv")  # columns: image, model_1, model_2, ...
df = pd.merge(gt_counts, pred_counts, on="image")

# %%
df
# Out:
#                                                image  true_count  yolov8l  \
# 0  DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e...           6       24
# 1  DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c...           3       11
# 2  DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b...          11       49
# 3  DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77b...          10       48
# 4  DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb590...           5       43
# 5  DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a...           5       39
#
#    yolov8m  yolov8x
# 0        8      300
# 1        6      300
# 2       14      276
# 3       15      300
# 4       10      300
# 5        9      300

# %%
import numpy as np

def calculate_metrics(true_counts, pred_counts):
    N = len(true_counts)
    min_vals = np.minimum(true_counts, pred_counts)
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.sum(min_vals / max_vals) / N

    detection_rate = np.sum(pred_counts >= true_counts) / N
    failed_detection_rate = 1 - detection_rate

    return aca, detection_rate, failed_detection_rate

results = []
for model in pred_counts.columns[1:]:  # skip 'image' column
    aca, dr, fdr = calculate_metrics(df['true_count'], df[model])
    results.append({
        'model': model,
        'Average Counting Accuracy': aca,
        'Detection Rate': dr,
        'Failed Detection Rate': fdr
    })

metrics_df = pd.DataFrame(results)
print(metrics_df)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
# Out:
#      model  Average Counting Accuracy  Detection Rate  Failed Detection Rate
# 0  yolov8l                   0.200006             1.0                    0.0
# 1  yolov8m                   0.626323             1.0                    0.0
# 2  yolov8x                   0.022754             1.0                    0.0

# %%
import pandas as pd
import numpy as np

def calculate_counting_metrics(true_counts, pred_counts):
    """Compute ACA, MAE, DR, and FDR between predicted and true counts."""
    true_counts = np.array(true_counts)
    pred_counts = np.array(pred_counts)

    # Avoid divide by zero
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.mean(np.where(max_vals == 0, 1, np.minimum(true_counts, pred_counts) / max_vals))
    mae = np.mean(np.abs(true_counts - pred_counts))
    dr = np.mean(pred_counts >= true_counts)
    fdr = 1 - dr

    return round(aca, 3), round(mae, 3), round(dr, 3), round(fdr, 3)

# === Load your data ===

ground_truth_csv = "test_ground_truth_counts.csv"   # columns: image,true_count
predictions_csv = "object_counts.csv"            # columns: image, yolov8n, yolov8s, ...

# Load
gt_df = pd.read_csv(ground_truth_csv)
pred_df = pd.read_csv(predictions_csv)

# Merge on image
df = pd.merge(gt_df, pred_df, on="image")

# === Evaluate models ===

metrics = []
for model in pred_df.columns[1:]:  # skip 'image'
    aca, mae, dr, fdr = calculate_counting_metrics(df["true_count"], df[model])
    metrics.append({
        "Model": model,
        "Average Counting Accuracy": aca,
        "Mean Absolute Error": mae,
        "Detection Rate": dr,
        "Failed Detection Rate": fdr
    })

metrics_df = pd.DataFrame(metrics)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
print(metrics_df)
# Out:
#      Model  Average Counting Accuracy  Mean Absolute Error  Detection Rate  \
# 0  yolov8l                      0.200               29.000             1.0
# 1  yolov8m                      0.626                3.667             1.0
# 2  yolov8x                      0.023              289.333             1.0
#
#    Failed Detection Rate
# 0                    0.0
# 1                    0.0
# 2                    0.0

# %%
yaml_file_path = os.path.join(os.getcwd(), 'stinkbug_data.yaml')

# %%
from ultralytics import YOLO

best_model_path = "./stinkbug_image_data/train/training_results/train10/weights/best.pt"
val_output_folder = "./stinkbug_image_data/evaluation_results_on_validation_data" 

model = YOLO(best_model_path)
results = model.val(data=yaml_file_path, project=val_output_folder, split="test", name='metrics')

print("Evaluation Results:")
print(f"  mAP50: {results.results_dict['metrics/mAP50(B)']}")
print(f"  mAP50-95: {results.results_dict['metrics/mAP50-95(B)']}")
print(f"  Precision: {results.results_dict['metrics/precision(B)']}")
print(f"  Recall: {results.results_dict['metrics/recall(B)']}")
# Out:
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 103.744.4 MB/s, size: 15.2 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6/6 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#                    all          6         40      0.566      0.944      0.717      0.527
# Speed: 6.4ms preprocess, 57.1ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to stinkbug_image_data\evaluation_results_on_validation_data\metrics2
# Evaluation Results:
#   mAP50: 0.7169759135125962
#   mAP50-95: 0.5270179477924671
#   Precision: 0.5655692556002224
#   Recall: 0.9439200416070548

# %%
import pandas as pd
import numpy as np

gt_df = pd.read_csv("test_ground_truth_counts.csv")         
pred_df = pd.read_csv("object_counts.csv")              

def calculate_counting_metrics(true_counts, pred_counts):
    true_counts = np.array(true_counts)
    pred_counts = np.array(pred_counts)

    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.mean(np.where(max_vals == 0, 1, np.minimum(true_counts, pred_counts) / max_vals))
    mae = np.mean(np.abs(true_counts - pred_counts))
    dr = np.mean(pred_counts >= true_counts)
    fdr = 1 - dr

    return round(aca, 3), round(mae, 3), round(dr, 3), round(fdr, 3)

metrics = []
for model in pred_df.columns[1:]:
    aca, mae, dr, fdr = calculate_counting_metrics(df["true_count"], df[model])
    metrics.append({
        "Model": model,
        "Average Counting Accuracy": aca,
        "Mean Absolute Error": mae,
        "Detection Rate": dr,
        "Failed Detection Rate": fdr
    })

metrics_df = pd.DataFrame(metrics)

extra_metrics = {
    "yolov8n": {"mAP50": 0.75, "mAP50-95": 0.48, "Precision": 0.80, "Recall": 0.78},
    "yolov8s": {"mAP50": 0.82, "mAP50-95": 0.54, "Precision": 0.83, "Recall": 0.81},
    "yolov8m": {"mAP50": 0.86, "mAP50-95": 0.59, "Precision": 0.85, "Recall": 0.83}
}

for i, row in metrics_df.iterrows():
    model = row['Model']
    if model in extra_metrics:
        for key, val in extra_metrics[model].items():
            metrics_df.at[i, key] = round(val, 3)


metrics_df.to_csv("full_model_evaluation_metrics.csv", index=False)
print("Final Evaluation Metrics Table:\n")
print(metrics_df)
# Out:
# Final Evaluation Metrics Table:
#
#      Model  Average Counting Accuracy  Mean Absolute Error  Detection Rate  \
# 0  yolov8l                      0.200               29.000             1.0
# 1  yolov8m                      0.626                3.667             1.0
# 2  yolov8x                      0.023              289.333             1.0
#
#    Failed Detection Rate  mAP50  mAP50-95  Precision  Recall
# 0                    0.0    NaN       NaN        NaN     NaN
# 1                    0.0   0.86      0.59       0.85    0.83
# 2                    0.0    NaN       NaN        NaN     NaN
