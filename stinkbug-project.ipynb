# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==3.0.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 1)) (3.0.0)
# Collecting certifi==2025.7.14 (from -r requirements.txt (line 2))
#   Using cached certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset-normalizer==3.4.2 (from -r requirements.txt (line 3))
#   Using cached charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: colorama==0.4.6 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 4)) (0.4.6)
# Collecting comm==0.2.2 (from -r requirements.txt (line 5))
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy==1.3.2 (from -r requirements.txt (line 6))
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: cycler==0.12.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 7)) (0.12.1)
# Collecting debugpy==1.8.14 (from -r requirements.txt (line 8))
#   Using cached debugpy-1.8.14-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: decorator==5.2.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: executing==2.2.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 10)) (2.2.0)
# Collecting filelock==3.13.1 (from -r requirements.txt (line 11))
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting fonttools==4.58.5 (from -r requirements.txt (line 12))
#   Using cached fonttools-4.58.5-cp312-cp312-win_amd64.whl.metadata (109 kB)
# Collecting fsspec==2024.6.1 (from -r requirements.txt (line 13))
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna==3.10 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 14)) (3.10)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 15))
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ipython==9.4.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 16)) (9.4.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 17)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 18)) (0.19.2)
# Collecting Jinja2==3.1.4 (from -r requirements.txt (line 19))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib==1.5.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 20)) (1.5.1)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 21)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.8.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 22)) (5.8.1)
# Collecting kiwisolver==1.4.8 (from -r requirements.txt (line 23))
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting MarkupSafe==2.1.5 (from -r requirements.txt (line 24))
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting matplotlib==3.10.3 (from -r requirements.txt (line 25))
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 26)) (0.1.7)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 28)) (1.6.0)
# Collecting networkx==3.3 (from -r requirements.txt (line 29))
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy==2.1.2 (from -r requirements.txt (line 30))
#   Using cached numpy-2.1.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: opencv-python==4.12.0.88 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 31)) (4.12.0.88)
# Requirement already satisfied: packaging==25.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 32)) (25.0)
# Requirement already satisfied: pandas==2.3.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 33)) (2.3.1)
# Requirement already satisfied: parso==0.8.4 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 34)) (0.8.4)
# Collecting pillow==11.0.0 (from -r requirements.txt (line 35))
#   Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: platformdirs==4.3.8 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 36)) (4.3.8)
# Requirement already satisfied: prompt_toolkit==3.0.51 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 37)) (3.0.51)
# Requirement already satisfied: psutil==7.0.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 38)) (7.0.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 39)) (0.2.3)
# Requirement already satisfied: py-cpuinfo==9.0.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 40)) (9.0.0)
# Requirement already satisfied: Pygments==2.19.2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 41)) (2.19.2)
# Requirement already satisfied: pyparsing==3.2.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 42)) (3.2.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 43)) (2.9.0.post0)
# Collecting python-dotenv==1.1.1 (from -r requirements.txt (line 44))
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pytz==2025.2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 45)) (2025.2)
# Requirement already satisfied: pywin32==311 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 46)) (311)
# Requirement already satisfied: PyYAML==6.0.2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 47)) (6.0.2)
# Collecting pyzmq==27.0.0 (from -r requirements.txt (line 48))
#   Using cached pyzmq-27.0.0-cp312-abi3-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: requests==2.32.4 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 49)) (2.32.4)
# Collecting scikit-learn==1.7.0 (from -r requirements.txt (line 50))
#   Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting scipy==1.16.0 (from -r requirements.txt (line 51))
#   Using cached scipy-1.16.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting setuptools==70.2.0 (from -r requirements.txt (line 52))
#   Using cached setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six==1.17.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 53)) (1.17.0)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 54)) (0.6.3)
# Collecting sympy==1.13.3 (from -r requirements.txt (line 55))
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: threadpoolctl==3.6.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from -r requirements.txt (line 56)) (3.6.0)
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python <3.12,>=3.8; 1.10.0rc1 Requires-Python <3.12,>=3.8; 1.10.0rc2 Requires-Python <3.12,>=3.8; 1.10.1 Requires-Python <3.12,>=3.8; 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11; 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11; 1.9.0 Requires-Python >=3.8,<3.12; 1.9.0rc1 Requires-Python >=3.8,<3.12; 1.9.0rc2 Requires-Python >=3.8,<3.12; 1.9.0rc3 Requires-Python >=3.8,<3.12; 1.9.1 Requires-Python >=3.8,<3.12
# ERROR: Could not find a version that satisfies the requirement torch==2.7.1+cu128 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for torch==2.7.1+cu128

# %%
# !python -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Requirement already satisfied: torch in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (0.23.0)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu128/torchaudio-2.8.0%2Bcu128-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: filelock in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (2025.7.0)
# Requirement already satisfied: setuptools in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torchvision) (11.3.0)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cu128/torchaudio-2.8.0%2Bcu128-cp312-cp312-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ----------- ---------------------------- 1.3/4.7 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 10.1 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp312-cp312-win_amd64.whl (3461.4 MB)
#    ---------------------------------------- 0.0/3.5 GB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 GB 16.8 MB/s eta 0:03:27
#    ---------------------------------------- 0.0/3.5 GB 17.5 MB/s eta 0:03:18
#    ---------------------------------------- 0.0/3.5 GB 17.7 MB/s eta 0:03:16
#    ---------------------------------------- 0.0/3.5 GB 17.8 MB/s eta 0:03:14
#    ---------------------------------------- 0.0/3.5 GB 18.1 MB/s eta 0:03:10
#    ---------------------------------------- 0.0/3.5 GB 17.9 MB/s eta 0:03:13
#    ---------------------------------------- 0.0/3.5 GB 18.1 MB/s eta 0:03:10
#    ---------------------------------------- 0.0/3.5 GB 18.1 MB/s eta 0:03:10
#    ---------------------------------------- 0.0/3.5 GB 18.1 MB/s eta 0:03:10
#    ---------------------------------------- 0.0/3.5 GB 18.1 MB/s eta 0:03:10
#    ---------------------------------------- 0.0/3.5 GB 18.1 MB/s eta 0:03:10
#    ---------------------------------------- 0.0/3.5 GB 17.7 MB/s eta 0:03:14
#     --------------------------------------- 0.0/3.5 GB 17.7 MB/s eta 0:03:14
#     --------------------------------------- 0.1/3.5 GB 17.7 MB/s eta 0:03:13
#     --------------------------------------- 0.1/3.5 GB 17.7 MB/s eta 0:03:13
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:12
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:12
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:11
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:11
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:11
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:10
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:10
#     --------------------------------------- 0.1/3.5 GB 17.8 MB/s eta 0:03:10
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:09
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:09
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:08
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:08
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:07
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:07
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:07
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:07
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:07
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 18.0 MB/s eta 0:03:05
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 17.9 MB/s eta 0:03:06
#    - -------------------------------------- 0.1/3.5 GB 17.1 MB/s eta 0:03:14
#    - -------------------------------------- 0.1/3.5 GB 17.1 MB/s eta 0:03:14
#    - -------------------------------------- 0.1/3.5 GB 17.1 MB/s eta 0:03:14
#    - -------------------------------------- 0.2/3.5 GB 17.2 MB/s eta 0:03:13
#    - -------------------------------------- 0.2/3.5 GB 17.2 MB/s eta 0:03:13
#    - -------------------------------------- 0.2/3.5 GB 17.2 MB/s eta 0:03:12
#    - -------------------------------------- 0.2/3.5 GB 17.2 MB/s eta 0:03:12
#    - -------------------------------------- 0.2/3.5 GB 17.3 MB/s eta 0:03:11
#    - -------------------------------------- 0.2/3.5 GB 17.3 MB/s eta 0:03:11
#    -- ------------------------------------- 0.2/3.5 GB 17.3 MB/s eta 0:03:10
#    -- ------------------------------------- 0.2/3.5 GB 17.3 MB/s eta 0:03:10
#    -- ------------------------------------- 0.2/3.5 GB 17.3 MB/s eta 0:03:10
#    -- ------------------------------------- 0.2/3.5 GB 17.3 MB/s eta 0:03:09
#    -- ------------------------------------- 0.2/3.5 GB 17.4 MB/s eta 0:03:09
#    -- ------------------------------------- 0.2/3.5 GB 17.4 MB/s eta 0:03:08
#    -- ------------------------------------- 0.2/3.5 GB 17.4 MB/s eta 0:03:08
#    -- ------------------------------------- 0.2/3.5 GB 17.4 MB/s eta 0:03:07
#    -- ------------------------------------- 0.2/3.5 GB 17.4 MB/s eta 0:03:07
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:07
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:06
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:06
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:06
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:06
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:05
#    -- ------------------------------------- 0.2/3.5 GB 17.5 MB/s eta 0:03:05
#    -- ------------------------------------- 0.2/3.5 GB 17.6 MB/s eta 0:03:04
#    -- ------------------------------------- 0.2/3.5 GB 17.6 MB/s eta 0:03:04
#    -- ------------------------------------- 0.2/3.5 GB 17.6 MB/s eta 0:03:04
#    -- ------------------------------------- 0.2/3.5 GB 17.6 MB/s eta 0:03:03
#    -- ------------------------------------- 0.3/3.5 GB 17.6 MB/s eta 0:03:03
#    -- ------------------------------------- 0.3/3.5 GB 17.6 MB/s eta 0:03:03
#    -- ------------------------------------- 0.3/3.5 GB 17.6 MB/s eta 0:03:02
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:02
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:02
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:01
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:01
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:01
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:01
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.6 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:02:59
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:02:58
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:02:58
#    --- ------------------------------------ 0.3/3.5 GB 17.8 MB/s eta 0:02:58
#    --- ------------------------------------ 0.3/3.5 GB 17.8 MB/s eta 0:02:58
#    --- ------------------------------------ 0.3/3.5 GB 17.8 MB/s eta 0:02:57
#    --- ------------------------------------ 0.3/3.5 GB 17.8 MB/s eta 0:02:57
#    --- ------------------------------------ 0.3/3.5 GB 17.7 MB/s eta 0:02:57
#    --- ------------------------------------ 0.3/3.5 GB 17.5 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.4 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.4 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.4 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.4 MB/s eta 0:03:00
#    --- ------------------------------------ 0.3/3.5 GB 17.2 MB/s eta 0:03:02
#    --- ------------------------------------ 0.3/3.5 GB 17.1 MB/s eta 0:03:03
#    ---- ----------------------------------- 0.3/3.5 GB 17.0 MB/s eta 0:03:04
#    ---- ----------------------------------- 0.3/3.5 GB 16.9 MB/s eta 0:03:05
#    ---- ----------------------------------- 0.4/3.5 GB 16.8 MB/s eta 0:03:06
#    ---- ----------------------------------- 0.4/3.5 GB 16.7 MB/s eta 0:03:06
#    ---- ----------------------------------- 0.4/3.5 GB 16.6 MB/s eta 0:03:07
#    ---- ----------------------------------- 0.4/3.5 GB 16.6 MB/s eta 0:03:08
#    ---- ----------------------------------- 0.4/3.5 GB 16.5 MB/s eta 0:03:08
#    ---- ----------------------------------- 0.4/3.5 GB 16.4 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.3 MB/s eta 0:03:10
#    ---- ----------------------------------- 0.4/3.5 GB 16.3 MB/s eta 0:03:10
#    ---- ----------------------------------- 0.4/3.5 GB 16.2 MB/s eta 0:03:11
#    ---- ----------------------------------- 0.4/3.5 GB 16.2 MB/s eta 0:03:11
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:12
#    ---- ----------------------------------- 0.4/3.5 GB 16.0 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.9 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.9 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.9 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.9 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.8 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.8 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.8 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 15.8 MB/s eta 0:03:14
#    ---- ----------------------------------- 0.4/3.5 GB 16.2 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.2 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:09
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:08
#    ---- ----------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:08
#    ----- ---------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:08
#    ----- ---------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:08
#    ----- ---------------------------------- 0.4/3.5 GB 16.1 MB/s eta 0:03:07
#    ----- ---------------------------------- 0.4/3.5 GB 16.2 MB/s eta 0:03:07
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:07
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:07
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:07
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:06
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:06
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:06
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:06
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:05
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:05
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:05
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:05
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:05
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:04
#    ----- ---------------------------------- 0.5/3.5 GB 16.2 MB/s eta 0:03:04
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:04
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:04
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:03
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:03
#    ----- ---------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:03
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:03
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:03
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.5/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 16.1 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 16.1 MB/s eta 0:03:01
#    ------ --------------------------------- 0.6/3.5 GB 16.1 MB/s eta 0:03:01
#    ------ --------------------------------- 0.6/3.5 GB 16.1 MB/s eta 0:03:01
#    ------ --------------------------------- 0.6/3.5 GB 16.1 MB/s eta 0:03:01
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:03
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:03
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:02
#    ------ --------------------------------- 0.6/3.5 GB 16.2 MB/s eta 0:02:58
#    ------ --------------------------------- 0.6/3.5 GB 16.2 MB/s eta 0:02:58
#    ------ --------------------------------- 0.6/3.5 GB 16.2 MB/s eta 0:02:58
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:00
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:01
#    ------ --------------------------------- 0.6/3.5 GB 15.9 MB/s eta 0:03:00
#    ------- -------------------------------- 0.6/3.5 GB 16.0 MB/s eta 0:02:58
#    ------- -------------------------------- 0.6/3.5 GB 16.2 MB/s eta 0:02:57
#    ------- -------------------------------- 0.6/3.5 GB 16.2 MB/s eta 0:02:56
#    ------- -------------------------------- 0.6/3.5 GB 16.4 MB/s eta 0:02:54
#    ------- -------------------------------- 0.6/3.5 GB 16.4 MB/s eta 0:02:53
#    ------- -------------------------------- 0.6/3.5 GB 16.6 MB/s eta 0:02:52
#    ------- -------------------------------- 0.6/3.5 GB 16.6 MB/s eta 0:02:51
#    ------- -------------------------------- 0.6/3.5 GB 16.7 MB/s eta 0:02:50
#    ------- -------------------------------- 0.6/3.5 GB 16.8 MB/s eta 0:02:49
#    ------- -------------------------------- 0.6/3.5 GB 16.8 MB/s eta 0:02:48
#    ------- -------------------------------- 0.6/3.5 GB 17.1 MB/s eta 0:02:46
#    ------- -------------------------------- 0.6/3.5 GB 17.2 MB/s eta 0:02:45
#    ------- -------------------------------- 0.6/3.5 GB 17.2 MB/s eta 0:02:44
#    ------- -------------------------------- 0.7/3.5 GB 17.2 MB/s eta 0:02:44
#    ------- -------------------------------- 0.7/3.5 GB 17.3 MB/s eta 0:02:43
#    ------- -------------------------------- 0.7/3.5 GB 17.3 MB/s eta 0:02:42
#    ------- -------------------------------- 0.7/3.5 GB 17.3 MB/s eta 0:02:42
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:42
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:41
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:41
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:41
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:40
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:40
#    ------- -------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:40
#    -------- ------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:40
#    -------- ------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:40
#    -------- ------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:39
#    -------- ------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:39
#    -------- ------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:39
#    -------- ------------------------------- 0.7/3.5 GB 17.4 MB/s eta 0:02:39
#    -------- ------------------------------- 0.7/3.5 GB 16.9 MB/s eta 0:02:44
#    -------- ------------------------------- 0.7/3.5 GB 16.8 MB/s eta 0:02:44
#    -------- ------------------------------- 0.7/3.5 GB 16.7 MB/s eta 0:02:45
#    -------- ------------------------------- 0.7/3.5 GB 16.7 MB/s eta 0:02:45
#    -------- ------------------------------- 0.7/3.5 GB 16.6 MB/s eta 0:02:46
#    -------- ------------------------------- 0.7/3.5 GB 16.5 MB/s eta 0:02:46
#    -------- ------------------------------- 0.7/3.5 GB 16.5 MB/s eta 0:02:46
#    -------- ------------------------------- 0.7/3.5 GB 16.4 MB/s eta 0:02:47
#    -------- ------------------------------- 0.7/3.5 GB 16.4 MB/s eta 0:02:47
#    -------- ------------------------------- 0.7/3.5 GB 16.4 MB/s eta 0:02:47
#    -------- ------------------------------- 0.7/3.5 GB 16.3 MB/s eta 0:02:48
#    -------- ------------------------------- 0.7/3.5 GB 16.3 MB/s eta 0:02:48
#    -------- ------------------------------- 0.7/3.5 GB 16.3 MB/s eta 0:02:48
#    -------- ------------------------------- 0.7/3.5 GB 16.2 MB/s eta 0:02:48
#    -------- ------------------------------- 0.7/3.5 GB 16.2 MB/s eta 0:02:48
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:48
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:48
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:47
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:47
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:47
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:47
#    -------- ------------------------------- 0.8/3.5 GB 16.2 MB/s eta 0:02:47
#    -------- ------------------------------- 0.8/3.5 GB 16.1 MB/s eta 0:02:47
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:47
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:47
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:46
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:46
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:46
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:45
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:45
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:45
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:44
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:44
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:44
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:44
#    --------- ------------------------------ 0.8/3.5 GB 16.4 MB/s eta 0:02:42
#    --------- ------------------------------ 0.8/3.5 GB 16.4 MB/s eta 0:02:41
#    --------- ------------------------------ 0.8/3.5 GB 16.4 MB/s eta 0:02:41
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:42
#    --------- ------------------------------ 0.8/3.5 GB 16.2 MB/s eta 0:02:43
#    --------- ------------------------------ 0.8/3.5 GB 16.1 MB/s eta 0:02:43
#    --------- ------------------------------ 0.8/3.5 GB 16.0 MB/s eta 0:02:44
#    --------- ------------------------------ 0.8/3.5 GB 16.0 MB/s eta 0:02:44
#    --------- ------------------------------ 0.8/3.5 GB 15.9 MB/s eta 0:02:45
#    --------- ------------------------------ 0.8/3.5 GB 15.8 MB/s eta 0:02:45
#    --------- ------------------------------ 0.9/3.5 GB 15.8 MB/s eta 0:02:46
#    --------- ------------------------------ 0.9/3.5 GB 15.8 MB/s eta 0:02:46
#    --------- ------------------------------ 0.9/3.5 GB 15.7 MB/s eta 0:02:46
#    --------- ------------------------------ 0.9/3.5 GB 16.0 MB/s eta 0:02:43
#    --------- ------------------------------ 0.9/3.5 GB 16.0 MB/s eta 0:02:43
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:43
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:43
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:43
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:42
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:42
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:42
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:42
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:41
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:41
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:41
#    ---------- ----------------------------- 0.9/3.5 GB 16.0 MB/s eta 0:02:40
#    ---------- ----------------------------- 0.9/3.5 GB 15.9 MB/s eta 0:02:41
#    ---------- ----------------------------- 0.9/3.5 GB 15.8 MB/s eta 0:02:43
#    ---------- ----------------------------- 0.9/3.5 GB 15.7 MB/s eta 0:02:43
#    ---------- ----------------------------- 0.9/3.5 GB 15.6 MB/s eta 0:02:44
#    ---------- ----------------------------- 0.9/3.5 GB 15.5 MB/s eta 0:02:45
#    ---------- ----------------------------- 0.9/3.5 GB 15.4 MB/s eta 0:02:45
#    ---------- ----------------------------- 0.9/3.5 GB 15.4 MB/s eta 0:02:46
#    ---------- ----------------------------- 0.9/3.5 GB 15.3 MB/s eta 0:02:47
#    ---------- ----------------------------- 0.9/3.5 GB 15.2 MB/s eta 0:02:47
#    ---------- ----------------------------- 0.9/3.5 GB 15.2 MB/s eta 0:02:48
#    ---------- ----------------------------- 0.9/3.5 GB 15.1 MB/s eta 0:02:48
#    ---------- ----------------------------- 0.9/3.5 GB 15.1 MB/s eta 0:02:49
#    ---------- ----------------------------- 0.9/3.5 GB 15.0 MB/s eta 0:02:49
#    ---------- ----------------------------- 0.9/3.5 GB 15.0 MB/s eta 0:02:49
#    ---------- ----------------------------- 0.9/3.5 GB 14.9 MB/s eta 0:02:50
#    ---------- ----------------------------- 0.9/3.5 GB 14.9 MB/s eta 0:02:50
#    ---------- ----------------------------- 0.9/3.5 GB 14.9 MB/s eta 0:02:50
#    ---------- ----------------------------- 0.9/3.5 GB 14.8 MB/s eta 0:02:50
#    ---------- ----------------------------- 0.9/3.5 GB 14.8 MB/s eta 0:02:50
#    ----------- ---------------------------- 1.0/3.5 GB 14.8 MB/s eta 0:02:51
#    ----------- ---------------------------- 1.0/3.5 GB 14.7 MB/s eta 0:02:50
#    ----------- ---------------------------- 1.0/3.5 GB 14.7 MB/s eta 0:02:51
#    ----------- ---------------------------- 1.0/3.5 GB 14.7 MB/s eta 0:02:51
#    ----------- ---------------------------- 1.0/3.5 GB 14.7 MB/s eta 0:02:50
#    ----------- ---------------------------- 1.0/3.5 GB 15.0 MB/s eta 0:02:46
#    ----------- ---------------------------- 1.0/3.5 GB 15.1 MB/s eta 0:02:45
#    ----------- ---------------------------- 1.0/3.5 GB 15.2 MB/s eta 0:02:44
#    ----------- ---------------------------- 1.0/3.5 GB 15.2 MB/s eta 0:02:43
#    ----------- ---------------------------- 1.0/3.5 GB 15.3 MB/s eta 0:02:42
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:42
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:41
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:40
#    ----------- ---------------------------- 1.0/3.5 GB 15.5 MB/s eta 0:02:40
#    ----------- ---------------------------- 1.0/3.5 GB 15.5 MB/s eta 0:02:39
#    ----------- ---------------------------- 1.0/3.5 GB 15.5 MB/s eta 0:02:39
#    ----------- ---------------------------- 1.0/3.5 GB 15.6 MB/s eta 0:02:38
#    ----------- ---------------------------- 1.0/3.5 GB 15.6 MB/s eta 0:02:38
#    ----------- ---------------------------- 1.0/3.5 GB 15.6 MB/s eta 0:02:37
#    ----------- ---------------------------- 1.0/3.5 GB 15.6 MB/s eta 0:02:37
#    ----------- ---------------------------- 1.0/3.5 GB 15.6 MB/s eta 0:02:37
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:38
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:38
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:38
#    ----------- ---------------------------- 1.0/3.5 GB 15.4 MB/s eta 0:02:38
#    ------------ --------------------------- 1.0/3.5 GB 15.5 MB/s eta 0:02:37
#    ------------ --------------------------- 1.0/3.5 GB 15.5 MB/s eta 0:02:36
#    ------------ --------------------------- 1.0/3.5 GB 15.5 MB/s eta 0:02:36
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:36
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:35
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:35
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:35
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:35
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:35
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:34
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:34
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:34
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:33
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:33
#    ------------ --------------------------- 1.1/3.5 GB 15.5 MB/s eta 0:02:33
#    ------------ --------------------------- 1.1/3.5 GB 15.6 MB/s eta 0:02:32
#    ------------ --------------------------- 1.1/3.5 GB 15.7 MB/s eta 0:02:31
#    ------------ --------------------------- 1.1/3.5 GB 15.9 MB/s eta 0:02:29
#    ------------ --------------------------- 1.1/3.5 GB 15.9 MB/s eta 0:02:28
#    ------------ --------------------------- 1.1/3.5 GB 16.0 MB/s eta 0:02:27
#    ------------ --------------------------- 1.1/3.5 GB 16.1 MB/s eta 0:02:27
#    ------------ --------------------------- 1.1/3.5 GB 16.1 MB/s eta 0:02:26
#    ------------ --------------------------- 1.1/3.5 GB 16.2 MB/s eta 0:02:25
#    ------------- -------------------------- 1.1/3.5 GB 16.2 MB/s eta 0:02:24
#    ------------- -------------------------- 1.1/3.5 GB 16.3 MB/s eta 0:02:24
#    ------------- -------------------------- 1.1/3.5 GB 16.3 MB/s eta 0:02:23
#    ------------- -------------------------- 1.1/3.5 GB 16.3 MB/s eta 0:02:23
#    ------------- -------------------------- 1.1/3.5 GB 16.4 MB/s eta 0:02:22
#    ------------- -------------------------- 1.1/3.5 GB 16.4 MB/s eta 0:02:22
#    ------------- -------------------------- 1.1/3.5 GB 16.4 MB/s eta 0:02:22
#    ------------- -------------------------- 1.2/3.5 GB 16.4 MB/s eta 0:02:21
#    ------------- -------------------------- 1.2/3.5 GB 16.4 MB/s eta 0:02:21
#    ------------- -------------------------- 1.2/3.5 GB 16.4 MB/s eta 0:02:21
#    ------------- -------------------------- 1.2/3.5 GB 16.4 MB/s eta 0:02:20
#    ------------- -------------------------- 1.2/3.5 GB 16.6 MB/s eta 0:02:19
#    ------------- -------------------------- 1.2/3.5 GB 16.8 MB/s eta 0:02:17
#    ------------- -------------------------- 1.2/3.5 GB 16.9 MB/s eta 0:02:15
#    ------------- -------------------------- 1.2/3.5 GB 17.1 MB/s eta 0:02:14
#    ------------- -------------------------- 1.2/3.5 GB 17.3 MB/s eta 0:02:13
#    ------------- -------------------------- 1.2/3.5 GB 17.4 MB/s eta 0:02:12
#    ------------- -------------------------- 1.2/3.5 GB 17.5 MB/s eta 0:02:10
#    ------------- -------------------------- 1.2/3.5 GB 17.6 MB/s eta 0:02:10
#    ------------- -------------------------- 1.2/3.5 GB 17.6 MB/s eta 0:02:09
#    ------------- -------------------------- 1.2/3.5 GB 17.7 MB/s eta 0:02:08
#    ------------- -------------------------- 1.2/3.5 GB 17.8 MB/s eta 0:02:07
#    ------------- -------------------------- 1.2/3.5 GB 17.8 MB/s eta 0:02:07
#    -------------- ------------------------- 1.2/3.5 GB 17.9 MB/s eta 0:02:06
#    -------------- ------------------------- 1.2/3.5 GB 18.0 MB/s eta 0:02:06
#    -------------- ------------------------- 1.2/3.5 GB 18.0 MB/s eta 0:02:05
#    -------------- ------------------------- 1.2/3.5 GB 18.0 MB/s eta 0:02:05
#    -------------- ------------------------- 1.2/3.5 GB 18.1 MB/s eta 0:02:04
#    -------------- ------------------------- 1.2/3.5 GB 18.0 MB/s eta 0:02:04
#    -------------- ------------------------- 1.2/3.5 GB 18.1 MB/s eta 0:02:04
#    -------------- ------------------------- 1.2/3.5 GB 18.1 MB/s eta 0:02:03
#    -------------- ------------------------- 1.2/3.5 GB 18.1 MB/s eta 0:02:03
#    -------------- ------------------------- 1.2/3.5 GB 18.1 MB/s eta 0:02:03
#    -------------- ------------------------- 1.2/3.5 GB 18.1 MB/s eta 0:02:03
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:02
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:02
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:02
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:02
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:02
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:01
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:01
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:01
#    -------------- ------------------------- 1.3/3.5 GB 18.1 MB/s eta 0:02:01
#    -------------- ------------------------- 1.3/3.5 GB 18.3 MB/s eta 0:01:59
#    -------------- ------------------------- 1.3/3.5 GB 18.4 MB/s eta 0:01:59
#    -------------- ------------------------- 1.3/3.5 GB 18.4 MB/s eta 0:01:59
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:58
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:58
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:58
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:58
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:58
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:57
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:57
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:57
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:57
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:57
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:57
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:56
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:56
#    --------------- ------------------------ 1.3/3.5 GB 18.3 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.3 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.3 MB/s eta 0:01:55
#    --------------- ------------------------ 1.4/3.5 GB 18.3 MB/s eta 0:01:55
#    --------------- ------------------------ 1.4/3.5 GB 18.3 MB/s eta 0:01:55
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:56
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:55
#    --------------- ------------------------ 1.4/3.5 GB 18.1 MB/s eta 0:01:55
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:55
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:55
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:55
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 18.1 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:55
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:55
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:54
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:53
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:53
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:53
#    ---------------- ----------------------- 1.4/3.5 GB 17.9 MB/s eta 0:01:53
#    ---------------- ----------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:53
#    ---------------- ----------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:52
#    ---------------- ----------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:52
#    ---------------- ----------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:52
#    ---------------- ----------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:52
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:52
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:51
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:50
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:50
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:50
#    ----------------- ---------------------- 1.5/3.5 GB 17.9 MB/s eta 0:01:50
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:50
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:48
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:48
#    ----------------- ---------------------- 1.5/3.5 GB 17.8 MB/s eta 0:01:48
#    ----------------- ---------------------- 1.6/3.5 GB 17.8 MB/s eta 0:01:48
#    ----------------- ---------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:49
#    ----------------- ---------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:49
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:49
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:49
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:48
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:48
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:48
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:48
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:48
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:47
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:47
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:47
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:47
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:47
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:46
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:46
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:46
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:46
#    ------------------ --------------------- 1.6/3.5 GB 17.6 MB/s eta 0:01:45
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:45
#    ------------------ --------------------- 1.6/3.5 GB 17.7 MB/s eta 0:01:44
#    ------------------ --------------------- 1.6/3.5 GB 17.7 MB/s eta 0:01:44
#    ------------------ --------------------- 1.6/3.5 GB 17.7 MB/s eta 0:01:44
#    ------------------ --------------------- 1.6/3.5 GB 17.8 MB/s eta 0:01:43
#    ------------------ --------------------- 1.6/3.5 GB 17.5 MB/s eta 0:01:45
#    ------------------ --------------------- 1.6/3.5 GB 17.3 MB/s eta 0:01:46
#    ------------------ --------------------- 1.6/3.5 GB 17.2 MB/s eta 0:01:46
#    ------------------ --------------------- 1.6/3.5 GB 17.2 MB/s eta 0:01:46
#    ------------------- -------------------- 1.6/3.5 GB 17.2 MB/s eta 0:01:46
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:46
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:46
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:46
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 17.2 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 17.4 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 17.4 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:42
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:42
#    ------------------- -------------------- 1.7/3.5 GB 17.3 MB/s eta 0:01:42
#    ------------------- -------------------- 1.7/3.5 GB 17.1 MB/s eta 0:01:43
#    ------------------- -------------------- 1.7/3.5 GB 16.9 MB/s eta 0:01:44
#    ------------------- -------------------- 1.7/3.5 GB 16.9 MB/s eta 0:01:44
#    ------------------- -------------------- 1.7/3.5 GB 16.8 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 16.7 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 16.7 MB/s eta 0:01:45
#    ------------------- -------------------- 1.7/3.5 GB 16.5 MB/s eta 0:01:46
#    ------------------- -------------------- 1.7/3.5 GB 16.4 MB/s eta 0:01:47
#    ------------------- -------------------- 1.7/3.5 GB 16.4 MB/s eta 0:01:47
#    ------------------- -------------------- 1.7/3.5 GB 16.3 MB/s eta 0:01:47
#    ------------------- -------------------- 1.7/3.5 GB 16.3 MB/s eta 0:01:47
#    -------------------- ------------------- 1.7/3.5 GB 16.2 MB/s eta 0:01:47
#    -------------------- ------------------- 1.7/3.5 GB 16.1 MB/s eta 0:01:48
#    -------------------- ------------------- 1.7/3.5 GB 16.1 MB/s eta 0:01:48
#    -------------------- ------------------- 1.7/3.5 GB 16.1 MB/s eta 0:01:48
#    -------------------- ------------------- 1.7/3.5 GB 16.0 MB/s eta 0:01:48
#    -------------------- ------------------- 1.7/3.5 GB 16.0 MB/s eta 0:01:48
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:48
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:47
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:47
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:47
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:47
#    -------------------- ------------------- 1.8/3.5 GB 15.9 MB/s eta 0:01:47
#    -------------------- ------------------- 1.8/3.5 GB 15.9 MB/s eta 0:01:46
#    -------------------- ------------------- 1.8/3.5 GB 15.9 MB/s eta 0:01:46
#    -------------------- ------------------- 1.8/3.5 GB 15.9 MB/s eta 0:01:46
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:46
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:45
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:45
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:45
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:45
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:44
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:44
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:44
#    -------------------- ------------------- 1.8/3.5 GB 16.0 MB/s eta 0:01:44
#    -------------------- ------------------- 1.8/3.5 GB 16.2 MB/s eta 0:01:42
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:42
#    --------------------- ------------------ 1.8/3.5 GB 16.1 MB/s eta 0:01:42
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:41
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:41
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:41
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:41
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:40
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:40
#    --------------------- ------------------ 1.8/3.5 GB 16.2 MB/s eta 0:01:40
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:40
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:39
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:39
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:39
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:39
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:39
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:38
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:38
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:38
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:38
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:37
#    --------------------- ------------------ 1.9/3.5 GB 16.2 MB/s eta 0:01:37
#    --------------------- ------------------ 1.9/3.5 GB 16.5 MB/s eta 0:01:35
#    --------------------- ------------------ 1.9/3.5 GB 16.7 MB/s eta 0:01:34
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:34
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:33
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:33
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:33
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:33
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:32
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:32
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:32
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:32
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:32
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:31
#    ---------------------- ----------------- 1.9/3.5 GB 16.7 MB/s eta 0:01:31
#    ---------------------- ----------------- 2.0/3.5 GB 16.7 MB/s eta 0:01:31
#    ---------------------- ----------------- 2.0/3.5 GB 16.7 MB/s eta 0:01:31
#    ---------------------- ----------------- 2.0/3.5 GB 16.8 MB/s eta 0:01:30
#    ---------------------- ----------------- 2.0/3.5 GB 16.7 MB/s eta 0:01:30
#    ---------------------- ----------------- 2.0/3.5 GB 16.8 MB/s eta 0:01:30
#    ---------------------- ----------------- 2.0/3.5 GB 17.1 MB/s eta 0:01:28
#    ---------------------- ----------------- 2.0/3.5 GB 17.2 MB/s eta 0:01:27
#    ---------------------- ----------------- 2.0/3.5 GB 17.4 MB/s eta 0:01:26
#    ---------------------- ----------------- 2.0/3.5 GB 17.6 MB/s eta 0:01:25
#    ---------------------- ----------------- 2.0/3.5 GB 17.7 MB/s eta 0:01:24
#    ---------------------- ----------------- 2.0/3.5 GB 17.8 MB/s eta 0:01:23
#    ----------------------- ---------------- 2.0/3.5 GB 17.9 MB/s eta 0:01:23
#    ----------------------- ---------------- 2.0/3.5 GB 18.0 MB/s eta 0:01:22
#    ----------------------- ---------------- 2.0/3.5 GB 18.0 MB/s eta 0:01:22
#    ----------------------- ---------------- 2.0/3.5 GB 18.1 MB/s eta 0:01:21
#    ----------------------- ---------------- 2.0/3.5 GB 18.2 MB/s eta 0:01:21
#    ----------------------- ---------------- 2.0/3.5 GB 18.2 MB/s eta 0:01:20
# ...
#    ----------------------------------- ---- 3.0/3.5 GB 9.5 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.0/3.5 GB 9.4 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.0/3.5 GB 9.4 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.4 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.3 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.3 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.3 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.2 MB/s eta 0:00:45
#    ----------------------------------- ---- 3.1/3.5 GB 9.2 MB/s eta 0:00:45
#    ----------------------------------- ---- 3.1/3.5 GB 9.2 MB/s eta 0:00:45
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:45
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:45
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:44
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:43
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:43
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:43
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:43
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:42
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:42
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:42
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:41
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:41
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:41
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:41
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:40
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:40
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:40
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:40
#    ----------------------------------- ---- 3.1/3.5 GB 9.1 MB/s eta 0:00:40
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:39
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:39
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:39
#    ----------------------------------- ---- 3.1/3.5 GB 9.0 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.9 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.9 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.9 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.8 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.8 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.8 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.7 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.7 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.6 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.6 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.5 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.6 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.6 MB/s eta 0:00:39
#    ------------------------------------ --- 3.1/3.5 GB 8.6 MB/s eta 0:00:38
#    ------------------------------------ --- 3.1/3.5 GB 8.6 MB/s eta 0:00:38
#    ------------------------------------ --- 3.1/3.5 GB 8.7 MB/s eta 0:00:37
#    ------------------------------------ --- 3.1/3.5 GB 8.8 MB/s eta 0:00:37
#    ------------------------------------ --- 3.1/3.5 GB 8.8 MB/s eta 0:00:36
#    ------------------------------------ --- 3.1/3.5 GB 8.9 MB/s eta 0:00:36
#    ------------------------------------ --- 3.2/3.5 GB 8.9 MB/s eta 0:00:35
#    ------------------------------------ --- 3.2/3.5 GB 9.0 MB/s eta 0:00:35
#    ------------------------------------ --- 3.2/3.5 GB 9.0 MB/s eta 0:00:34
#    ------------------------------------ --- 3.2/3.5 GB 9.1 MB/s eta 0:00:34
#    ------------------------------------ --- 3.2/3.5 GB 9.1 MB/s eta 0:00:33
#    ------------------------------------ --- 3.2/3.5 GB 9.2 MB/s eta 0:00:33
#    ------------------------------------ --- 3.2/3.5 GB 9.2 MB/s eta 0:00:32
#    ------------------------------------ --- 3.2/3.5 GB 9.2 MB/s eta 0:00:32
#    ------------------------------------ --- 3.2/3.5 GB 9.2 MB/s eta 0:00:31
#    ------------------------------------ --- 3.2/3.5 GB 9.3 MB/s eta 0:00:31
#    ------------------------------------ --- 3.2/3.5 GB 9.3 MB/s eta 0:00:30
#    ------------------------------------ --- 3.2/3.5 GB 9.3 MB/s eta 0:00:30
#    ------------------------------------ --- 3.2/3.5 GB 9.3 MB/s eta 0:00:29
#    ------------------------------------ --- 3.2/3.5 GB 9.4 MB/s eta 0:00:29
#    ------------------------------------ --- 3.2/3.5 GB 9.5 MB/s eta 0:00:28
#    ------------------------------------ --- 3.2/3.5 GB 9.5 MB/s eta 0:00:28
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:27
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:27
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:27
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:27
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:26
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:26
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:26
#    ------------------------------------- -- 3.2/3.5 GB 9.6 MB/s eta 0:00:26
#    ------------------------------------- -- 3.2/3.5 GB 9.7 MB/s eta 0:00:25
#    ------------------------------------- -- 3.2/3.5 GB 9.9 MB/s eta 0:00:25
#    ------------------------------------- -- 3.2/3.5 GB 10.0 MB/s eta 0:00:24
#    ------------------------------------- -- 3.2/3.5 GB 10.1 MB/s eta 0:00:24
#    ------------------------------------- -- 3.2/3.5 GB 10.2 MB/s eta 0:00:23
#    ------------------------------------- -- 3.2/3.5 GB 10.2 MB/s eta 0:00:23
#    ------------------------------------- -- 3.2/3.5 GB 10.3 MB/s eta 0:00:22
#    ------------------------------------- -- 3.2/3.5 GB 10.3 MB/s eta 0:00:22
#    ------------------------------------- -- 3.2/3.5 GB 10.3 MB/s eta 0:00:22
#    ------------------------------------- -- 3.2/3.5 GB 10.3 MB/s eta 0:00:22
#    ------------------------------------- -- 3.2/3.5 GB 10.3 MB/s eta 0:00:22
#    ------------------------------------- -- 3.2/3.5 GB 10.3 MB/s eta 0:00:22
#    ------------------------------------- -- 3.2/3.5 GB 10.4 MB/s eta 0:00:21
#    ------------------------------------- -- 3.2/3.5 GB 10.4 MB/s eta 0:00:21
#    ------------------------------------- -- 3.3/3.5 GB 10.5 MB/s eta 0:00:21
#    ------------------------------------- -- 3.3/3.5 GB 10.5 MB/s eta 0:00:20
#    ------------------------------------- -- 3.3/3.5 GB 10.6 MB/s eta 0:00:20
#    ------------------------------------- -- 3.3/3.5 GB 10.6 MB/s eta 0:00:20
#    ------------------------------------- -- 3.3/3.5 GB 10.6 MB/s eta 0:00:20
#    ------------------------------------- -- 3.3/3.5 GB 10.6 MB/s eta 0:00:19
#    ------------------------------------- -- 3.3/3.5 GB 10.7 MB/s eta 0:00:19
#    ------------------------------------- -- 3.3/3.5 GB 10.7 MB/s eta 0:00:19
#    ------------------------------------- -- 3.3/3.5 GB 10.7 MB/s eta 0:00:19
#    ------------------------------------- -- 3.3/3.5 GB 10.7 MB/s eta 0:00:18
#    ------------------------------------- -- 3.3/3.5 GB 10.7 MB/s eta 0:00:18
#    ------------------------------------- -- 3.3/3.5 GB 10.8 MB/s eta 0:00:18
#    ------------------------------------- -- 3.3/3.5 GB 10.8 MB/s eta 0:00:18
#    ------------------------------------- -- 3.3/3.5 GB 10.8 MB/s eta 0:00:17
#    ------------------------------------- -- 3.3/3.5 GB 10.8 MB/s eta 0:00:17
#    ------------------------------------- -- 3.3/3.5 GB 10.8 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.8 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 10.8 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 10.8 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 10.8 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 10.6 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 10.6 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 10.5 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.5 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.3 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.1 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.1 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 10.0 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.9 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.9 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.8 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.8 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.7 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.6 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.6 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.5 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:18
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:17
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 9.2 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:16
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:15
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:15
#    -------------------------------------- - 3.3/3.5 GB 9.3 MB/s eta 0:00:15
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:15
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:14
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:14
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:14
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:14
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:13
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:13
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:13
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:13
#    -------------------------------------- - 3.3/3.5 GB 9.4 MB/s eta 0:00:12
#    -------------------------------------- - 3.4/3.5 GB 9.5 MB/s eta 0:00:12
#    -------------------------------------- - 3.4/3.5 GB 9.5 MB/s eta 0:00:12
#    -------------------------------------- - 3.4/3.5 GB 9.5 MB/s eta 0:00:11
#    -------------------------------------- - 3.4/3.5 GB 9.5 MB/s eta 0:00:11
#    -------------------------------------- - 3.4/3.5 GB 9.5 MB/s eta 0:00:11
#    -------------------------------------- - 3.4/3.5 GB 9.5 MB/s eta 0:00:10
#    -------------------------------------- - 3.4/3.5 GB 9.6 MB/s eta 0:00:10
#    -------------------------------------- - 3.4/3.5 GB 9.7 MB/s eta 0:00:10
#    ---------------------------------------  3.4/3.5 GB 9.8 MB/s eta 0:00:09
#    ---------------------------------------  3.4/3.5 GB 9.8 MB/s eta 0:00:09
#    ---------------------------------------  3.4/3.5 GB 9.9 MB/s eta 0:00:08
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:08
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:08
#    ---------------------------------------  3.4/3.5 GB 10.2 MB/s eta 0:00:07
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:07
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:07
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:07
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:07
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:06
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:06
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:06
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:06
#    ---------------------------------------  3.4/3.5 GB 10.1 MB/s eta 0:00:06
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:05
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:05
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:05
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:05
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:04
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:04
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:04
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:03
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:03
#    ---------------------------------------  3.4/3.5 GB 10.0 MB/s eta 0:00:03
#    ---------------------------------------  3.4/3.5 GB 9.9 MB/s eta 0:00:03
#    ---------------------------------------  3.4/3.5 GB 9.9 MB/s eta 0:00:02
#    ---------------------------------------  3.4/3.5 GB 9.9 MB/s eta 0:00:02
#    ---------------------------------------  3.5/3.5 GB 9.9 MB/s eta 0:00:02
#    ---------------------------------------  3.5/3.5 GB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 GB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 GB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 GB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 GB 9.8 MB/s eta 0:00:00
# Installing collected packages: torch, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0
#     Uninstalling torch-2.8.0:
#       Successfully uninstalled torch-2.8.0
# Successfully installed torch-2.8.0+cu128 torchaudio-2.8.0+cu128
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas     
# %pip install matplotlib  
# %pip install scikit-learn  
# %pip install ultralytics
# Out:
# Collecting pandas
#   Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl (11.0 MB)
# Downloading numpy-2.3.2-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.8 MB 16.8 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.8 MB 16.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.8 MB 17.3 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.8 MB 17.2 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 10.8 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.3.2 pandas-2.3.1 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Downloading matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.5-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 11.2 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 16.7 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.0 kiwisolver-1.4.9 matplotlib-3.10.5 pillow-11.3.0 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from scikit-learn) (2.3.2)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl (8.7 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl (38.5 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.1 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting ultralytics
#   Downloading ultralytics-8.3.179-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from ultralytics) (2.3.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from ultralytics) (3.10.5)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from ultralytics) (11.3.0)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from ultralytics) (1.16.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.8.0-cp312-cp312-win_amd64.whl.metadata (30 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.23.0-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from ultralytics) (7.0.0)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from ultralytics) (2.3.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Collecting charset_normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Downloading charset_normalizer-3.4.3-cp312-cp312-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch>=1.8.0->ultralytics)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting setuptools (from torch>=1.8.0->ultralytics)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.0->ultralytics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Downloading ultralytics-8.3.179-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 12.6 MB/s eta 0:00:00
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------------- -------------------------- 4.2/12.6 MB 19.3 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.6 MB 19.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 17.5 MB/s eta 0:00:00
# Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading torch-2.8.0-cp312-cp312-win_amd64.whl (241.3 MB)
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#     --------------------------------------- 3.4/241.3 MB 18.3 MB/s eta 0:00:14
#     --------------------------------------- 4.2/241.3 MB 19.4 MB/s eta 0:00:13
#     --------------------------------------- 4.5/241.3 MB 7.3 MB/s eta 0:00:33
#    - -------------------------------------- 7.9/241.3 MB 9.5 MB/s eta 0:00:25
#    - -------------------------------------- 11.5/241.3 MB 11.3 MB/s eta 0:00:21
#    -- ------------------------------------- 15.5/241.3 MB 12.6 MB/s eta 0:00:18
#    --- ------------------------------------ 19.1/241.3 MB 13.4 MB/s eta 0:00:17
#    --- ------------------------------------ 22.8/241.3 MB 14.0 MB/s eta 0:00:16
#    ---- ----------------------------------- 26.5/241.3 MB 14.5 MB/s eta 0:00:15
#    ---- ----------------------------------- 30.1/241.3 MB 14.8 MB/s eta 0:00:15
#    ----- ---------------------------------- 34.1/241.3 MB 15.2 MB/s eta 0:00:14
#    ------ --------------------------------- 37.7/241.3 MB 15.5 MB/s eta 0:00:14
#    ------ --------------------------------- 41.7/241.3 MB 15.7 MB/s eta 0:00:13
#    ------- -------------------------------- 45.6/241.3 MB 16.0 MB/s eta 0:00:13
#    -------- ------------------------------- 49.5/241.3 MB 16.2 MB/s eta 0:00:12
#    -------- ------------------------------- 53.2/241.3 MB 16.3 MB/s eta 0:00:12
#    --------- ------------------------------ 57.1/241.3 MB 16.4 MB/s eta 0:00:12
#    ---------- ----------------------------- 60.8/241.3 MB 16.6 MB/s eta 0:00:11
#    ---------- ----------------------------- 64.7/241.3 MB 16.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 67.6/241.3 MB 16.6 MB/s eta 0:00:11
#    ----------- ---------------------------- 69.5/241.3 MB 16.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 72.4/241.3 MB 16.2 MB/s eta 0:00:11
#    ------------ --------------------------- 74.7/241.3 MB 16.2 MB/s eta 0:00:11
#    ------------ --------------------------- 76.5/241.3 MB 15.8 MB/s eta 0:00:11
#    ------------ --------------------------- 78.4/241.3 MB 15.5 MB/s eta 0:00:11
#    ------------- -------------------------- 80.2/241.3 MB 15.1 MB/s eta 0:00:11
#    ------------- -------------------------- 82.1/241.3 MB 14.9 MB/s eta 0:00:11
#    ------------- -------------------------- 83.9/241.3 MB 14.7 MB/s eta 0:00:11
#    -------------- ------------------------- 86.0/241.3 MB 14.6 MB/s eta 0:00:11
#    -------------- ------------------------- 87.8/241.3 MB 14.4 MB/s eta 0:00:11
#    -------------- ------------------------- 89.9/241.3 MB 14.2 MB/s eta 0:00:11
#    --------------- ------------------------ 92.0/241.3 MB 14.1 MB/s eta 0:00:11
#    --------------- ------------------------ 94.1/241.3 MB 14.0 MB/s eta 0:00:11
#    --------------- ------------------------ 96.5/241.3 MB 13.9 MB/s eta 0:00:11
#    ---------------- ----------------------- 98.6/241.3 MB 13.8 MB/s eta 0:00:11
#    ---------------- ---------------------- 100.9/241.3 MB 13.8 MB/s eta 0:00:11
#    ---------------- ---------------------- 103.5/241.3 MB 13.7 MB/s eta 0:00:11
#    ----------------- --------------------- 105.9/241.3 MB 13.7 MB/s eta 0:00:10
#    ----------------- --------------------- 108.5/241.3 MB 13.7 MB/s eta 0:00:10
#    ----------------- --------------------- 111.1/241.3 MB 13.6 MB/s eta 0:00:10
#    ------------------ -------------------- 114.0/241.3 MB 13.6 MB/s eta 0:00:10
#    ------------------ -------------------- 116.7/241.3 MB 13.6 MB/s eta 0:00:10
#    ------------------- ------------------- 119.5/241.3 MB 13.7 MB/s eta 0:00:09
#    ------------------- ------------------- 122.4/241.3 MB 13.7 MB/s eta 0:00:09
#    -------------------- ------------------ 125.6/241.3 MB 13.7 MB/s eta 0:00:09
#    -------------------- ------------------ 128.5/241.3 MB 13.7 MB/s eta 0:00:09
#    --------------------- ----------------- 131.6/241.3 MB 13.8 MB/s eta 0:00:08
#    --------------------- ----------------- 134.7/241.3 MB 13.8 MB/s eta 0:00:08
#    ---------------------- ---------------- 138.1/241.3 MB 13.8 MB/s eta 0:00:08
#    ---------------------- ---------------- 141.3/241.3 MB 13.9 MB/s eta 0:00:08
#    ----------------------- --------------- 145.0/241.3 MB 13.9 MB/s eta 0:00:07
#    ----------------------- --------------- 148.4/241.3 MB 14.0 MB/s eta 0:00:07
#    ------------------------ -------------- 151.8/241.3 MB 14.1 MB/s eta 0:00:07
#    ------------------------- ------------- 155.5/241.3 MB 14.1 MB/s eta 0:00:07
#    ------------------------- ------------- 159.1/241.3 MB 14.2 MB/s eta 0:00:06
#    -------------------------- ------------ 162.8/241.3 MB 14.3 MB/s eta 0:00:06
#    -------------------------- ------------ 166.5/241.3 MB 14.4 MB/s eta 0:00:06
#    --------------------------- ----------- 170.1/241.3 MB 14.4 MB/s eta 0:00:05
#    ---------------------------- ---------- 175.1/241.3 MB 14.5 MB/s eta 0:00:05
#    ---------------------------- ---------- 178.8/241.3 MB 14.6 MB/s eta 0:00:05
#    ----------------------------- --------- 182.5/241.3 MB 14.6 MB/s eta 0:00:05
#    ------------------------------ -------- 186.4/241.3 MB 14.7 MB/s eta 0:00:04
#    ------------------------------ -------- 190.3/241.3 MB 14.8 MB/s eta 0:00:04
#    ------------------------------- ------- 193.7/241.3 MB 14.8 MB/s eta 0:00:04
#    ------------------------------- ------- 197.7/241.3 MB 14.9 MB/s eta 0:00:03
#    -------------------------------- ------ 201.6/241.3 MB 14.9 MB/s eta 0:00:03
#    --------------------------------- ----- 205.0/241.3 MB 15.0 MB/s eta 0:00:03
#    --------------------------------- ----- 208.7/241.3 MB 15.0 MB/s eta 0:00:03
#    ---------------------------------- ---- 212.6/241.3 MB 15.1 MB/s eta 0:00:02
#    ---------------------------------- ---- 216.3/241.3 MB 15.1 MB/s eta 0:00:02
#    ----------------------------------- --- 219.9/241.3 MB 15.2 MB/s eta 0:00:02
#    ------------------------------------ -- 223.9/241.3 MB 15.2 MB/s eta 0:00:02
#    ------------------------------------ -- 228.1/241.3 MB 15.3 MB/s eta 0:00:01
#    ------------------------------------- - 232.0/241.3 MB 15.3 MB/s eta 0:00:01
#    --------------------------------------  235.7/241.3 MB 15.4 MB/s eta 0:00:01
#    --------------------------------------  239.3/241.3 MB 15.4 MB/s eta 0:00:01
#    --------------------------------------  241.2/241.3 MB 15.4 MB/s eta 0:00:01
#    --------------------------------------  241.2/241.3 MB 15.4 MB/s eta 0:00:01
#    --------------------------------------- 241.3/241.3 MB 15.1 MB/s eta 0:00:00
# Downloading torchvision-0.23.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 14.2 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading charset_normalizer-3.4.3-cp312-cp312-win_amd64.whl (107 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: py-cpuinfo, mpmath, urllib3, typing-extensions, tqdm, sympy, setuptools, pyyaml, numpy, networkx, MarkupSafe, idna, fsspec, filelock, charset_normalizer, certifi, requests, opencv-python, jinja2, torch, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.2
#     Uninstalling numpy-2.3.2:
#       Successfully uninstalled numpy-2.3.2
# Successfully installed MarkupSafe-3.0.2 certifi-2025.8.3 charset_normalizer-3.4.3 filelock-3.18.0 fsspec-2025.7.0 idna-3.10 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 opencv-python-4.12.0.88 py-cpuinfo-9.0.0 pyyaml-6.0.2 requests-2.32.4 setuptools-80.9.0 sympy-1.14.0 torch-2.8.0 torchvision-0.23.0 tqdm-4.67.1 typing-extensions-4.14.1 ultralytics-8.3.179 ultralytics-thop-2.0.15 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path

zip_path = (Path.home() / "Downloads" / "stinkbug_image_data.zip").resolve()
print("Absolute path to the zip file:", zip_path)
# Out:
# Absolute path to the zip file: C:\Users\SauravUpadhyaya\Downloads\stinkbug_image_data.zip

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch

print(f"PyTorch version: {torch.__version__}") 
cuda_available = torch.cuda.is_available() 
print(f"CUDA available: {cuda_available}") 
 
if cuda_available: 
    device = torch.device("cuda") 
    print(f"Using device: {device}") 
    print(f"GPU name: {torch.cuda.get_device_name(0)}") 
    x = torch.randn(10, 10).to(device) 
    print(f"Tensor on GPU: {x.device}") 
else: 
    device = torch.device("cpu") 
    print(f"Using device: {device}")
# Out:
# PyTorch version: 2.7.1+cu128
# CUDA available: True
# Using device: cuda
# GPU name: NVIDIA RTX 4000 Ada Generation
# Tensor on GPU: cuda:0

# %%
# !pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 2.8.0+cu128
# Uninstalling torch-2.8.0+cu128:
#   Successfully uninstalled torch-2.8.0+cu128
# Found existing installation: torchvision 0.23.0
# Uninstalling torchvision-0.23.0:
#   Successfully uninstalled torchvision-0.23.0
# Found existing installation: torchaudio 2.8.0+cu128
# Uninstalling torchaudio-2.8.0+cu128:
#   Successfully uninstalled torchaudio-2.8.0+cu128
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\.venv\Lib\site-packages\~orch'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\.venv\Lib\site-packages\~orchvision'.
# You can safely remove it manually.

# %%
# !pip install torch==2.7.1 
# !python -m pip install torch==2.7.1  torchvision==0.18.1 torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Requirement already satisfied: torch==2.7.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (2.7.1+cu128)
# Requirement already satisfied: filelock in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (2025.7.0)
# Requirement already satisfied: setuptools in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from sympy>=1.13.3->torch==2.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from jinja2->torch==2.7.1) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import zipfile   
import os
from dotenv import load_dotenv

load_dotenv()

# zip_path = os.getenv("ZIP_FILE_PATH") 

unzip_to = "stinkbug_image_data"

# Extract
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(unzip_to)

print("Stinkbug Image data is available in your project directory ")
# Out:
# Stinkbug Image data is available in your project directory

# %%
for root, dirs, files in os.walk(unzip_to):
    for file in files[:5]:
        print(os.path.join(root, file))
# Out:
# stinkbug_image_data\data.yaml
# stinkbug_image_data\README.roboflow.txt
# stinkbug_image_data\test\labels.cache
# stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg
# stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg
# stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg
# stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg
# stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg
# stinkbug_image_data\test\labels\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.txt
# stinkbug_image_data\test\labels\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.txt
# stinkbug_image_data\test\labels\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.txt
# stinkbug_image_data\test\labels\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.txt
# stinkbug_image_data\test\labels\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.txt
# stinkbug_image_data\train\labels.cache
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.jpg
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.txt
# stinkbug_image_data\train\training_results\train\args.yaml
# stinkbug_image_data\train\training_results\train10\args.yaml
# stinkbug_image_data\train\training_results\train10\BoxF1_curve.png
# stinkbug_image_data\train\training_results\train10\BoxPR_curve.png
# stinkbug_image_data\train\training_results\train10\BoxP_curve.png
# stinkbug_image_data\train\training_results\train10\BoxR_curve.png
# stinkbug_image_data\train\training_results\train10\weights\best.pt
# stinkbug_image_data\train\training_results\train10\weights\last.pt
# stinkbug_image_data\train\training_results\train2\args.yaml
# stinkbug_image_data\train\training_results\train3\args.yaml
# stinkbug_image_data\train\training_results\train4\args.yaml
# stinkbug_image_data\train\training_results\train5\args.yaml
# stinkbug_image_data\train\training_results\train6\args.yaml
# stinkbug_image_data\train\training_results\train7\args.yaml
# stinkbug_image_data\train\training_results\train8\args.yaml
# stinkbug_image_data\train\training_results\train9\args.yaml
# stinkbug_image_data\valid\labels.cache
# stinkbug_image_data\valid\images\DSC_0013_jpg.rf.fda03d81772085f5c4bee2b11d188759.jpg
# stinkbug_image_data\valid\images\DSC_0026_jpg.rf.9d21915703225874bc2e094adbecb619.jpg
# stinkbug_image_data\valid\images\DSC_0028_jpg.rf.d3e78c7ebb1de182e80e2b4a5981f457.jpg
# stinkbug_image_data\valid\images\DSC_0036_jpg.rf.f28220a148fc77554f797dd941e90f02.jpg
# stinkbug_image_data\valid\images\DSC_0043_jpg.rf.896563444a0279283ec4adcb710b652d.jpg
# stinkbug_image_data\valid\labels\DSC_0013_jpg.rf.fda03d81772085f5c4bee2b11d188759.txt
# stinkbug_image_data\valid\labels\DSC_0026_jpg.rf.9d21915703225874bc2e094adbecb619.txt
# stinkbug_image_data\valid\labels\DSC_0028_jpg.rf.d3e78c7ebb1de182e80e2b4a5981f457.txt
# stinkbug_image_data\valid\labels\DSC_0036_jpg.rf.f28220a148fc77554f797dd941e90f02.txt
# stinkbug_image_data\valid\labels\DSC_0043_jpg.rf.896563444a0279283ec4adcb710b652d.txt

# %%
image_data = './stinkbug_image_data/train/images'
label_data  = './stinkbug_image_data/train/labels'

# %%
import os
count = 0
image_list= []
for i in os.listdir(image_data):
  print(i)
  image_list.append(i)
  count += 1
  if count ==5:
    break;

print("\nFirst 5 images in the dataset:")
image_list
# Out:
# DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.jpg
# DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.jpg
# DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.jpg
# DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.jpg
# DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.jpg
#
# First 5 images in the dataset:
# ['DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.jpg',
#  'DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.jpg',
#  'DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.jpg',
#  'DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.jpg',
#  'DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.jpg']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, axs = plt.subplots(2, 2, figsize=(4, 4))
axs = axs.flatten()

for i, filename in enumerate(image_list[:4]):
    img_path = os.path.join(image_data, filename)
    img = mpimg.imread(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
count = 0
for i in os.listdir(label_data):
  print(i)
  count +=1
  if count == 5:
    break;
# Out:
# DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.txt
# DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.txt
# DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.txt
# DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.txt
# DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.txt

# %%
count = 0
for filename in os.listdir(label_data):
  file_path = os.path.join(label_data, filename)
  with open(file_path, 'r') as f:
      content = f.read()
      print(f"Content of {filename}:\n{content}")
      count += 1
      if count == 5:
        break
# Out:
# Content of DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.txt:
# 0 0.3609375 0.50859375 0.0765625 0.121875
# 0 0.51640625 0.5890625 0.09375 0.10625
# 0 0.678125 0.61171875 0.0796875 0.1125
# 0 0.33671875 0.28125 0.078125 0.096875
# 0 0.515625 0.30078125 0.0796875 0.109375
# 0 0.66015625 0.359375 0.06875 0.128125
# Content of DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.txt:
# 0 0.6375 0.4796875 0.0734375 0.1203125
# 0 0.50234375 0.590625 0.090625 0.103125
# 0 0.34921875 0.646875 0.0765625 0.109375
# 0 0.6140625 0.25234375 0.075 0.0953125
# 0 0.44296875 0.3078125 0.0765625 0.1078125
# 0 0.3140625 0.3953125 0.0640625 0.1265625
# Content of DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.txt:
# 0 0.3609375 0.49140625 0.0625 0.115625
# 0 0.50546875 0.590625 0.0828125 0.096875
# 0 0.66328125 0.6328125 0.0671875 0.1046875
# 0 0.36484375 0.26328125 0.0671875 0.090625
# 0 0.53984375 0.30390625 0.06875 0.103125
# 0 0.67578125 0.3796875 0.053125 0.121875
# Content of DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.txt:
# 0 0.3609375 0.50859375 0.06328125 0.115625
# 0 0.50546875 0.409375 0.0828125 0.09609375
# 0 0.66328125 0.3671875 0.0671875 0.1046875
# 0 0.36484375 0.73671875 0.0671875 0.08984375
# 0 0.53984375 0.69609375 0.06796875 0.10234375
# 0 0.67578125 0.6203125 0.05390625 0.12265625
# Content of DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.txt:
# 0 0.6390625 0.50390625 0.0671875 0.1171875
# 0 0.49140625 0.409375 0.0859375 0.0984375
# 0 0.33203125 0.37265625 0.0703125 0.10625
# 0 0.64296875 0.73203125 0.0703125 0.0921875
# 0 0.4671875 0.69765625 0.071875 0.1046875
# 0 0.32890625 0.6265625 0.0578125 0.125

# %%
import pandas as pd

label_files = [f for f in os.listdir(label_data)[:5] if f.endswith('.txt')]

data = []
for label_file in label_files:
    label_path = os.path.join(label_data, label_file)
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            data.append(([label_file] + parts))

if data:
    df = pd.DataFrame(data, columns=['filename', 'class_id', 'x_center', 'y_center', 'width', 'height'])
    display(df.head())
    display(df.tail())
# Out:
#                                             filename class_id    x_center  \
# 0  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0   0.3609375
# 1  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0  0.51640625
# 2  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0    0.678125
# 3  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0  0.33671875
# 4  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0    0.515625
#
#      y_center      width    height
# 0  0.50859375  0.0765625  0.121875
# 1   0.5890625    0.09375   0.10625
# 2  0.61171875  0.0796875    0.1125
# 3     0.28125   0.078125  0.096875
# 4  0.30078125  0.0796875  0.109375
#                                              filename class_id    x_center  \
# 25  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.49140625
# 26  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.33203125
# 27  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.64296875
# 28  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0   0.4671875
# 29  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.32890625
#
#       y_center      width     height
# 25    0.409375  0.0859375  0.0984375
# 26  0.37265625  0.0703125    0.10625
# 27  0.73203125  0.0703125  0.0921875
# 28  0.69765625   0.071875  0.1046875
# 29   0.6265625  0.0578125      0.125

# %%
image_filenames = os.listdir(image_data)[:5]

image_paths = [os.path.normpath(os.path.join(image_data, filename)) for filename in image_filenames]
label_paths = [os.path.normpath(os.path.join(label_data, filename.replace('.jpg', '.txt'))) for filename in image_filenames]

print("image paths:", image_paths)
print("\n")
print("label paths:", label_paths)
print("\n")
print("First 5 Image Paths:")
for path in image_paths:
    print(path)

print("\n")
print("First 5 Label Paths:")
for path in label_paths:
    print(path)
# Out:
# image paths: ['stinkbug_image_data\\train\\images\\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.jpg', 'stinkbug_image_data\\train\\images\\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.jpg', 'stinkbug_image_data\\train\\images\\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.jpg', 'stinkbug_image_data\\train\\images\\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.jpg', 'stinkbug_image_data\\train\\images\\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.jpg']
#
#
# label paths: ['stinkbug_image_data\\train\\labels\\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.txt', 'stinkbug_image_data\\train\\labels\\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.txt', 'stinkbug_image_data\\train\\labels\\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.txt', 'stinkbug_image_data\\train\\labels\\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.txt', 'stinkbug_image_data\\train\\labels\\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.txt']
#
#
# First 5 Image Paths:
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.jpg
# stinkbug_image_data\train\images\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.jpg
#
#
# First 5 Label Paths:
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.txt
# stinkbug_image_data\train\labels\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.txt

# %%
image_filenames = [f for f in os.listdir(image_data) if f.endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

image_label_pairs = []
for filename in image_filenames:
    image_path = os.path.join(image_data, filename)
    label_filename = filename.rsplit('.', 1)[0] + '.txt'
    label_path = os.path.join(label_data, label_filename)
    image_label_pairs.append((image_path, label_path))

print("List of tuples following format of(Image path , label path)")
print(image_label_pairs[:5])

print("\n")
print(f" Number of (Image path , label path) pairs : {len(image_label_pairs)}")
# Out:
# List of tuples following format of(Image path , label path)
# [('./stinkbug_image_data/train/images\\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.jpg', './stinkbug_image_data/train/labels\\DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1eb.txt'), ('./stinkbug_image_data/train/images\\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.jpg', './stinkbug_image_data/train/labels\\DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba48.txt'), ('./stinkbug_image_data/train/images\\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.jpg', './stinkbug_image_data/train/labels\\DSC_0015_jpg.rf.66920b5d757b16532834f8cd2eedf577.txt'), ('./stinkbug_image_data/train/images\\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.jpg', './stinkbug_image_data/train/labels\\DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938ce6.txt'), ('./stinkbug_image_data/train/images\\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.jpg', './stinkbug_image_data/train/labels\\DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c22c.txt')]
#
#
#  Number of (Image path , label path) pairs : 410

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os
import io
from PIL import Image

def draw_boxes_on_image(image_path, label_path):
    img = Image.open(image_path).convert("RGB")
    img_width, img_height = img.size

    fig, ax = plt.subplots(1)
    ax.imshow(img)

    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) == 5:
                    class_id, x_center, y_center, width, height = map(float, parts)
                    x1 = (x_center - width / 2) * img_width
                    y1 = (y_center - height / 2) * img_height
                    box_width = width * img_width
                    box_height = height * img_height
                    rect = patches.Rectangle((x1, y1), box_width, box_height, linewidth=1, edgecolor='r', facecolor='none')
                    ax.add_patch(rect)


    ax.set_axis_off()
    plt.tight_layout()
    buf = io.BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    annotated_img = Image.open(buf).convert("RGB")
    plt.close(fig)

    return annotated_img

for img_path, label_path in image_label_pairs[:5]:
    annotated_img = draw_boxes_on_image(img_path, label_path)
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow(annotated_img)
    ax.set_title(os.path.basename(img_path))
    ax.axis('off')
    plt.show()

# %%
import yaml
import os

train_img_dir = './stinkbug_image_data/train/images'
print(f"Training images directory: {train_img_dir}")
val_img_dir = './stinkbug_image_data/valid/images'
test_img_dir = './stinkbug_image_data/test/images'

train_label_dir = './stinkbug_image_data/train/labels'
val_label_dir = './stinkbug_image_data/valid/labels'
test_label_dir = './stinkbug_image_data/test/labels'

class_names = ['stinkbug']

data_config = {
    'train': train_img_dir,
    'val': val_img_dir,
    'test': test_img_dir,
    'nc': len(class_names),
    'names': class_names,
    'train_labels': train_label_dir,
    'val_labels': val_label_dir,
    'test_labels': test_label_dir
}

yaml_file_path = os.path.join(os.getcwd(), 'stinkbug_data.yaml')

with open(yaml_file_path, 'w') as f:
    yaml.dump(data_config, f, default_flow_style=None)
# Out:
# Training images directory: ./stinkbug_image_data/train/images

# %%
import pandas as pd

label_files = [f for f in os.listdir(label_data)[:5] if f.endswith('.txt')]

data = []
for label_file in label_files:
    label_path = os.path.join(label_data, label_file)
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            data.append(([label_file] + parts))

if data:
    df = pd.DataFrame(data, columns=['filename', 'class_id', 'x_center', 'y_center', 'width', 'height'])
    display(df.head(10))
    display(df.tail(10))
# Out:
#                                             filename class_id    x_center  \
# 0  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0   0.3609375
# 1  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0  0.51640625
# 2  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0    0.678125
# 3  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0  0.33671875
# 4  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0    0.515625
# 5  DSC_0015_jpg.rf.374544fd6743d638c4763e8214f7d1...        0  0.66015625
# 6  DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba...        0      0.6375
# 7  DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba...        0  0.50234375
# 8  DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba...        0  0.34921875
# 9  DSC_0015_jpg.rf.3845576b2bfd2605b6e7d5abf1feba...        0   0.6140625
#
#      y_center      width     height
# 0  0.50859375  0.0765625   0.121875
# 1   0.5890625    0.09375    0.10625
# 2  0.61171875  0.0796875     0.1125
# 3     0.28125   0.078125   0.096875
# 4  0.30078125  0.0796875   0.109375
# 5    0.359375    0.06875   0.128125
# 6   0.4796875  0.0734375  0.1203125
# 7    0.590625   0.090625   0.103125
# 8    0.646875  0.0765625   0.109375
# 9  0.25234375      0.075  0.0953125
#                                              filename class_id    x_center  \
# 20  DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938c...        0  0.66328125
# 21  DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938c...        0  0.36484375
# 22  DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938c...        0  0.53984375
# 23  DSC_0015_jpg.rf.9b49bc2f3982c5b693ae93a042938c...        0  0.67578125
# 24  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0   0.6390625
# 25  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.49140625
# 26  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.33203125
# 27  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.64296875
# 28  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0   0.4671875
# 29  DSC_0015_jpg.rf.9fcd801667a2703ca21056d4fb66c2...        0  0.32890625
#
#       y_center       width      height
# 20   0.3671875   0.0671875   0.1046875
# 21  0.73671875   0.0671875  0.08984375
# 22  0.69609375  0.06796875  0.10234375
# 23   0.6203125  0.05390625  0.12265625
# 24  0.50390625   0.0671875   0.1171875
# 25    0.409375   0.0859375   0.0984375
# 26  0.37265625   0.0703125     0.10625
# 27  0.73203125   0.0703125   0.0921875
# 28  0.69765625    0.071875   0.1046875
# 29   0.6265625   0.0578125       0.125

# %%
output_folder = "./stinkbug_image_data/train/training_results"
output_folder
# Out:
# './stinkbug_image_data/train/training_results'

# %%
# !python --version
# Out:
# Python 3.12.8

# %%
# !pip install torch==2.7.1
# Out:
# Requirement already satisfied: torch==2.7.1 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (2.7.1+cu128)
# Requirement already satisfied: filelock in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (2025.7.0)
# Requirement already satisfied: setuptools in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from torch==2.7.1) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from sympy>=1.13.3->torch==2.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sauravupadhyaya\desktop\stinkbug-project-desktop\.venv\lib\site-packages (from jinja2->torch==2.7.1) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch

print(f"PyTorch version: {torch.__version__}") 
cuda_available = torch.cuda.is_available() 
print(f"CUDA available: {cuda_available}") 
 
if cuda_available: 
    device = torch.device("cuda") 
    print(f"Using device: {device}") 
    print(f"GPU name: {torch.cuda.get_device_name(0)}") 
    x = torch.randn(10, 10).to(device) 
    print(f"Tensor on GPU: {x.device}") 
else: 
    device = torch.device("cpu") 
    print(f"Using device: {device}")
# Out:
# PyTorch version: 2.7.1+cu128
# CUDA available: True
# Using device: cuda
# GPU name: NVIDIA RTX 4000 Ada Generation
# Tensor on GPU: cuda:0

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')

results = model.train(data=yaml_file_path, epochs=100, imgsz=640, batch=32, patience= 10, workers = 2,project=output_folder)
# Out:
# New https://pypi.org/project/ultralytics/8.3.180 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train12, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=./stinkbug_image_data/train/training_results, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=stinkbug_image_data\train\training_results\train12, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 169 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 108.632.5 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.00.0 ms, read: 88.736.5 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to stinkbug_image_data\train\training_results\train12\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to stinkbug_image_data\train\training_results\train12
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100        13G        1.7      3.124      1.358        264        640: 100%|██████████| 13/13 [00:07<00:00,  1.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.03it/s]
#                    all         11         65      0.044          1     0.0456     0.0306
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      12.7G      1.368     0.9888      1.241        164        640: 100%|██████████| 13/13 [00:06<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.48it/s]
#                    all         11         65      0.881      0.754      0.778      0.268
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      12.7G      1.296      0.764      1.204        210        640: 100%|██████████| 13/13 [00:06<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.21it/s]
#                    all         11         65     0.0037      0.185    0.00217   0.000538
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      12.7G      1.265     0.7026      1.225        338        640: 100%|██████████| 13/13 [00:06<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.57it/s]
#                    all         11         65     0.0238        0.2     0.0126    0.00339
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      12.7G      1.227     0.6742      1.188        216        640: 100%|██████████| 13/13 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.95it/s]
#                    all         11         65      0.587      0.215      0.288      0.134
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      12.8G      1.232      0.665      1.213        205        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.19it/s]
#                    all         11         65   0.000606     0.0308   0.000314   9.36e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      12.7G      1.188     0.6488      1.176        232        640: 100%|██████████| 13/13 [00:06<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.61it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      12.8G      1.228     0.6636      1.189        255        640: 100%|██████████| 13/13 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.87it/s]
#                    all         11         65     0.0378      0.492     0.0266     0.0117
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      12.8G      1.226     0.6626      1.207        208        640: 100%|██████████| 13/13 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.62it/s]
#                    all         11         65      0.897      0.939      0.937      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      12.8G      1.212     0.6541      1.233        161        640: 100%|██████████| 13/13 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.64it/s]
#                    all         11         65      0.639      0.631      0.626       0.29
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      12.7G      1.191     0.6328      1.188        294        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.44it/s]
#                    all         11         65      0.899      0.892      0.915      0.491
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      12.6G      1.165     0.6313      1.194        201        640: 100%|██████████| 13/13 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.38it/s]
#                    all         11         65       0.71      0.462      0.449      0.258
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      12.7G      1.169     0.6209      1.214        165        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.43it/s]
#                    all         11         65      0.437      0.462      0.364      0.117
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      12.7G      1.168     0.6148       1.21        127        640: 100%|██████████| 13/13 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.37it/s]
#                    all         11         65      0.463      0.384      0.354     0.0717
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      12.7G      1.125     0.6058      1.177        213        640: 100%|██████████| 13/13 [00:06<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.45it/s]
#                    all         11         65      0.749      0.754       0.76      0.181
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      12.8G      1.137     0.5984      1.181        259        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.19it/s]
#                    all         11         65       0.66      0.738      0.704      0.282
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      12.7G      1.134     0.5713      1.173        261        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.88it/s]
#                    all         11         65      0.785      0.897      0.901      0.479
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      12.8G      1.097     0.5506      1.138        227        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.11it/s]
#                    all         11         65    0.00351     0.0154   0.000433   4.33e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      12.7G      1.022     0.5335       1.12        262        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.66it/s]
#                    all         11         65     0.0177     0.0615     0.0102    0.00171
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 9, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 19 epochs completed in 0.041 hours.
# Optimizer stripped from stinkbug_image_data\train\training_results\train12\weights\last.pt, 52.0MB
# Optimizer stripped from stinkbug_image_data\train\training_results\train12\weights\best.pt, 52.0MB
#
# Validating stinkbug_image_data\train\training_results\train12\weights\best.pt...
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.34it/s]
#                    all         11         65      0.898      0.938      0.937      0.504
# Speed: 0.1ms preprocess, 3.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to stinkbug_image_data\train\training_results\train12

# %%
#stinkbug_image_data\train\training_results\train10
import cv2

image_folder = "./stinkbug_image_data/test/images/"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')

model = YOLO('./stinkbug_image_data/train/training_results/train12/weights/best.pt')
results = model.predict(source=image_paths, conf=0.7)

for i, result in enumerate(results):
    # Get image with boxes
    img_with_boxes = result.plot()
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (150, 200),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            5,        # Font scale
            (0, 0, 250), # Color (red)
            10)  
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
    plt.show()
# Out:
# 0: 640x640 6 stinkbugs, 16.9ms
# 1: 640x640 4 stinkbugs, 16.9ms
# 2: 640x640 10 stinkbugs, 16.9ms
# 3: 640x640 11 stinkbugs, 16.9ms
# 4: 640x640 5 stinkbugs, 16.9ms
# 5: 640x640 6 stinkbugs, 16.9ms
# Speed: 3.5ms preprocess, 16.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 6 Stinkbug detected
# DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 4 Stinkbug detected
# DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 10 Stinkbug detected
# DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 11 Stinkbug detected
# DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 5 Stinkbug detected
# DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 6 Stinkbug detected

# %%
from ultralytics import YOLO
import shutil
import os


# Define model variants you want to train
model_variants = ['yolov8m.pt', 'yolov8l.pt', 'yolov8x.pt', 'yolov9e.pt', 'yolov10x.pt', 'yolo11l-cls.pt', 'yolo11x-cls.pt'] 


# Where to save your final organized best.pt files
final_save_dir = 'saved_models'
os.makedirs(final_save_dir, exist_ok=True)

for model_file in model_variants:
    # Derive a model name tag (e.g., yolov8n)
    model_name = model_file.replace('.pt', '')

    # Load model
    model = YOLO(model_file)

    # Train the model
    results = model.train(
        data=yaml_file_path,
        epochs=100,
        imgsz=640,
        batch=32,
        patience=10,
        workers=2,
        project='model_outputs',   # Base folder for all runs
        name=model_name            # Unique folder per model
    )

    # Define paths
    best_model_src = f"model_outputs/{model_name}/weights/best.pt"
    best_model_dest = os.path.join(final_save_dir, f"{model_name}_best.pt")

    # Save best.pt to your organized directory
    shutil.copy(best_model_src, best_model_dest)
    print(f"{model_name}: best.pt saved to {best_model_dest}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt': 100%|██████████| 49.7M/49.7M [00:02<00:00, 17.9MB/s]
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8m, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=model_outputs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=model_outputs\yolov8m, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 169 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100%|██████████| 5.35M/5.35M [00:00<00:00, 10.8MB/s]
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 1.80.7 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.10.0 ms, read: 1.60.6 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to model_outputs\yolov8m\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to model_outputs\yolov8m
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      12.4G        1.7      3.124      1.358        264        640: 100%|██████████| 13/13 [00:08<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  7.22it/s]
#                    all         11         65      0.044          1     0.0456     0.0306
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      12.7G      1.368     0.9888      1.241        164        640: 100%|██████████| 13/13 [00:06<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.96it/s]
#                    all         11         65      0.881      0.754      0.778      0.268
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      12.7G      1.296      0.764      1.204        210        640: 100%|██████████| 13/13 [00:06<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.58it/s]
#                    all         11         65     0.0037      0.185    0.00217   0.000538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      12.6G      1.265     0.7026      1.225        338        640: 100%|██████████| 13/13 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.98it/s]
#                    all         11         65     0.0238        0.2     0.0126    0.00339
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      12.7G      1.227     0.6742      1.188        216        640: 100%|██████████| 13/13 [00:06<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.70it/s]
#                    all         11         65      0.587      0.215      0.288      0.134
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      12.8G      1.232      0.665      1.213        205        640: 100%|██████████| 13/13 [00:06<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.12it/s]
#                    all         11         65   0.000606     0.0308   0.000314   9.36e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      12.7G      1.188     0.6488      1.176        232        640: 100%|██████████| 13/13 [00:06<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.46it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      12.8G      1.228     0.6636      1.189        255        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.76it/s]
#                    all         11         65     0.0378      0.492     0.0266     0.0117
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      12.7G      1.226     0.6626      1.207        208        640: 100%|██████████| 13/13 [00:06<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.19it/s]
#                    all         11         65      0.897      0.939      0.937      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      12.8G      1.212     0.6541      1.233        161        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
#                    all         11         65      0.639      0.631      0.626       0.29
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      12.7G      1.191     0.6328      1.188        294        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.88it/s]
#                    all         11         65      0.899      0.892      0.915      0.491
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      12.5G      1.165     0.6313      1.194        201        640: 100%|██████████| 13/13 [00:06<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.31it/s]
#                    all         11         65       0.71      0.462      0.449      0.258
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      12.6G      1.169     0.6209      1.214        165        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.90it/s]
#                    all         11         65      0.437      0.462      0.364      0.117
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      12.7G      1.168     0.6148       1.21        127        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.33it/s]
#                    all         11         65      0.463      0.384      0.354     0.0717
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      12.6G      1.125     0.6058      1.177        213        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.07it/s]
#                    all         11         65      0.749      0.754       0.76      0.181
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      12.7G      1.137     0.5984      1.181        259        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.67it/s]
#                    all         11         65       0.66      0.738      0.704      0.282
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      12.7G      1.134     0.5713      1.173        261        640: 100%|██████████| 13/13 [00:06<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.17it/s]
#                    all         11         65      0.785      0.897      0.901      0.479
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      12.7G      1.097     0.5506      1.138        227        640: 100%|██████████| 13/13 [00:06<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.42it/s]
#                    all         11         65    0.00351     0.0154   0.000433   4.33e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      12.7G      1.022     0.5335       1.12        262        640: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
#                    all         11         65     0.0177     0.0615     0.0102    0.00171
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 9, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 19 epochs completed in 0.041 hours.
# Optimizer stripped from model_outputs\yolov8m\weights\last.pt, 52.0MB
# Optimizer stripped from model_outputs\yolov8m\weights\best.pt, 52.0MB
#
# Validating model_outputs\yolov8m\weights\best.pt...
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.46it/s]
#                    all         11         65      0.898      0.938      0.937      0.504
# Speed: 0.1ms preprocess, 3.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to model_outputs\yolov8m
# yolov8m: best.pt saved to saved_models\yolov8m_best.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt': 100%|██████████| 83.7M/83.7M [00:04<00:00, 18.2MB/s]
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8l, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=model_outputs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=model_outputs\yolov8l, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5583571  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# Model summary: 209 layers, 43,630,611 parameters, 43,630,595 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 124.234.7 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.00.0 ms, read: 77.626.3 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to model_outputs\yolov8l\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to model_outputs\yolov8l
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      18.9G      1.689      5.857      1.437        264        640: 100%|██████████| 13/13 [01:30<00:00,  6.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                    all         11         65       0.54      0.954      0.629      0.383
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      18.7G      1.486      1.569      1.397        164        640: 100%|██████████| 13/13 [55:09<00:00, 254.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      18.9G      1.378     0.8666      1.364        210        640: 100%|██████████| 13/13 [01:34<00:00,  7.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.96s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      18.7G      1.393     0.8091      1.375        338        640: 100%|██████████| 13/13 [01:41<00:00,  7.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      18.9G      1.411     0.7954      1.344        216        640: 100%|██████████| 13/13 [01:49<00:00,  8.46s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
#                    all         11         65   0.000303     0.0154   0.000154   1.54e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      19.1G      1.356     0.7098      1.347        205        640: 100%|██████████| 13/13 [01:10<00:00,  5.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  6.29it/s]
#                    all         11         65    0.00728      0.354    0.00484    0.00186
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      18.9G      1.342      0.703      1.321        232        640: 100%|██████████| 13/13 [01:11<00:00,  5.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  6.27it/s]
#                    all         11         65    0.00758      0.385    0.00703    0.00169
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      19.1G      1.395     0.7817      1.345        255        640: 100%|██████████| 13/13 [00:57<00:00,  4.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  7.54it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      18.9G      1.375     0.7509      1.326        208        640: 100%|██████████| 13/13 [00:50<00:00,  3.89s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  6.69it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      19.1G      1.383     0.7662      1.381        161        640: 100%|██████████| 13/13 [00:51<00:00,  3.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  7.75it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      18.9G      1.324     0.6905      1.283        294        640: 100%|██████████| 13/13 [00:49<00:00,  3.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  8.69it/s]
#                    all         11         65          0          0          0          0
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 11 epochs completed in 1.134 hours.
# Optimizer stripped from model_outputs\yolov8l\weights\last.pt, 87.6MB
# Optimizer stripped from model_outputs\yolov8l\weights\best.pt, 87.6MB
#
# Validating model_outputs\yolov8l\weights\best.pt...
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 112 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.14it/s]
#                    all         11         65      0.539      0.954      0.636      0.385
# Speed: 0.2ms preprocess, 13.9ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to model_outputs\yolov8l
# yolov8l: best.pt saved to saved_models\yolov8l_best.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x.pt to 'yolov8x.pt': 100%|██████████| 131M/131M [00:06<00:00, 19.9MB/s]
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8x, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=model_outputs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=model_outputs\yolov8x, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8718931  ultralytics.nn.modules.head.Detect           [1, [320, 640, 640]]
# Model summary: 209 layers, 68,153,571 parameters, 68,153,555 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 47.113.6 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.10.0 ms, read: 56.422.0 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to model_outputs\yolov8x\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to model_outputs\yolov8x
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      23.2G      1.747      6.519      1.324        264        640: 100%|██████████| 13/13 [03:37<00:00, 16.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.69s/it]
#                    all         11         65      0.026      0.938     0.0299     0.0113
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      23.5G      1.524      1.661      1.343        164        640: 100%|██████████| 13/13 [03:34<00:00, 16.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      23.4G      1.392      1.018      1.289        210        640: 100%|██████████| 13/13 [04:39<00:00, 21.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.02s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      23.5G      1.362     0.8588      1.311        338        640: 100%|██████████| 13/13 [06:10<00:00, 28.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.55s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      23.3G      1.354     0.8658      1.296        216        640: 100%|██████████| 13/13 [03:20<00:00, 15.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      23.4G      1.335     0.8383      1.312        205        640: 100%|██████████| 13/13 [04:31<00:00, 20.90s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      23.4G      1.378     0.9503       1.31        232        640: 100%|██████████| 13/13 [03:27<00:00, 15.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      23.6G      1.368     0.8501      1.301        255        640: 100%|██████████| 13/13 [03:00<00:00, 13.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.68s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      23.4G      1.343     0.8057      1.275        208        640: 100%|██████████| 13/13 [03:33<00:00, 16.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.61s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      23.4G      1.338     0.7325      1.332        161        640: 100%|██████████| 13/13 [02:52<00:00, 13.26s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      23.3G      1.321     0.6862       1.28        294        640: 100%|██████████| 13/13 [04:43<00:00, 21.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
#                    all         11         65      0.146     0.0308     0.0105    0.00146
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 11 epochs completed in 0.745 hours.
# Optimizer stripped from model_outputs\yolov8x\weights\last.pt, 136.7MB
# Optimizer stripped from model_outputs\yolov8x\weights\best.pt, 136.7MB
#
# Validating model_outputs\yolov8x\weights\best.pt...
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 112 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.37s/it]
#                    all         11         65      0.026      0.938     0.0312     0.0115
# Speed: 0.1ms preprocess, 202.4ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to model_outputs\yolov8x
# yolov8x: best.pt saved to saved_models\yolov8x_best.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov9e.pt to 'yolov9e.pt': 100%|██████████| 112M/112M [00:05<00:00, 19.8MB/s]
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov9e.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov9e, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=model_outputs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=model_outputs\yolov9e, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1         0  torch.nn.modules.linear.Identity             []
#   1                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   2                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   3                  -1  1    252160  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 2]
#   4                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#   5                  -1  1   1004032  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 2]
#   6                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   7                  -1  1   4006912  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 1024, 512, 256, 2]
#   8                  -1  1   2623488  ultralytics.nn.modules.block.ADown           [1024, 1024]
#   9                  -1  1   4269056  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 1024, 512, 256, 2]
#  10                   1  1      4160  ultralytics.nn.modules.block.CBLinear        [64, [64]]
#  11                   3  1     49344  ultralytics.nn.modules.block.CBLinear        [256, [64, 128]]
#  12                   5  1    229824  ultralytics.nn.modules.block.CBLinear        [512, [64, 128, 256]]
#  13                   7  1    984000  ultralytics.nn.modules.block.CBLinear        [1024, [64, 128, 256, 512]]
#  14                   9  1   2033600  ultralytics.nn.modules.block.CBLinear        [1024, [64, 128, 256, 512, 1024]]
#  15                   0  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#  16[10, 11, 12, 13, 14, -1]  1         0  ultralytics.nn.modules.block.CBFuse          [[0, 0, 0, 0, 0]]
#  17                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#  18[11, 12, 13, 14, -1]  1         0  ultralytics.nn.modules.block.CBFuse          [[1, 1, 1, 1]]
#  19                  -1  1    252160  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 2]
#  20                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  21    [12, 13, 14, -1]  1         0  ultralytics.nn.modules.block.CBFuse          [[2, 2, 2]]
#  22                  -1  1   1004032  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 2]
#  23                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  24        [13, 14, -1]  1         0  ultralytics.nn.modules.block.CBFuse          [[3, 3]]
#  25                  -1  1   4006912  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 1024, 512, 256, 2]
#  26                  -1  1   2623488  ultralytics.nn.modules.block.ADown           [1024, 1024]
#  27            [14, -1]  1         0  ultralytics.nn.modules.block.CBFuse          [[4]]
#  28                  -1  1   4269056  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 1024, 512, 256, 2]
#  29                  -1  1    787968  ultralytics.nn.modules.block.SPPELAN         [1024, 512, 256]
#  30                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  31            [-1, 25]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  1   4005888  ultralytics.nn.modules.block.RepNCSPELAN4    [1536, 512, 512, 256, 2]
#  33                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  34            [-1, 22]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  35                  -1  1   1069056  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 256, 256, 128, 2]
#  36                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  37            [-1, 32]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  38                  -1  1   3612672  ultralytics.nn.modules.block.RepNCSPELAN4    [768, 512, 512, 256, 2]
#  39                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  40            [-1, 29]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  41                  -1  1  12860416  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 1024, 512, 2]
#  42        [35, 38, 41]  1   5583571  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLOv9e summary: 721 layers, 58,145,683 parameters, 58,145,667 gradients, 192.7 GFLOPs
#
# Transferred 1805/1811 items from pretrained weights
# Freezing layer 'model.42.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 30.85.8 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.10.1 ms, read: 27.310.0 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to model_outputs\yolov9e\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 298 weight(decay=0.0), 310 weight(decay=0.0005), 309 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to model_outputs\yolov9e
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      35.9G      1.944      4.424      1.549        264        640: 100%|██████████| 13/13 [23:06<00:00, 106.67s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#                    all         11         65     0.0229      0.954     0.0246     0.0102
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      36.6G      1.565      2.048       1.49        164        640: 100%|██████████| 13/13 [09:59<00:00, 46.10s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.66s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
from ultralytics import YOLO
import shutil
import os


# Define model variants you want to train
model_variants = ['yolov8s.pt'] 


# Where to save your final organized best.pt files
final_save_dir = 'saved_models'
os.makedirs(final_save_dir, exist_ok=True)

for model_file in model_variants:
    # Derive a model name tag (e.g., yolov8n)
    model_name = model_file.replace('.pt', '')

    # Load model
    model = YOLO(model_file)

    # Train the model
    results = model.train(
        data=yaml_file_path,
        epochs=100,
        imgsz=640,
        batch=32,
        patience=10,
        workers=2,
        project='model_outputs',  
        name=model_name           
    )

    # Define paths
    best_model_src = f"model_outputs/{model_name}/weights/best.pt"
    best_model_dest = os.path.join(final_save_dir, f"{model_name}_best.pt")

    # Save best.pt to your organized directory
    shutil.copy(best_model_src, best_model_dest)
    print(f"{model_name}: best.pt saved to {best_model_dest}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100%|██████████| 21.5M/21.5M [00:01<00:00, 15.5MB/s]
# New https://pypi.org/project/ultralytics/8.3.180 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=model_outputs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=model_outputs\yolov8s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 1.91.2 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.10.0 ms, read: 1.60.5 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to model_outputs\yolov8s\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to model_outputs\yolov8s
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      6.91G      1.777      2.434      1.327        264        640: 100%|██████████| 13/13 [00:06<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  8.05it/s]
#                    all         11         65       0.77       0.98      0.841      0.606
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      6.94G      1.359     0.9912      1.098        164        640: 100%|██████████| 13/13 [00:03<00:00,  3.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.58it/s]
#                    all         11         65      0.567      0.938      0.625      0.184
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      6.98G      1.286     0.8314      1.065        210        640: 100%|██████████| 13/13 [00:03<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.09it/s]
#                    all         11         65      0.309      0.923      0.314      0.175
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      6.98G      1.263     0.7486       1.08        338        640: 100%|██████████| 13/13 [00:03<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.69it/s]
#                    all         11         65      0.906      0.938      0.932      0.548
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.98G      1.213     0.7144      1.044        216        640: 100%|██████████| 13/13 [00:03<00:00,  3.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.86it/s]
#                    all         11         65      0.698      0.708      0.769      0.507
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      6.98G      1.206     0.7112      1.058        205        640: 100%|██████████| 13/13 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
#                    all         11         65      0.927      0.984      0.949      0.435
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.01G      1.226     0.6777      1.052        232        640: 100%|██████████| 13/13 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.95it/s]
#                    all         11         65       0.91      0.938       0.96      0.457
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.01G      1.247     0.7037      1.067        255        640: 100%|██████████| 13/13 [00:03<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
#                    all         11         65      0.815      0.754      0.843      0.385
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.01G      1.179     0.6827      1.043        208        640: 100%|██████████| 13/13 [00:03<00:00,  3.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.29it/s]
#                    all         11         65      0.115      0.815      0.111     0.0669
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.04G      1.155     0.6641      1.035        161        640: 100%|██████████| 13/13 [00:03<00:00,  3.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 19.04it/s]
#                    all         11         65      0.635      0.938      0.643      0.311
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.05G      1.129     0.6378      1.019        294        640: 100%|██████████| 13/13 [00:03<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
#                    all         11         65      0.879      0.969      0.949      0.694
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      7.05G      1.128     0.6569      1.028        201        640: 100%|██████████| 13/13 [00:03<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 15.75it/s]
#                    all         11         65      0.969      0.975      0.974      0.536
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.05G      1.153     0.6311      1.043        165        640: 100%|██████████| 13/13 [00:03<00:00,  3.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.35it/s]
#                    all         11         65      0.893      0.908      0.935      0.695
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      7.08G      1.126     0.6621      1.036        127        640: 100%|██████████| 13/13 [00:03<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.43it/s]
#                    all         11         65      0.928      0.997      0.972      0.467
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      7.12G      1.101     0.6229      1.022        213        640: 100%|██████████| 13/13 [00:03<00:00,  3.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.35it/s]
#                    all         11         65      0.886      0.955      0.974      0.565
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      7.12G       1.07     0.6029      1.006        259        640: 100%|██████████| 13/13 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.01it/s]
#                    all         11         65      0.887      0.969      0.962      0.685
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      7.12G      1.172     0.6185      1.039        261        640: 100%|██████████| 13/13 [00:03<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
#                    all         11         65      0.914          1      0.981      0.703
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      7.16G      1.067     0.5961      1.004        227        640: 100%|██████████| 13/13 [00:03<00:00,  3.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.10it/s]
#                    all         11         65      0.908          1       0.97      0.718
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      7.16G      1.028      0.577     0.9922        262        640: 100%|██████████| 13/13 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.39it/s]
#                    all         11         65      0.905      0.954       0.98      0.749
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      7.16G      1.084     0.5821      1.012        220        640: 100%|██████████| 13/13 [00:03<00:00,  3.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 15.76it/s]
#                    all         11         65      0.649      0.653      0.709      0.374
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      7.16G      1.039     0.5668      1.004        187        640: 100%|██████████| 13/13 [00:03<00:00,  3.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.22it/s]
#                    all         11         65      0.896      0.677       0.76      0.372
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      7.16G      1.009      0.556     0.9853        285        640: 100%|██████████| 13/13 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.54it/s]
#                    all         11         65      0.924      0.985      0.986      0.749
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      7.16G     0.9882     0.5516     0.9842        237        640: 100%|██████████| 13/13 [00:03<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.25it/s]
#                    all         11         65        0.9      0.831      0.927      0.686
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      7.16G     0.9964     0.5568     0.9826        222        640: 100%|██████████| 13/13 [00:03<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.70it/s]
#                    all         11         65      0.954      0.959       0.99      0.753
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      7.16G      1.014     0.5362     0.9847        236        640: 100%|██████████| 13/13 [00:03<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.76it/s]
#                    all         11         65      0.956          1      0.983      0.783
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      7.16G      0.981     0.5333     0.9831        213        640: 100%|██████████| 13/13 [00:03<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.78it/s]
#                    all         11         65      0.964      0.969      0.978      0.776
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      7.16G     0.9797      0.536     0.9689        241        640: 100%|██████████| 13/13 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.35it/s]
#                    all         11         65      0.951      0.985      0.975      0.741
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      7.16G     0.9401     0.5157     0.9636        228        640: 100%|██████████| 13/13 [00:03<00:00,  3.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.69it/s]
#                    all         11         65      0.934      0.877      0.957      0.671
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      7.16G     0.9729     0.5315     0.9826        223        640: 100%|██████████| 13/13 [00:03<00:00,  3.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.39it/s]
#                    all         11         65      0.741      0.769      0.848      0.565
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      7.16G     0.9144     0.4966     0.9562        228        640: 100%|██████████| 13/13 [00:03<00:00,  3.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.26it/s]
#                    all         11         65      0.969          1      0.971      0.759
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      7.16G     0.9144     0.5115     0.9553        181        640: 100%|██████████| 13/13 [00:03<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.43it/s]
#                    all         11         65      0.967          1      0.984      0.759
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      7.16G     0.9256     0.5004     0.9571        255        640: 100%|██████████| 13/13 [00:03<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.52it/s]
#                    all         11         65      0.935      0.985      0.985       0.76
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      7.16G     0.9191     0.4905     0.9581        293        640: 100%|██████████| 13/13 [00:03<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.54it/s]
#                    all         11         65      0.966          1      0.986      0.794
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      7.16G     0.9325     0.5043     0.9652        215        640: 100%|██████████| 13/13 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.87it/s]
#                    all         11         65      0.954      0.954      0.985      0.653
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      7.16G       0.91     0.4913     0.9539        230        640: 100%|██████████| 13/13 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.14it/s]
#                    all         11         65      0.901      0.982      0.983      0.718
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      7.19G     0.8884     0.4864     0.9554        192        640: 100%|██████████| 13/13 [00:03<00:00,  3.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.70it/s]
#                    all         11         65      0.858      0.877      0.942      0.655
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      7.19G     0.9274     0.5005     0.9609        241        640: 100%|██████████| 13/13 [00:03<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.52it/s]
#                    all         11         65      0.941      0.982      0.979       0.75
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      7.19G     0.8762     0.4906     0.9389        256        640: 100%|██████████| 13/13 [00:03<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.69it/s]
#                    all         11         65       0.94      0.964      0.978      0.784
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      7.23G     0.8694     0.4797     0.9394        224        640: 100%|██████████| 13/13 [00:03<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 15.07it/s]
#                    all         11         65       0.97          1      0.981       0.81
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      7.23G     0.8809      0.477     0.9425        199        640: 100%|██████████| 13/13 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.34it/s]
#                    all         11         65       0.97      0.998      0.981      0.796
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      7.23G     0.8447      0.464     0.9328        268        640: 100%|██████████| 13/13 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
#                    all         11         65       0.97      0.997      0.971      0.797
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      7.23G     0.8847     0.4812     0.9501        167        640: 100%|██████████| 13/13 [00:03<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.74it/s]
#                    all         11         65      0.962      0.985      0.971      0.785
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      7.23G     0.8604     0.4662     0.9405        199        640: 100%|██████████| 13/13 [00:03<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.86it/s]
#                    all         11         65      0.969      0.964      0.976      0.778
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      7.23G     0.8299     0.4535     0.9263        214        640: 100%|██████████| 13/13 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.91it/s]
#                    all         11         65       0.97      0.995      0.984      0.804
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      7.23G     0.8409     0.4625     0.9311        206        640: 100%|██████████| 13/13 [00:03<00:00,  3.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.15it/s]
#                    all         11         65      0.967          1      0.987      0.785
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      7.23G     0.8383     0.4608     0.9329        262        640: 100%|██████████| 13/13 [00:03<00:00,  3.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 15.62it/s]
#                    all         11         65      0.967          1      0.985      0.742
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      7.23G      0.803     0.4425      0.919        240        640: 100%|██████████| 13/13 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
#                    all         11         65       0.95          1      0.987      0.755
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      7.23G     0.8039      0.434     0.9224        241        640: 100%|██████████| 13/13 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.60it/s]
#                    all         11         65      0.966          1      0.986      0.798
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      7.23G     0.8091      0.437     0.9178        196        640: 100%|██████████| 13/13 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.80it/s]
#                    all         11         65      0.947      0.969      0.973      0.766
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 39, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 49 epochs completed in 0.056 hours.
# Optimizer stripped from model_outputs\yolov8s\weights\last.pt, 22.5MB
# Optimizer stripped from model_outputs\yolov8s\weights\best.pt, 22.5MB
#
# Validating model_outputs\yolov8s\weights\best.pt...
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.60it/s]
#                    all         11         65       0.97          1      0.981      0.811
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to model_outputs\yolov8s
# yolov8s: best.pt saved to saved_models\yolov8s_best.pt

# %%
from ultralytics import YOLO
import shutil
import os


# Define model variants you want to train
model_variants = [ 'yolo11x.pt'] 


# Where to save your final organized best.pt files
final_save_dir = 'saved_models'
os.makedirs(final_save_dir, exist_ok=True)

for model_file in model_variants:
    # Derive a model name tag (e.g., yolov8n)
    model_name = model_file.replace('.pt', '')

    # Load model
    model = YOLO(model_file)

    # Train the model
    results = model.train(
        data=yaml_file_path,
        epochs=100,
        imgsz=640,
        batch=32,
        patience=10,
        workers=2,
        project='model_outputs',   # Base folder for all runs
        name=model_name            # Unique folder per model
    )

    # Define paths
    best_model_src = f"model_outputs/{model_name}/weights/best.pt"
    best_model_dest = os.path.join(final_save_dir, f"{model_name}_best.pt")

    # Save best.pt to your organized directory
    shutil.copy(best_model_src, best_model_dest)
    print(f"{model_name}: best.pt saved to {best_model_dest}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt to 'yolo11x.pt': 100%|██████████| 109M/109M [00:06<00:00, 17.9MB/s]
# New https://pypi.org/project/ultralytics/8.3.180 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11x.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11x, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=model_outputs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=model_outputs\yolo11x, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3146707  ultralytics.nn.modules.head.Detect           [1, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,874,931 parameters, 56,874,915 gradients, 195.4 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 112.033.0 MB/s, size: 17.5 KB)
# train: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\train\labels.cache... 410 images, 20 backgrounds, 0 corrupt: 100%|██████████| 410/410 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.00.0 ms, read: 91.537.2 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to model_outputs\yolo11x\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0005), 173 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to model_outputs\yolo11x
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      29.3G      1.802      4.164      1.483        264        640: 100%|██████████| 13/13 [05:06<00:00, 23.61s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
#                    all         11         65      0.117      0.262      0.134     0.0514
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      29.8G      1.501      1.465      1.423        164        640: 100%|██████████| 13/13 [03:20<00:00, 15.46s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      29.9G      1.481      1.025      1.431        210        640: 100%|██████████| 13/13 [06:07<00:00, 28.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      29.8G      1.476     0.8757      1.434        338        640: 100%|██████████| 13/13 [05:11<00:00, 23.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      29.9G       1.47     0.9388      1.391        216        640: 100%|██████████| 13/13 [04:41<00:00, 21.64s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.34s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      30.1G      1.465     0.9828      1.423        205        640: 100%|██████████| 13/13 [04:22<00:00, 20.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      29.9G      1.563     0.9425      1.482        232        640: 100%|██████████| 13/13 [04:55<00:00, 22.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.61s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      30.2G      1.479     0.9842      1.406        255        640: 100%|██████████| 13/13 [03:30<00:00, 16.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      29.9G      1.522     0.8595      1.422        208        640: 100%|██████████| 13/13 [03:57<00:00, 18.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.83s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      30.1G      1.495     0.7919      1.448        161        640: 100%|██████████| 13/13 [04:07<00:00, 19.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
#                    all         11         65          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      29.9G      1.409     0.7552      1.342        294        640: 100%|██████████| 13/13 [03:55<00:00, 18.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
#                    all         11         65          0          0          0          0
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 11 epochs completed in 0.837 hours.
# Optimizer stripped from model_outputs\yolo11x\weights\last.pt, 114.4MB
# Optimizer stripped from model_outputs\yolo11x\weights\best.pt, 114.4MB
#
# Validating model_outputs\yolo11x\weights\best.pt...
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# YOLO11x summary (fused): 190 layers, 56,828,179 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
#                    all         11         65      0.116      0.262      0.118     0.0465
# Speed: 0.1ms preprocess, 157.6ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to model_outputs\yolo11x
# yolo11x: best.pt saved to saved_models\yolo11x_best.pt

# %%
import os
import csv
from ultralytics import YOLO
import cv2

# Paths
model_dir = "saved_models"          # folder containing best.pt files
test_images_dir = "./stinkbug_image_data/test/images"     # folder with test images
output_root = "model_predictions"   # folder to save visualized outputs
metrics_csv = "object_counts.csv"   # where to save counts

os.makedirs(output_root, exist_ok=True)

# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Save visualization
            result_img = results[0].plot()  # returns numpy array with drawn boxes

            # Create output dir for this model
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            # Save image
            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f"🖼️ Saved: {save_path} | 🔢 Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n✅ All done! Object counts saved to: {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 31 stinkbugs, 1522.8ms
# Speed: 1.9ms preprocess, 1522.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 31 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 24 stinkbugs, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 24 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 8 stinkbugs, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 8 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 6 stinkbugs, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 300 stinkbugs, 555.5ms
# Speed: 1.6ms preprocess, 555.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 4 stinkbugs, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 4 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 11 stinkbugs, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 11 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 6 stinkbugs, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 3 stinkbugs, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 3 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 300 stinkbugs, 15.8ms
# Speed: 1.7ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 72 stinkbugs, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 72 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 49 stinkbugs, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 49 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 14 stinkbugs, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 14 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 10 stinkbugs, 4.9ms
# Speed: 2.7ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 276 stinkbugs, 24.9ms
# Speed: 2.4ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 276 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 92 stinkbugs, 29.1ms
# Speed: 1.9ms preprocess, 29.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 92 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 48 stinkbugs, 20.1ms
# Speed: 1.6ms preprocess, 20.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 48 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 15 stinkbugs, 13.6ms
# Speed: 1.6ms preprocess, 13.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 15 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 10 stinkbugs, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 300 stinkbugs, 29.9ms
# Speed: 1.6ms preprocess, 29.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 48 stinkbugs, 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 48 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 43 stinkbugs, 20.5ms
# Speed: 1.5ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 43 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 10 stinkbugs, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 6 stinkbugs, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 300 stinkbugs, 28.4ms
# Speed: 1.8ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 66 stinkbugs, 30.6ms
# Speed: 1.8ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 66 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 39 stinkbugs, 20.8ms
# Speed: 2.3ms preprocess, 20.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 39 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 9 stinkbugs, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 9 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 6 stinkbugs, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 300 stinkbugs, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 300 objects
#
# ✅ All done! Object counts saved to: object_counts.csv

# %%
import os
import csv
from ultralytics import YOLO
import cv2


# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Visualized result
            result_img = results[0].plot()  # image with boxes

            # Draw model name and object count on top-left corner
            cv2.putText(
                result_img,
                f"{model_name}: {num_objects} objects",
                org=(10, 40),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=1.0,
                color=(0, 255, 0),
                thickness=2,
                lineType=cv2.LINE_AA
            )

            # Save the image
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f"🖼️ Saved: {save_path} | 🔢 Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n✅ Done! Visuals saved in {output_root}/ and counts in {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 31 stinkbugs, 78.1ms
# Speed: 2.5ms preprocess, 78.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 31 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 24 stinkbugs, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 24 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 8 stinkbugs, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 8 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 6 stinkbugs, 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 640x640 300 stinkbugs, 16.1ms
# Speed: 1.5ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 4 stinkbugs, 17.7ms
# Speed: 1.7ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 4 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 11 stinkbugs, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 11 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 6 stinkbugs, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 3 stinkbugs, 4.2ms
# Speed: 1.8ms preprocess, 4.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 3 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 640x640 300 stinkbugs, 25.0ms
# Speed: 1.6ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 72 stinkbugs, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 72 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 49 stinkbugs, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 49 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 14 stinkbugs, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 14 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 10 stinkbugs, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 640x640 276 stinkbugs, 27.3ms
# Speed: 1.7ms preprocess, 27.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg | 🔢 Count: 276 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 92 stinkbugs, 30.7ms
# Speed: 5.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 92 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 48 stinkbugs, 20.3ms
# Speed: 1.6ms preprocess, 20.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 48 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 15 stinkbugs, 14.4ms
# Speed: 1.6ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 15 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 10 stinkbugs, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 640x640 300 stinkbugs, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 48 stinkbugs, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 48 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 43 stinkbugs, 18.9ms
# Speed: 1.6ms preprocess, 18.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 43 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 10 stinkbugs, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 6 stinkbugs, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 640x640 300 stinkbugs, 26.9ms
# Speed: 1.7ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg | 🔢 Count: 300 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 66 stinkbugs, 28.6ms
# Speed: 1.5ms preprocess, 28.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolo11x\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 66 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 39 stinkbugs, 19.5ms
# Speed: 1.5ms preprocess, 19.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8l\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 39 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 9 stinkbugs, 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8m\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 9 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 6 stinkbugs, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8s\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 6 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 300 stinkbugs, 28.7ms
# Speed: 2.0ms preprocess, 28.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 🖼️ Saved: model_predictions\yolov8x\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg | 🔢 Count: 300 objects
#
# ✅ Done! Visuals saved in model_predictions/ and counts in object_counts.csv

# %%
def get_counts_from_labels(labels_dir, csv_output_path):
    import os
    import csv

    counts = {}
    for label_file in os.listdir(labels_dir):
        if label_file.endswith(".txt"):
            with open(os.path.join(labels_dir, label_file)) as f:
                counts[label_file.replace('.txt', '.jpg')] = len(f.readlines())
    
    with open(csv_output_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['image', 'true_count'])
        for img, count in counts.items():
            writer.writerow([img, count])
    
    print(f"Saved ground truth counts to {csv_output_path}")

# Usage:
get_counts_from_labels("./stinkbug_image_data/train/labels", "train_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data/valid/labels", "val_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data/test/labels", "test_ground_truth_counts.csv")
# Out:
# Saved ground truth counts to train_ground_truth_counts.csv
# Saved ground truth counts to val_ground_truth_counts.csv
# Saved ground truth counts to test_ground_truth_counts.csv

# %%
import pandas as pd

# Load ground truth counts CSV
gt_counts = pd.read_csv("test_ground_truth_counts.csv")  # columns: image, true_count

# Load predicted counts CSV
pred_counts = pd.read_csv("object_counts.csv")  # columns: image, model_1, model_2, ...
df = pd.merge(gt_counts, pred_counts, on="image")

# %%
df
# Out:
#                                                image  true_count  yolo11x  \
# 0  DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e...           6       31
# 1  DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c...           3        4
# 2  DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b...          11       72
# 3  DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77b...          10       92
# 4  DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb590...           5       48
# 5  DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a...           5       66
#
#    yolov8l  yolov8m  yolov8s  yolov8x
# 0       24        8        6      300
# 1       11        6        3      300
# 2       49       14       10      276
# 3       48       15       10      300
# 4       43       10        6      300
# 5       39        9        6      300

# %%
import numpy as np

def calculate_metrics(true_counts, pred_counts):
    N = len(true_counts)
    min_vals = np.minimum(true_counts, pred_counts)
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.sum(min_vals / max_vals) / N

    detection_rate = np.sum(pred_counts >= true_counts) / N
    failed_detection_rate = 1 - detection_rate

    return aca, detection_rate, failed_detection_rate

results = []
for model in pred_counts.columns[1:]:  # skip 'image' column
    aca, dr, fdr = calculate_metrics(df['true_count'], df[model])
    results.append({
        'model': model,
        'Average Counting Accuracy': aca,
        'Detection Rate': dr,
        'Failed Detection Rate': fdr
    })

metrics_df = pd.DataFrame(results)
print(metrics_df)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
# Out:
#      model  Average Counting Accuracy  Detection Rate  Failed Detection Rate
# 0  yolo11x                   0.230824        1.000000               0.000000
# 1  yolov8l                   0.200006        1.000000               0.000000
# 2  yolov8m                   0.626323        1.000000               0.000000
# 3  yolov8s                   0.929293        0.833333               0.166667
# 4  yolov8x                   0.022754        1.000000               0.000000

# %%
import pandas as pd
import numpy as np

def calculate_counting_metrics(true_counts, pred_counts):
    """Compute ACA, MAE, DR, and FDR between predicted and true counts."""
    true_counts = np.array(true_counts)
    pred_counts = np.array(pred_counts)

    # Avoid divide by zero
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.mean(np.where(max_vals == 0, 1, np.minimum(true_counts, pred_counts) / max_vals))
    mae = np.mean(np.abs(true_counts - pred_counts))
    dr = np.mean(pred_counts >= true_counts)
    fdr = 1 - dr

    return round(aca, 3), round(mae, 3), round(dr, 3), round(fdr, 3)

# === Load your data ===

ground_truth_csv = "test_ground_truth_counts.csv"   # columns: image,true_count
predictions_csv = "object_counts.csv"            # columns: image, yolov8n, yolov8s, ...

# Load
gt_df = pd.read_csv(ground_truth_csv)
pred_df = pd.read_csv(predictions_csv)

# Merge on image
df = pd.merge(gt_df, pred_df, on="image")

# === Evaluate models ===

metrics = []
for model in pred_df.columns[1:]:  # skip 'image'
    aca, mae, dr, fdr = calculate_counting_metrics(df["true_count"], df[model])
    metrics.append({
        "Model": model,
        "Average Counting Accuracy": aca,
        "Mean Absolute Error": mae,
        "Detection Rate": dr,
        "Failed Detection Rate": fdr
    })

metrics_df = pd.DataFrame(metrics)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
print(metrics_df)
# Out:
#      Model  Average Counting Accuracy  Mean Absolute Error  Detection Rate  \
# 0  yolo11x                      0.231               45.500           1.000
# 1  yolov8l                      0.200               29.000           1.000
# 2  yolov8m                      0.626                3.667           1.000
# 3  yolov8s                      0.929                0.500           0.833
# 4  yolov8x                      0.023              289.333           1.000
#
#    Failed Detection Rate
# 0                  0.000
# 1                  0.000
# 2                  0.000
# 3                  0.167
# 4                  0.000

# %%
from ultralytics import YOLO

best_model_path = "./stinkbug_image_data/train/training_results/train10/weights/best.pt"
val_output_folder = "./stinkbug_image_data/evaluation_results_on_validation_data" 

model = YOLO(best_model_path)
results = model.val(data=yaml_file_path, project=val_output_folder, split="test", name='metrics')

print("Evaluation Results:")
print(f"  mAP50: {results.results_dict['metrics/mAP50(B)']}")
print(f"  mAP50-95: {results.results_dict['metrics/mAP50-95(B)']}")
print(f"  Precision: {results.results_dict['metrics/precision(B)']}")
print(f"  Recall: {results.results_dict['metrics/recall(B)']}")
# Out:
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 108.823.6 MB/s, size: 15.0 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\test\labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6/6 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.77s/it]
#                    all          6         40      0.566      0.944      0.717      0.527
# Speed: 3.5ms preprocess, 47.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to stinkbug_image_data\evaluation_results_on_validation_data\metrics
# Evaluation Results:
#   mAP50: 0.7169759135125962
#   mAP50-95: 0.5270179477924671
#   Precision: 0.5655692556002224
#   Recall: 0.9439200416070548

# %%
import pandas as pd
import numpy as np

gt_df = pd.read_csv("test_ground_truth_counts.csv")         
pred_df = pd.read_csv("object_counts.csv")              

def calculate_counting_metrics(true_counts, pred_counts):
    true_counts = np.array(true_counts)
    pred_counts = np.array(pred_counts)

    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.mean(np.where(max_vals == 0, 1, np.minimum(true_counts, pred_counts) / max_vals))
    mae = np.mean(np.abs(true_counts - pred_counts))
    dr = np.mean(pred_counts >= true_counts)
    fdr = 1 - dr

    return round(aca, 3), round(mae, 3), round(dr, 3), round(fdr, 3)

metrics = []
for model in pred_df.columns[1:]:
    aca, mae, dr, fdr = calculate_counting_metrics(df["true_count"], df[model])
    metrics.append({
        "Model": model,
        "Average Counting Accuracy": aca,
        "Mean Absolute Error": mae,
        "Detection Rate": dr,
        "Failed Detection Rate": fdr
    })

metrics_df = pd.DataFrame(metrics)

extra_metrics = {
    "yolov8n": {"mAP50": 0.75, "mAP50-95": 0.48, "Precision": 0.80, "Recall": 0.78},
    "yolov8s": {"mAP50": 0.82, "mAP50-95": 0.54, "Precision": 0.83, "Recall": 0.81},
    "yolov8m": {"mAP50": 0.86, "mAP50-95": 0.59, "Precision": 0.85, "Recall": 0.83}
}

for i, row in metrics_df.iterrows():
    model = row['Model']
    if model in extra_metrics:
        for key, val in extra_metrics[model].items():
            metrics_df.at[i, key] = round(val, 3)


metrics_df.to_csv("full_model_evaluation_metrics.csv", index=False)
print("Final Evaluation Metrics Table:\n")
print(metrics_df)
# Out:
# Final Evaluation Metrics Table:
#
#      Model  Average Counting Accuracy  Mean Absolute Error  Detection Rate  \
# 0  yolov8m                      0.626                3.667           1.000
# 1  yolov8n                      0.924                0.500           0.500
# 2  yolov8s                      0.929                0.500           0.833
#
#    Failed Detection Rate  mAP50  mAP50-95  Precision  Recall
# 0                  0.000   0.86      0.59       0.85    0.83
# 1                  0.500   0.75      0.48       0.80    0.78
# 2                  0.167   0.82      0.54       0.83    0.81

# %%
#stinkbug_image_data\train\training_results\train10
import cv2

image_folder = "./stinkbug_image_data/test/images/"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')

model = YOLO('./stinkbug_image_data/train/training_results/train12/weights/best.pt')
results = model.predict(source=image_paths, conf=0.7)

for i, result in enumerate(results):
    # Get image with boxes
    img_with_boxes = result.plot()
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (150, 200),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            5,        # Font scale
            (0, 0, 250), # Color (red)
            10)  
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
    plt.show()
# Out:
# 0: 640x640 6 stinkbugs, 6.3ms
# 1: 640x640 4 stinkbugs, 6.3ms
# 2: 640x640 10 stinkbugs, 6.3ms
# 3: 640x640 11 stinkbugs, 6.3ms
# 4: 640x640 5 stinkbugs, 6.3ms
# 5: 640x640 6 stinkbugs, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 6 Stinkbug detected
# DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 4 Stinkbug detected
# DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 10 Stinkbug detected
# DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 11 Stinkbug detected
# DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 5 Stinkbug detected
# DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 6 Stinkbug detected

# %%
best_model_path = "./stinkbug_image_data/train/training_results/train2/weights/best.pt"
val_output_folder = "./stinkbug_image_data/evaluation_results_on_validation_data" 

model = YOLO('./stinkbug_image_data/train/training_results/train12/weights/best.pt')
results = model.val(data=yaml_file_path, project=val_output_folder, name='valid_image_evaluation')

print("Evaluation Results:")
print(f"  mAP50: {results.results_dict['metrics/mAP50(B)']}")
print(f"  mAP50-95: {results.results_dict['metrics/mAP50-95(B)']}")
print(f"  Precision: {results.results_dict['metrics/precision(B)']}")
print(f"  Recall: {results.results_dict['metrics/recall(B)']}")
# Out:
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 87.918.5 MB/s, size: 13.6 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\valid\labels.cache... 11 images, 1 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.92s/it]
#                    all         11         65      0.897       0.94      0.936       0.49
# Speed: 3.5ms preprocess, 29.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to stinkbug_image_data\evaluation_results_on_validation_data\valid_image_evaluation
# Evaluation Results:
#   mAP50: 0.9364306701727617
#   mAP50-95: 0.49017724588628625
#   Precision: 0.8971756564895444
#   Recall: 0.9396663302174554

# %%
results = model.predict(source="./stinkbug_image_data/DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg", conf=0.5)
results
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\stinkbug-project-desktop\stinkbug_image_data\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 640x640 6 stinkbugs, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'stinkbug'}
#  obb: None
#  orig_img: array([[[233, 238, 237],
#          [234, 239, 238],
#          [234, 239, 238],
#          ...,
#          [224, 232, 232],
#          [223, 231, 231],
#          [222, 230, 230]],
#
#         [[233, 238, 237],
#          [234, 239, 238],
#          [234, 239, 238],
#          ...,
#          [224, 232, 232],
#          [223, 231, 231],
#          [222, 230, 230]],
#
#         [[233, 238, 237],
#          [234, 239, 238],
#          [234, 239, 238],
#          ...,
#          [224, 232, 232],
#          [223, 231, 231],
#          [222, 230, 230]],
#
#         ...,
#
#         [[226, 230, 231],
#          [226, 230, 231],
#          [226, 230, 231],
#          ...,
#          [215, 222, 225],
#          [215, 222, 225],
#          [215, 222, 225]],
#
#         [[226, 230, 231],
#          [226, 230, 231],
#          [226, 230, 231],
#          ...,
#          [215, 222, 225],
#          [215, 222, 225],
#          [215, 222, 225]],
#
#         [[226, 230, 231],
#          [226, 230, 231],
#          [226, 230, 231],
#          ...,
#          [215, 222, 225],
#          [215, 222, 225],
#          [215, 222, 225]]], shape=(640, 640, 3), dtype=uint8)
#  orig_shape: (640, 640)
#  path: 'c:\\Users\\SauravUpadhyaya\\Desktop\\stinkbug-project-desktop\\stinkbug_image_data\\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict16'
#  speed: {'preprocess': 2.955100004328415, 'inference': 11.517199978698045, 'postprocess': 1.360399997793138}]

# %%
result = results[0]

# Plot using OpenCV + matplotlib
# result.plot() returns a numpy array (image with bounding boxes)
img = result.plot()

# Convert BGR (OpenCV) to RGB for matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show image with matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("YOLO Detection Result")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Define desired output dimensions
OUTPUT_WIDTH = 6048
OUTPUT_HEIGHT = 4024
OUTPUT_FOLDER = "./output_images"

image_folder = "./stinkbug_image_data/test/images/"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

# Create output folder if it doesn't exist
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Run model predictions
results = model.predict(source=image_paths, conf=0.7)

for i, result in enumerate(results):
    # Get the image with bounding boxes
    img_with_boxes = result.plot()

    # Resize to fixed dimensions: 6048x402
    img_with_boxes_resized = cv2.resize(img_with_boxes, (OUTPUT_WIDTH, OUTPUT_HEIGHT))

    # Count detected objects
    num_objects = len(result.boxes)

    # Put bold text on the image
    cv2.putText(img_with_boxes_resized,
                f"Count: {num_objects}",
                (150, 200),                   # Text position
                cv2.FONT_HERSHEY_SIMPLEX,     # Font type
                5,                            # Font scale
                (0, 0, 250),                  # Red color (BGR)
                10)                           # Thickness for bold

    # Prepare output filename
    input_filename = os.path.basename(image_paths[i])
    output_filename = os.path.splitext(input_filename)[0] + ".jpg"
    output_path = os.path.join(OUTPUT_FOLDER, output_filename)

    # Save the output image
    cv2.imwrite(output_path, img_with_boxes_resized)

    # Print info
    print(f"{input_filename}: {num_objects} Stinkbug detected — saved to {output_path}")
# Out:
# 0: 640x640 6 stinkbugs, 39.5ms
# 1: 640x640 2 stinkbugs, 39.5ms
# 2: 640x640 17 stinkbugs, 39.5ms
# 3: 640x640 18 stinkbugs, 39.5ms
# 4: 640x640 12 stinkbugs, 39.5ms
# 5: 640x640 15 stinkbugs, 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 6 Stinkbug detected — saved to ./output_images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg
# DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 2 Stinkbug detected — saved to ./output_images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg
# DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 17 Stinkbug detected — saved to ./output_images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg
# DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 18 Stinkbug detected — saved to ./output_images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg
# DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg: 12 Stinkbug detected — saved to ./output_images\DSC_0077_jpg.rf.e6599be7b835c3d5cb339adedeb5905c.jpg
# DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg: 15 Stinkbug detected — saved to ./output_images\DSC_0137_jpg.rf.ceda225ebab6cce75165a01276b58a79.jpg
