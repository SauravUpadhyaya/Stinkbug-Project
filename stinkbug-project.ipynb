# %%
# !pip install -r requirements.txt

# %%
# !python -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128

# %%
# %pip install pandas     
# %pip install matplotlib  
# %pip install scikit-learn  
# %pip install ultralytics

# %%
# from pathlib import Path

# zip_path = (Path.home() / "Downloads" / "1008_red_banded_image_dataset.zip").resolve()
# print("Absolute path to the zip file:", zip_path)

# %%
# %pip install python-dotenv

# %%
import torch

print(f"PyTorch version: {torch.__version__}") 
cuda_available = torch.cuda.is_available() 
print(f"CUDA available: {cuda_available}") 
 
if cuda_available: 
    device = torch.device("cuda") 
    print(f"Using device: {device}") 
    print(f"GPU name: {torch.cuda.get_device_name(0)}") 
    x = torch.randn(10, 10).to(device) 
    print(f"Tensor on GPU: {x.device}") 
else: 
    device = torch.device("cpu") 
    print(f"Using device: {device}")
# Out:
# PyTorch version: 2.7.1+cu128
# CUDA available: True
# Using device: cuda
# GPU name: NVIDIA RTX 4000 Ada Generation
# Tensor on GPU: cuda:0

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.2.6

# %%
# !pip uninstall torch torchvision torchaudio -y (need to be used if there is version issue with pytorch)

# %%
# !pip install torch==2.7.1

# %%
# import zipfile   
# import os
# from dotenv import load_dotenv

# load_dotenv()

# # zip_path = os.getenv("ZIP_FILE_PATH") 

# unzip_to = "stinkbug_image_data_third_file"

# # Extract
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(unzip_to)

# print("Stinkbug Image data is available in your project directory ")

# %%
# for root, dirs, files in os.walk(unzip_to):
#     for file in files[:5]:
#         print(os.path.join(root, file))

# %%
image_data = './stinkbug_image_data_third_file/train/images'
label_data  = './stinkbug_image_data_third_file/train/labels'

# %%
import os
count = 0
image_list= []
for i in os.listdir(image_data):
  print(i)
  image_list.append(i)
  count += 1
  if count ==5:
    break;

print("\nFirst 5 images in the dataset:")
image_list
# Out:
# AdltStnkBug_002_3500_jpg.rf.0596631d93d928b9573d33882e768552.jpg
# AdltStnkBug_004_4500_jpg.rf.cf5e23eec87cb5725928334d2f6b7a38.jpg
# AdltStnkBug_005_3500_jpg.rf.4d2368383a49d002492273d41ced4ee1.jpg
# AdltStnkBug_005_4500_jpg.rf.f92f13cb913e80f117d5c4fb8a036373.jpg
# AdltStnkBug_006_3500_jpg.rf.6a2ed42ee54426a567747b65e1d0107e.jpg
#
# First 5 images in the dataset:
# ['AdltStnkBug_002_3500_jpg.rf.0596631d93d928b9573d33882e768552.jpg',
#  'AdltStnkBug_004_4500_jpg.rf.cf5e23eec87cb5725928334d2f6b7a38.jpg',
#  'AdltStnkBug_005_3500_jpg.rf.4d2368383a49d002492273d41ced4ee1.jpg',
#  'AdltStnkBug_005_4500_jpg.rf.f92f13cb913e80f117d5c4fb8a036373.jpg',
#  'AdltStnkBug_006_3500_jpg.rf.6a2ed42ee54426a567747b65e1d0107e.jpg']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, axs = plt.subplots(2, 2, figsize=(4, 4))
axs = axs.flatten()

for i, filename in enumerate(image_list[:4]):
    img_path = os.path.join(image_data, filename)
    img = mpimg.imread(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
count = 0
for i in os.listdir(label_data):
  print(i)
  count +=1
  if count == 5:
    break;
# Out:
# AdltStnkBug_002_3500_jpg.rf.0596631d93d928b9573d33882e768552.txt
# AdltStnkBug_004_4500_jpg.rf.cf5e23eec87cb5725928334d2f6b7a38.txt
# AdltStnkBug_005_3500_jpg.rf.4d2368383a49d002492273d41ced4ee1.txt
# AdltStnkBug_005_4500_jpg.rf.f92f13cb913e80f117d5c4fb8a036373.txt
# AdltStnkBug_006_3500_jpg.rf.6a2ed42ee54426a567747b65e1d0107e.txt

# %%
count = 0
for filename in os.listdir(label_data):
  file_path = os.path.join(label_data, filename)
  with open(file_path, 'r') as f:
      content = f.read()
      print(f"Content of {filename}:\n{content}")
      count += 1
      if count == 5:
        break
# Out:
# Content of AdltStnkBug_002_3500_jpg.rf.0596631d93d928b9573d33882e768552.txt:
# 0 0.4970703125 0.41455078125 0.03125 0.03662109375
# 0 0.6236572265625 0.402587890625 0.027587890625 0.03125
# 0 0.4658203125 0.8541259765625 0.02880859375 0.038330078125
# 0 0.3394775390625 0.46923828125 0.031005859375 0.02880859375
# 0 0.643798828125 0.347900390625 0.02880859375 0.03955078125
# 0 0.629150390625 0.77294921875 0.025390625 0.04150390625
# 0 0.5440673828125 0.74853515625 0.030029296875 0.037109375
# 0 0.4161376953125 0.6790771484375 0.024658203125 0.052978515625
# 0 0.6177978515625 0.591796875 0.020263671875 0.04638671875
# 0 0.5771484375 0.635498046875 0.029296875 0.0322265625
# Content of AdltStnkBug_004_4500_jpg.rf.cf5e23eec87cb5725928334d2f6b7a38.txt:
# 0 0.7828369140625 0.6419677734375 0.030029296875 0.047119140625
# 0 0.5064697265625 0.843505859375 0.021240234375 0.04150390625
# 0 0.326416015625 0.808837890625 0.02587890625 0.04736328125
# ...

# %%
import pandas as pd

label_files = [f for f in os.listdir(label_data)[:5] if f.endswith('.txt')]

data = []
for label_file in label_files:
    label_path = os.path.join(label_data, label_file)
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            data.append(([label_file] + parts))

if data:
    df = pd.DataFrame(data, columns=['filename', 'class_id', 'x_center', 'y_center', 'width', 'height'])
    display(df.head())
    display(df.tail())
# Out:
#                                             filename class_id  \
# 0  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 1  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 2  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 3  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 4  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
#
#           x_center         y_center           width          height
# 0     0.4970703125    0.41455078125         0.03125   0.03662109375
# 1  0.6236572265625   0.402587890625  0.027587890625         0.03125
# 2     0.4658203125  0.8541259765625   0.02880859375  0.038330078125
# 3  0.3394775390625    0.46923828125  0.031005859375   0.02880859375
# 4   0.643798828125   0.347900390625   0.02880859375   0.03955078125
#                                              filename class_id  \
# 42  AdltStnkBug_006_3500_jpg.rf.6a2ed42ee54426a567...        0
# ...

# %%
image_filenames = os.listdir(image_data)[:5]

image_paths = [os.path.normpath(os.path.join(image_data, filename)) for filename in image_filenames]
label_paths = [os.path.normpath(os.path.join(label_data, filename.replace('.jpg', '.txt'))) for filename in image_filenames]

print("image paths:", image_paths)
print("\n")
print("label paths:", label_paths)
print("\n")
print("First 5 Image Paths:")
for path in image_paths:
    print(path)

print("\n")
print("First 5 Label Paths:")
for path in label_paths:
    print(path)
# Out:
# image paths: ['stinkbug_image_data_third_file\\train\\images\\AdltStnkBug_002_3500_jpg.rf.0596631d93d928b9573d33882e768552.jpg', 'stinkbug_image_data_third_file\\train\\images\\AdltStnkBug_004_4500_jpg.rf.cf5e23eec87cb5725928334d2f6b7a38.jpg', 'stinkbug_image_data_third_file\\train\\images\\AdltStnkBug_005_3500_jpg.rf.4d2368383a49d002492273d41ced4ee1.jpg', 'stinkbug_image_data_third_file\\train\\images\\AdltStnkBug_005_4500_jpg.rf.f92f13cb913e80f117d5c4fb8a036373.jpg', 'stinkbug_image_data_third_file\\train\\images\\AdltStnkBug_006_3500_jpg.rf.6a2ed42ee54426a567747b65e1d0107e.jpg']
#
#
# ...

# %%
image_filenames = [f for f in os.listdir(image_data) if f.endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

image_label_pairs = []
for filename in image_filenames:
    image_path = os.path.join(image_data, filename)
    label_filename = filename.rsplit('.', 1)[0] + '.txt'
    label_path = os.path.join(label_data, label_filename)
    image_label_pairs.append((image_path, label_path))

print("List of tuples following format of(Image path , label path)")
print(image_label_pairs[:5])

print("\n")
print(f" Number of (Image path , label path) pairs : {len(image_label_pairs)}")
# Out:
# List of tuples following format of(Image path , label path)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os
import io
from PIL import Image

def draw_boxes_on_image(image_path, label_path):
    img = Image.open(image_path).convert("RGB")
    img_width, img_height = img.size

    fig, ax = plt.subplots(1)
    ax.imshow(img)

    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) == 5:
                    class_id, x_center, y_center, width, height = map(float, parts)
                    x1 = (x_center - width / 2) * img_width
                    y1 = (y_center - height / 2) * img_height
                    box_width = width * img_width
                    box_height = height * img_height
                    rect = patches.Rectangle((x1, y1), box_width, box_height, linewidth=1, edgecolor='r', facecolor='none')
                    ax.add_patch(rect)


    ax.set_axis_off()
    plt.tight_layout()
    buf = io.BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    annotated_img = Image.open(buf).convert("RGB")
    plt.close(fig)

    return annotated_img

for img_path, label_path in image_label_pairs[:5]:
    annotated_img = draw_boxes_on_image(img_path, label_path)
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow(annotated_img)
    ax.set_title(os.path.basename(img_path))
    ax.axis('off')
    plt.show()

# %%
import yaml
import os

train_img_dir = './stinkbug_image_data_third_file/train/images'
print(f"Training images directory: {train_img_dir}")
val_img_dir = './stinkbug_image_data_third_file/valid/images'
test_img_dir = './stinkbug_image_data_third_file/test/images'

train_label_dir = './stinkbug_image_data_third_file/train/labels'
val_label_dir = './stinkbug_image_data_third_file/valid/labels'
test_label_dir = './stinkbug_image_data_third_file/test/labels'

class_names = ['stinkbug']

data_config = {
    'train': train_img_dir,
    'val': val_img_dir,
    'test': test_img_dir,
    'nc': len(class_names),
    'names': class_names,
    'train_labels': train_label_dir,
    'val_labels': val_label_dir,
    'test_labels': test_label_dir
}

yaml_file_path = os.path.join(os.getcwd(), 'stinkbug_data.yaml')

with open(yaml_file_path, 'w') as f:
    yaml.dump(data_config, f, default_flow_style=None)
# Out:
# Training images directory: ./stinkbug_image_data_third_file/train/images

# %%
import pandas as pd

label_files = [f for f in os.listdir(label_data)[:5] if f.endswith('.txt')]

data = []
for label_file in label_files:
    label_path = os.path.join(label_data, label_file)
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            data.append(([label_file] + parts))

if data:
    df = pd.DataFrame(data, columns=['filename', 'class_id', 'x_center', 'y_center', 'width', 'height'])
    display(df.head(10))
    display(df.tail(10))
# Out:
#                                             filename class_id  \
# 0  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 1  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 2  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 3  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 4  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 5  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 6  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 7  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 8  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
# 9  AdltStnkBug_002_3500_jpg.rf.0596631d93d928b957...        0
#
#           x_center         y_center           width          height
# 0     0.4970703125    0.41455078125         0.03125   0.03662109375
# 1  0.6236572265625   0.402587890625  0.027587890625         0.03125
# 2     0.4658203125  0.8541259765625   0.02880859375  0.038330078125
# ...

# %%
output_folder = "./stinkbug_image_data_third_file/train/training_results"
output_folder
# Out:
# './stinkbug_image_data_third_file/train/training_results'

# %%
# !python --version
# Out:
# Python 3.12.8

# %%
import torch

print(f"PyTorch version: {torch.__version__}") 
cuda_available = torch.cuda.is_available() 
print(f"CUDA available: {cuda_available}") 
 
if cuda_available: 
    device = torch.device("cuda") 
    print(f"Using device: {device}") 
    print(f"GPU name: {torch.cuda.get_device_name(0)}") 
    x = torch.randn(10, 10).to(device) 
    print(f"Tensor on GPU: {x.device}") 
else: 
    device = torch.device("cpu") 
    print(f"Using device: {device}")
# Out:
# PyTorch version: 2.7.1+cu128
# CUDA available: True
# Using device: cuda
# GPU name: NVIDIA RTX 4000 Ada Generation
# Tensor on GPU: cuda:0

# %%
# from ultralytics import YOLO

# model = YOLO('yolov8s.pt')

# results = model.train(data=yaml_file_path, epochs=100, imgsz=640, batch=32, patience= 10, workers = 2,project=output_folder)

# %%
# # converting the dimension of image into 4096*4096 aiming to use the autolabel feature of the roboflow

# from PIL import Image
# import os

# # Path to the folder with your images
# input_folder = './Adult_Stinkbugs_4096_4096'
# output_folder = 'resized_images_4096_4096'

# target_size = (4096, 4096)

# # Create output folder if it doesn't exist
# os.makedirs(output_folder, exist_ok=True)

# # Supported image extensions
# image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp']

# # Resize loop
# for filename in os.listdir(input_folder):
#     if any(filename.lower().endswith(ext) for ext in image_extensions):
#         input_path = os.path.join(input_folder, filename)
#         output_path = os.path.join(output_folder, filename)

#         try:
#             with Image.open(input_path) as img:
#                 resized_img = img.resize(target_size, Image.LANCZOS)
#                 resized_img.save(output_path)
#                 print(f"Resized: {filename}")
#         except Exception as e:
#             print(f"Error processing {filename}: {e}")

# %%
from ultralytics import YOLO
import shutil
import os


# Define model variants you want to train
model_variants = ['yolov8s.pt', 'yolov8m.pt', 'yolov8l.pt', 'yolov8x.pt'] 


# Where to save your final organized best.pt files
final_save_dir = 'saved_models_of_1008_images'
os.makedirs(final_save_dir, exist_ok=True)

for model_file in model_variants:
    # Derive a model name tag (e.g., yolov8n)
    model_name = model_file.replace('.pt', '')

    # Load model
    model = YOLO(model_file)

    # Train the model
    results = model.train(
        data=yaml_file_path,
        epochs=100,
        imgsz=640,
        batch=32,
        patience=10,
        workers=2,
        project='model_outputsof_1008_images',   # Base folder for all runs
        name=model_name            # Unique folder per model
    )

    # Define paths
    best_model_src = f"model_outputsof_1008_images/{model_name}/weights/best.pt"
    best_model_dest = os.path.join(final_save_dir, f"{model_name}_best.pt")

    # Save best.pt to your organized directory
    shutil.copy(best_model_src, best_model_dest)
    print(f"{model_name}: best.pt saved to {best_model_dest}")
# Out:
# New https://pypi.org/project/ultralytics/8.3.193 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# ...

# %%
from ultralytics import YOLO
import shutil
import os


# Define model variants you want to train
model_variants = ['yolov8l.pt', 'yolov8x.pt'] 


# Where to save your final organized best.pt files
final_save_dir = 'saved_models_of_1008_images'
os.makedirs(final_save_dir, exist_ok=True)

for model_file in model_variants:
    # Derive a model name tag (e.g., yolov8n)
    model_name = model_file.replace('.pt', '')

    # Load model
    model = YOLO(model_file)

    # Train the model
    results = model.train(
        data=yaml_file_path,
        epochs=100,
        imgsz=640,
        batch=32,
        patience=10,
        workers=2,
        project='model_outputsof_1008_images',   # Base folder for all runs
        name=model_name            # Unique folder per model
    )

    # Define paths
    best_model_src = f"model_outputsof_1008_images/{model_name}/weights/best.pt"
    best_model_dest = os.path.join(final_save_dir, f"{model_name}_best.pt")

    # Save best.pt to your organized directory
    shutil.copy(best_model_src, best_model_dest)
    print(f"{model_name}: best.pt saved to {best_model_dest}")
# Out:
# New https://pypi.org/project/ultralytics/8.3.193 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# ...

# %%
# from ultralytics import YOLO
# import shutil
# import os


# # Define model variants you want to train
# model_variants = [ 'yolo11x.pt'] 


# # Where to save your final organized best.pt files
# final_save_dir = 'saved_models_of_1008_images'
# os.makedirs(final_save_dir, exist_ok=True)

# for model_file in model_variants:
#     # Derive a model name tag (e.g., yolov8n)
#     model_name = model_file.replace('.pt', '')

#     # Load model
#     model = YOLO(model_file)

#     # Train the model
#     results = model.train(
#         data=yaml_file_path,
#         epochs=100,
#         imgsz=640,
#         batch=32,
#         patience=10,
#         workers=2,
#         project='model_outputsof_1008_images',   # Base folder for all runs
#         name=model_name            # Unique folder per model
#     )

#     # Define paths
#     best_model_src = f"model_outputsof_1008_images/{model_name}/weights/best.pt"
#     best_model_dest = os.path.join(final_save_dir, f"{model_name}_best.pt")

#     # Save best.pt to your organized directory
#     shutil.copy(best_model_src, best_model_dest)
#     print(f"{model_name}: best.pt saved to {best_model_dest}")

# %%
# using test dataset and best models to count the number of stinkbugs 

import os
import csv
from ultralytics import YOLO
import cv2


model_dir = "saved_models_of_1008_images"          
test_images_dir = "./stinkbug_image_data_third_file/test/images"    
output_root = "model_predictions"  
metrics_csv = "object_counts.csv"   

os.makedirs(output_root, exist_ok=True)

# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Save visualization
            result_img = results[0].plot() 

            # Create output dir for this model
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            # Save image
            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f"Saved: {save_path} | Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n All done! Object counts saved to: {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg: 640x640 10 stinkbugs, 36.8ms
# Speed: 6.3ms preprocess, 36.8ms inference, 84.4ms postprocess per image at shape (1, 3, 640, 640)
# Saved: model_predictions\yolov8l\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg | Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg: 640x640 10 stinkbugs, 26.6ms
# Speed: 4.2ms preprocess, 26.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Saved: model_predictions\yolov8m\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg | Count: 10 objects
#
# ...

# %%
import os
import csv
from ultralytics import YOLO
import cv2


# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Visualized result
            result_img = results[0].plot()  # image with boxes

            # Draw model name and object count on top-left corner
            cv2.putText(
                result_img,
                f"{model_name}: {num_objects} objects",
                org=(10, 40),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=1.0,
                color=(0, 255, 0),
                thickness=2,
                lineType=cv2.LINE_AA
            )

            # Save the image
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f" Saved: {save_path} | Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n Done! Visuals saved in {output_root}/ and counts in {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg: 640x640 10 stinkbugs, 71.6ms
# Speed: 5.0ms preprocess, 71.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#  Saved: model_predictions\yolov8l\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg | Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg: 640x640 10 stinkbugs, 34.1ms
# Speed: 5.0ms preprocess, 34.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#  Saved: model_predictions\yolov8m\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg | Count: 10 objects
#
# ...

# %%
def get_counts_from_labels(labels_dir, csv_output_path):
    import os
    import csv

    counts = {}
    for label_file in os.listdir(labels_dir):
        if label_file.endswith(".txt"):
            with open(os.path.join(labels_dir, label_file)) as f:
                counts[label_file.replace('.txt', '.jpg')] = len(f.readlines())
    
    with open(csv_output_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['image', 'true_count'])
        for img, count in counts.items():
            writer.writerow([img, count])
    
    print(f"Saved ground truth counts to {csv_output_path}")

# Usage:
get_counts_from_labels("./stinkbug_image_data_third_file/train/labels", "train_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data_third_file/valid/labels", "val_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data_third_file/test/labels", "test_ground_truth_counts.csv")
# Out:
# Saved ground truth counts to train_ground_truth_counts.csv
# Saved ground truth counts to val_ground_truth_counts.csv
# Saved ground truth counts to test_ground_truth_counts.csv

# %%
import pandas as pd

# Load ground truth counts CSV
gt_counts = pd.read_csv("test_ground_truth_counts.csv")  

# Load predicted counts CSV
pred_counts = pd.read_csv("object_counts.csv")  
df = pd.merge(gt_counts, pred_counts, on="image")

# %%
df
# Out:
#                                                  image  true_count  yolov8l  \
# 0    AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1...          10       10
# 1    AdltStnkBug_003_4500_jpg.rf.5f87dbb22f549c29f6...          10       10
# 2    AdltStnkBug_006_5500_jpg.rf.c2c34bdc5e17b0ae98...           7        7
# 3    AdltStnkBug_013_5500_jpg.rf.487e22e297360b9540...           7        7
# 4    AdltStnkBug_016_4500_jpg.rf.6b13e707920e40450e...          10       10
# ..                                                 ...         ...      ...
# 146  AdltStnkBug_325_4500_jpg.rf.5e83d82b625e488a74...          15       15
# 147  AdltStnkBug_329_5500_jpg.rf.69d6715f62dfcabb27...          14       14
# 148  AdltStnkBug_332_5500_jpg.rf.78f1dfb1127de8f4d4...          13       13
# 149  AdltStnkBug_334_3500_jpg.rf.88d4b32883c6575e1e...          12       15
# 150  AdltStnkBug_336_5500_jpg.rf.d6151419b895b22298...          13       13
#
#      yolov8m  yolov8s  yolov8x
# ...

# %%
import numpy as np

def calculate_metrics(true_counts, pred_counts):
    N = len(true_counts)
    min_vals = np.minimum(true_counts, pred_counts)
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.sum(min_vals / max_vals) / N

    detection_rate = np.sum(pred_counts >= true_counts) / N
    failed_detection_rate = 1 - detection_rate

    return aca, detection_rate, failed_detection_rate

results = []
for model in pred_counts.columns[1:]: 
    aca, dr, fdr = calculate_metrics(df['true_count'], df[model])
    results.append({
        'model': model,
        'Average Counting Accuracy': aca,
        'Detection Rate': dr,
        'Failed Detection Rate': fdr
    })

metrics_df = pd.DataFrame(results)
print(metrics_df)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
# Out:
#      model  Average Counting Accuracy  Detection Rate  Failed Detection Rate
# 0  yolov8l                   0.941716        0.993377               0.006623
# 1  yolov8m                   0.987530        0.993377               0.006623
# 2  yolov8s                   0.991021        0.993377               0.006623
# 3  yolov8x                   0.977106        0.993377               0.006623

# %%
import pandas as pd
import numpy as np

def calculate_counting_metrics(true_counts, pred_counts):
    """Compute ACA, MAE, DR, and FDR between predicted and true counts."""
    true_counts = np.array(true_counts)
    pred_counts = np.array(pred_counts)

    # Avoid divide by zero
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.mean(np.where(max_vals == 0, 1, np.minimum(true_counts, pred_counts) / max_vals))
    mae = np.mean(np.abs(true_counts - pred_counts))
    dr = np.mean(pred_counts >= true_counts)
    fdr = 1 - dr

    return round(aca, 3), round(mae, 3), round(dr, 3), round(fdr, 3)

# === Load your data ===

ground_truth_csv = "test_ground_truth_counts.csv"   # columns: image,true_count
predictions_csv = "object_counts.csv"            # columns: image, yolov8n, yolov8s, ...

# Load
gt_df = pd.read_csv(ground_truth_csv)
pred_df = pd.read_csv(predictions_csv)

# Merge on image
df = pd.merge(gt_df, pred_df, on="image")

# === Evaluate models ===

metrics = []
for model in pred_df.columns[1:]: 
    aca, mae, dr, fdr = calculate_counting_metrics(df["true_count"], df[model])
    metrics.append({
        "Model": model,
        "Average Counting Accuracy": aca,
        "Mean Absolute Error": mae,
        "Detection Rate": dr,
        "Failed Detection Rate": fdr
    })

metrics_df = pd.DataFrame(metrics)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
print(metrics_df)
# Out:
#      Model  Average Counting Accuracy  Mean Absolute Error  Detection Rate  \
# 0  yolov8l                      0.942                0.656           0.993
# 1  yolov8m                      0.988                0.139           0.993
# 2  yolov8s                      0.991                0.113           0.993
# 3  yolov8x                      0.977                0.278           0.993
#
#    Failed Detection Rate
# 0                  0.007
# 1                  0.007
# 2                  0.007
# 3                  0.007

# %%
import pandas as pd
import os
from ultralytics import YOLO  
from pathlib import Path 

#model_paths = [f"./saved_models/{f}".replace("\\", "/") for f in os.listdir("saved_models") if f.endswith(".pt")]

model_folder = "saved_models_of_1008_images"


for f in os.listdir(model_folder):
    print("best model name :",f)
    print("model path: ", os.path.join(model_folder, f))



model_paths = [os.path.join(model_folder, f) for f in os.listdir(model_folder) if f.endswith(".pt")]

# Folder to save evaluation results
val_output_folder = "val_outputs"

# Store results
results_list = []

for model_path in model_paths:
    print(f"Evaluating model: {model_path}")
    model = YOLO(model_path)

    # Run validation on the test split
    results = model.val(data=yaml_file_path, project=val_output_folder, split="test", name='metrics')


    # Extract metrics
    metrics = results.results_dict  # returns a dict with metrics

    results_list.append({
        "Model": os.path.basename(model_path),
        "mAP50": results.results_dict['metrics/mAP50(B)'],
        "mAP50-95": results.results_dict['metrics/mAP50-95(B)'],
        "Precision": results.results_dict['metrics/precision(B)'],
        "Recall": results.results_dict['metrics/recall(B)'],
    })

# Create DataFrame
df = pd.DataFrame(results_list)

# Show results
print("\nEvaluation Results DataFrame:")
print(df)
# Out:
# best model name : yolov8l_best.pt
# model path:  saved_models_of_1008_images\yolov8l_best.pt
# best model name : yolov8m_best.pt
# model path:  saved_models_of_1008_images\yolov8m_best.pt
# best model name : yolov8s_best.pt
# model path:  saved_models_of_1008_images\yolov8s_best.pt
# best model name : yolov8x_best.pt
# model path:  saved_models_of_1008_images\yolov8x_best.pt
# Evaluating model: saved_models_of_1008_images\yolov8l_best.pt
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 112 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 966.7186.9 MB/s, size: 385.1 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\labels.cache... 151 images, 0 backgrounds, 0 corrupt: 100%|██████████| 151/151 [00:00<?, ?it/s]
# ...

# %%
# %matplotlib inline

# %%
print(os.path.exists("./saved_models_of_1008_images/yolov8s_best.pt"))
# Out:
# True

# %%
# Checking if the best model is working fine on some random images
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os


image_folder = "./stinkbug_image_data_third_file/test/images/"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')


model = YOLO('./saved_models_of_1008_images/yolov8s_best.pt')
results = model.predict(source=image_paths, conf=0.7)
for i, result in enumerate(results):
 
    # Get image with boxes
    img_with_boxes = result.plot()

    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
        f"Count: {num_objects}",
        (40, 40),  # Position (x, y)
        cv2.FONT_HERSHEY_SIMPLEX,
        1,        # Font scale
        (0, 0, 250), # Color (red)
        2)  
print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

# Convert BGR to RGB for matplotlib
img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

# Plot
plt.figure(figsize=(10, 10))
plt.imshow(img_rgb)
plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
plt.show()
# Out:
# 0: 640x640 10 stinkbugs, 3.6ms
# 1: 640x640 10 stinkbugs, 3.6ms
# 2: 640x640 7 stinkbugs, 3.6ms
# 3: 640x640 7 stinkbugs, 3.6ms
# 4: 640x640 10 stinkbugs, 3.6ms
# 5: 640x640 8 stinkbugs, 3.6ms
# 6: 640x640 12 stinkbugs, 3.6ms
# 7: 640x640 9 stinkbugs, 3.6ms
# 8: 640x640 9 stinkbugs, 3.6ms
# 9: 640x640 10 stinkbugs, 3.6ms
# 10: 640x640 10 stinkbugs, 3.6ms
# 11: 640x640 10 stinkbugs, 3.6ms
# 12: 640x640 11 stinkbugs, 3.6ms
# 13: 640x640 10 stinkbugs, 3.6ms
# 14: 640x640 11 stinkbugs, 3.6ms
# 15: 640x640 11 stinkbugs, 3.6ms
# 16: 640x640 10 stinkbugs, 3.6ms
# 17: 640x640 8 stinkbugs, 3.6ms
# 18: 640x640 7 stinkbugs, 3.6ms
# 19: 640x640 8 stinkbugs, 3.6ms
# 20: 640x640 5 stinkbugs, 3.6ms
# 21: 640x640 6 stinkbugs, 3.6ms
# 22: 640x640 9 stinkbugs, 3.6ms
# 23: 640x640 9 stinkbugs, 3.6ms
# 24: 640x640 9 stinkbugs, 3.6ms
# 25: 640x640 9 stinkbugs, 3.6ms
# 26: 640x640 9 stinkbugs, 3.6ms
# 27: 640x640 9 stinkbugs, 3.6ms
# 28: 640x640 9 stinkbugs, 3.6ms
# 29: 640x640 9 stinkbugs, 3.6ms
# ...

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Define desired output dimensions
OUTPUT_WIDTH = 6048
OUTPUT_HEIGHT = 4024
OUTPUT_FOLDER = "./output_images"

image_folder = "./stinkbug_image_data/test/images/"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

# Create output folder if it doesn't exist
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Run model predictions
results = model.predict(source=image_paths, conf=0.7)

for i, result in enumerate(results):
    # Get the image with bounding boxes
    img_with_boxes = result.plot()

    # Resize to fixed dimensions: 6048x402
    img_with_boxes_resized = cv2.resize(img_with_boxes, (OUTPUT_WIDTH, OUTPUT_HEIGHT))

    # Count detected objects
    num_objects = len(result.boxes)

    # Put bold text on the image
    cv2.putText(img_with_boxes_resized,
                f"Count: {num_objects}",
                (150, 200),                   # Text position
                cv2.FONT_HERSHEY_SIMPLEX,     # Font type
                5,                            # Font scale
                (0, 0, 250),                  # Red color (BGR)
                10)                           # Thickness for bold

    # Prepare output filename
    input_filename = os.path.basename(image_paths[i])
    output_filename = os.path.splitext(input_filename)[0] + ".jpg"
    output_path = os.path.join(OUTPUT_FOLDER, output_filename)

    # Save the output image
    cv2.imwrite(output_path, img_with_boxes_resized)

    # Print info
    print(f"{input_filename}: {num_objects} Stinkbug detected — saved to {output_path}")
# Out:
# 0: 640x640 6 stinkbugs, 39.5ms
# 1: 640x640 2 stinkbugs, 39.5ms
# 2: 640x640 17 stinkbugs, 39.5ms
# 3: 640x640 18 stinkbugs, 39.5ms
# 4: 640x640 12 stinkbugs, 39.5ms
# 5: 640x640 15 stinkbugs, 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg: 6 Stinkbug detected — saved to ./output_images\DSC_0014_jpg.rf.3df37a9ff9d8fb1d6474f188dc196e5e.jpg
# DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg: 2 Stinkbug detected — saved to ./output_images\DSC_0018_jpg.rf.db62384e024523dd8312d9e8a8643c1e.jpg
# DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg: 17 Stinkbug detected — saved to ./output_images\DSC_0058_jpg.rf.62ce10bbe22fce5e1ea37edb36fa6b09.jpg
# DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg: 18 Stinkbug detected — saved to ./output_images\DSC_0064_jpg.rf.5fe135ee89e20b310b764ea7cba77bd1.jpg
# ...

# %%
# creating confusion matrix plots for test and val splits

import os
from pathlib import Path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, confusion_matrix, ConfusionMatrixDisplay
from tqdm.auto import tqdm
import matplotlib.patches as patches

# try import ultralytics
try:
    from ultralytics import YOLO
except Exception as e:
    raise RuntimeError("ultralytics is required for this cell. Install with: pip install ultralytics")

ROOT = Path('.')
models_dir = ROOT / 'saved_models_of_1008_images'
data_root = ROOT / 'stinkbug_image_data_third_file'
output_base = ROOT / 'evaluation_outputs_of_1008'

# configuration
IOU_THRESH = 0.5
CONF_THRESH = 0.25
IMAGE_EXTS = ('.jpg', '.jpeg', '.png')

# helpers

def xywh_to_xyxy(xywh, img_w, img_h):
    x_c, y_c, w, h = xywh
    x1 = (x_c - w / 2.0) * img_w
    y1 = (y_c - h / 2.0) * img_h
    x2 = (x_c + w / 2.0) * img_w
    y2 = (y_c + h / 2.0) * img_h
    return [float(x1), float(y1), float(x2), float(y2)]


def iou(boxA, boxB):
    # boxes: [x1,y1,x2,y2]
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interW = max(0, xB - xA)
    interH = max(0, yB - yA)
    interArea = interW * interH
    boxAArea = max(0, boxA[2] - boxA[0]) * max(0, boxA[3] - boxA[1])
    boxBArea = max(0, boxB[2] - boxB[0]) * max(0, boxB[3] - boxB[1])
    denom = boxAArea + boxBArea - interArea
    if denom <= 0:
        return 0.0
    return interArea / denom


def read_gt_labels(label_path, img_w, img_h):
    boxes = []
    if not label_path.exists():
        return boxes
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls = int(parts[0])
            xywh = list(map(float, parts[1:5]))
            boxes.append({'cls': cls, 'box': xywh_to_xyxy(xywh, img_w, img_h), 'matched': False})
    return boxes


def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)


def plot_and_save_confusion(cm_counts, out_dir: Path, model_name: str, split: str):
    """Custom confusion plotting: diagonal cells filled blue with white text, off-diagonals white with black text.
    Rows are PREDICTED classes, columns are ACTUAL classes (this is the detection convention used here).
    Saved figures will have:
      - Y-axis: label 'Predicted' (vertical), tick labels vertical
      - X-axis: label 'Actual' (horizontal), tick labels horizontal
      - Colorbar label (if shown) vertical
    This variant shows ONLY raw counts (no percentage annotations).
    """
    ensure_dir(out_dir)

    # Explicit mapping for this binary problem (predicted row, actual column)
    # row 0 = predicted: target, row 1 = predicted: background
    # col 0 = actual: target, col 1 = actual: background
    # Replace with your class names as needed
    pred_names = ['prediction: Redbanded stink bug', 'prediction: background']
    actual_names = ['actual: Redbanded stink bug', 'actual: background']

    # --- Raw counts panel ---
    fig, ax = plt.subplots(figsize=(6,5), dpi=300)
    ax.set_xlim(0,2); ax.set_ylim(0,2)
    ax.invert_yaxis()

    # Draw 2x2 cells with diagonal blue
    diag_color = '#1f77b4'  # blue
    off_color = '#ffffff'   # white
    edge_color = 'black'

    for i in range(2):
        for j in range(2):
            face = diag_color if i == j else off_color
            rect = patches.Rectangle((j, i), 1, 1, facecolor=face, edgecolor=edge_color, linewidth=2)
            ax.add_patch(rect)
            # annotation: count
            try:
                count = int(cm_counts[i, j])
            except Exception:
                count = 0
            txt_color = 'white' if i == j else 'black'
            ax.text(j + 0.5, i + 0.5, f"{count}", ha='center', va='center', color=txt_color, fontsize=28, fontweight='bold')

    # Set ticks: columns are ACTUAL, rows are PREDICTED
    ax.set_xticks([0.5, 1.5])
    # x tick text horizontally (rotation=0)
    ax.set_xticklabels([n.replace('actual: ', '') for n in actual_names], fontsize=14, rotation=0, ha='center', va='top')
    ax.set_yticks([0.5, 1.5])
    # y tick text vertically (rotation=90)
    ax.set_yticklabels([n.replace('prediction: ', '') for n in pred_names], fontsize=14, rotation=90, ha='center', va='center')

    # Axis labels with requested orientations
    ax.set_xlabel('Actual', fontsize=14, rotation=0, labelpad=12)
    ax.set_ylabel('Predicted', fontsize=14, rotation=90, labelpad=12)

    ax.set_title(f'Confusion matrix', fontsize=16)
    plt.tight_layout()
    fig_path_png = out_dir / 'confusion_matrix_counts.png'
    fig_path_pdf = out_dir / 'confusion_matrix_counts.pdf'
    fig.savefig(str(fig_path_png))
    fig.savefig(str(fig_path_pdf))
    plt.close(fig)

    # --- Second panel: counts-only (larger text) ---
    fig, ax = plt.subplots(figsize=(6,5), dpi=300)
    ax.set_xlim(0,2); ax.set_ylim(0,2)
    ax.invert_yaxis()

    for i in range(2):
        for j in range(2):
            face = diag_color if i == j else off_color
            rect = patches.Rectangle((j, i), 1, 1, facecolor=face, edgecolor=edge_color, linewidth=2)
            ax.add_patch(rect)
            try:
                count = int(cm_counts[i, j])
            except Exception:
                count = 0
            txt_color = 'white' if i == j else 'black'
            # annotate count
            ax.text(j + 0.5, i + 0.5, f"{count}", ha='center', va='center', color=txt_color, fontsize=32, fontweight='bold')

    ax.set_xticks([0.5, 1.5])
    ax.set_xticklabels([n.replace('actual: ', '') for n in actual_names], fontsize=14, rotation=0, ha='center', va='top')
    ax.set_yticks([0.5, 1.5])
    ax.set_yticklabels([n.replace('prediction: ', '') for n in pred_names], fontsize=14, rotation=90, ha='center', va='center')

    ax.set_xlabel('Actual', fontsize=14, rotation=0, labelpad=12)
    ax.set_ylabel('Predicted', fontsize=14, rotation=90, labelpad=12)

    ax.set_title(f'Confusion matrix (counts) ({model_name} - {split})', fontsize=16)
    plt.tight_layout()
    fig_path_png = out_dir / 'confusion_matrix_normalized_row_annotated.png'
    fig_path_pdf = out_dir / 'confusion_matrix_normalized_row_annotated.pdf'
    fig.savefig(str(fig_path_png))
    fig.savefig(str(fig_path_pdf))
    plt.close(fig)


def evaluate_model_on_split(model_path: Path, split: str, max_images=None):
    # split: 'test' or 'valid' (data uses 'val' naming in data.yaml; folder is 'valid' in this project)
    split_folder = 'test' if split == 'test' else 'valid'
    imgs_dir = data_root / split_folder / 'images'
    labels_dir = data_root / split_folder / 'labels'

    if not imgs_dir.exists():
        print(f"Images directory for split '{split}' not found: {imgs_dir}")
        return

    model = YOLO(str(model_path))
    images = sorted([p for p in imgs_dir.iterdir() if p.suffix.lower() in IMAGE_EXTS])
    if max_images:
        images = images[:max_images]

    all_confidences = []
    all_labels = []
    TP = FP = FN = 0
    detection_counts = []

    for img_p in tqdm(images, desc=f"{model_path.name} - {split}"):
        img = Image.open(img_p)
        img_w, img_h = img.size
        label_file = labels_dir / (img_p.stem + '.txt')
        gt_boxes = read_gt_labels(label_file, img_w, img_h)

        # run inference - get predictions as boxes with confidences
        results = model.predict(source=str(img_p), conf=CONF_THRESH, imgsz=640, verbose=False)
        res = results[0]
        preds = []
        if hasattr(res, 'boxes') and res.boxes is not None:
            for box in res.boxes:
                # box.xyxy, box.conf, box.cls
                xyxy = box.xyxy.cpu().numpy().tolist() if hasattr(box.xyxy, 'cpu') else box.xyxy.tolist()
                if isinstance(xyxy, list) and len(xyxy) == 1 and isinstance(xyxy[0], (list, tuple)):
                    xyxy = xyxy[0]
                if not (isinstance(xyxy, (list, tuple)) and len(xyxy) == 4):
                    continue
                xyxy = [float(x) for x in xyxy]
                conf = float(box.conf.cpu().numpy()) if hasattr(box.conf, 'cpu') else float(box.conf)
                cls = int(box.cls.cpu().numpy()) if hasattr(box.cls, 'cpu') else int(box.cls)
                preds.append({'cls': cls, 'box': xyxy, 'conf': conf})

        preds = sorted(preds, key=lambda x: x['conf'], reverse=True)
        detection_counts.append(len(preds))

        for p in preds:
            matched = False
            for gt in gt_boxes:
                if gt['matched']:
                    continue
                if gt['cls'] != p['cls']:
                    continue
                if iou(p['box'], gt['box']) >= IOU_THRESH:
                    TP += 1
                    gt['matched'] = True
                    matched = True
                    all_confidences.append(p['conf'])
                    all_labels.append(1)
                    break
            if not matched:
                FP += 1
                all_confidences.append(p['conf'])
                all_labels.append(0)

        for gt in gt_boxes:
            if not gt['matched']:
                FN += 1

    # confusion matrix: [[TP, FN],[FP, TN]] ; TN set to 0 in detection context
    cm = np.array([[TP, FN], [FP, 0]])

    # output dir
    out_dir = output_base / model_path.stem / split
    ensure_dir(out_dir)

    # Save improved confusion matrices using our custom helper (counts-only)
    try:
        plot_and_save_confusion(cm, out_dir, model_path.stem, split)
    except Exception as e:
        print('Failed to plot with custom helper, falling back to matplotlib-only plots:', e)
        plt.figure(figsize=(5,4))
        plt.imshow(cm, cmap='Blues')
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, int(cm[i, j]), ha='center', va='center', color='black')
        # make y-axis tick labels vertical in fallback as well
        ax = plt.gca()
        ax.set_xticks([0, 1])
        ax.set_xticklabels(['actual: Redbanded stink bug', 'actual: background'], rotation=0)
        ax.set_yticks([0, 1])
        ax.set_yticklabels(['prediction: Redbanded stink bug', 'prediction: background'], rotation=90, ha='center', va='center')
        plt.xlabel('Actual')
        plt.ylabel('Predicted')
        plt.title(f'Confusion matrix')
        plt.tight_layout()
        plt.savefig(out_dir / 'confusion_matrix_counts.png')
        plt.close()

    # PR curve
    if len(all_confidences) > 0:
        precisions, recalls, thresholds = precision_recall_curve(all_labels, all_confidences)
        plt.figure()
        plt.plot(recalls, precisions, marker='.')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title(f'Precision-Recall curve ({model_path.stem} - {split})')
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(out_dir / 'pr_curve.png')
        plt.close()

        thr_plot = np.concatenate(([0.0], thresholds))
        prec_plot = precisions
        rec_plot = recalls
        plt.figure()
        plt.plot(thr_plot, prec_plot, label='Precision')
        plt.plot(thr_plot, rec_plot, label='Recall')
        plt.xlabel('Confidence threshold (approx)')
        plt.ylabel('Score')
        plt.title(f'Precision/Recall vs threshold ({model_path.stem} - {split})')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(out_dir / 'precision_recall_vs_threshold.png')
        plt.close()

    # detection count histogram
    plt.figure()
    plt.hist(detection_counts, bins=range(0, max(detection_counts) + 2 if detection_counts else 2), color='tab:blue', alpha=0.8)
    plt.xlabel('Number of detections (per image)')
    plt.ylabel('Image count')
    plt.title(f'Detection counts histogram ({model_path.stem} - {split})')
    plt.tight_layout()
    plt.savefig(out_dir / 'detection_counts_histogram.png')
    plt.close()

    # write summary
    total_images = len(images)
    precision_approx = TP / (TP + FP) if (TP + FP) > 0 else 0.0
    recall_approx = TP / (TP + FN) if (TP + FN) > 0 else 0.0
    with open(out_dir / 'summary.txt', 'w') as f:
        f.write(f'Model: {model_path.name}\n')
        f.write(f'Split: {split}\n')
        f.write(f'Images evaluated: {total_images}\n')
        f.write(f'TP: {TP}\n')
        f.write(f'FP: {FP}\n')
        f.write(f'FN: {FN}\n')
        f.write(f'Precision (approx): {precision_approx:.4f}\n')
        f.write(f'Recall (approx): {recall_approx:.4f}\n')

    print(f'Evaluation outputs saved to: {out_dir} (images: {total_images})')


# Main orchestration: iterate models and splits
model_files = sorted([p for p in models_dir.iterdir() if p.suffix == '.pt'])
if not model_files:
    raise RuntimeError(f'No .pt models found in {models_dir}')

splits = ['val', 'test']  # user asked for both validation and test; our folders are 'valid' and 'test'
# map 'val' to 'valid' internally in evaluate function

for m in model_files:
    for s in splits:
        evaluate_model_on_split(m, s)

print('\nAll evaluations finished. Check the evaluation_outputs_of_1008 folder for results.')
# Out:
# yolov8l_best.pt - val:   0%|          | 0/151 [00:00<?, ?it/s]C:\Users\SauravUpadhyaya\AppData\Local\Temp\ipykernel_23140\1604179396.py:210: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   conf = float(box.conf.cpu().numpy()) if hasattr(box.conf, 'cpu') else float(box.conf)
# C:\Users\SauravUpadhyaya\AppData\Local\Temp\ipykernel_23140\1604179396.py:211: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cls = int(box.cls.cpu().numpy()) if hasattr(box.cls, 'cpu') else int(box.cls)
# yolov8l_best.pt - val: 100%|██████████| 151/151 [00:10<00:00, 15.08it/s]
# ...

# %%
# Concise parser: prints per-epoch train/val losses from Ultralytics metrics CSV for YOLOv8s
import os, glob, csv

def print_epoch_losses(run_dir):
    run_dir = os.path.normpath(run_dir)
    candidates = [os.path.join(run_dir, 'metrics.csv'), os.path.join(run_dir, 'results.csv')] + glob.glob(os.path.join(run_dir, '*.csv'))
    csv_path = next((p for p in candidates if os.path.exists(p)), None)
    if not csv_path:
        print(f'No CSV metrics found in {run_dir}')
        return
    with open(csv_path, newline='') as f:
        reader = csv.DictReader(f)
        rows = list(reader)
        hdrs = reader.fieldnames or []
    if not rows:
        print(f'Found CSV at {csv_path} but it has no rows')
        return
    # common column name heuristics (kept minimal)
    epoch_col = next((h for h in hdrs if h.lower() in ('epoch', 'ep')), None)
    train_col = next((h for h in hdrs if 'train' in h.lower() and 'loss' in h.lower()), None) or next((h for h in hdrs if h.lower() == 'loss'), None)
    val_col = next((h for h in hdrs if ('val' in h.lower() or 'valid' in h.lower()) and 'loss' in h.lower()), None) or next((h for h in hdrs if 'val' in h.lower()), None)

    for i, row in enumerate(rows, start=1):
        e = row.get(epoch_col) if epoch_col else i
        try:
            e = int(float(e))
        except Exception:
            e = i
        train_loss = float(row.get(train_col, 0.0)) if train_col else 0.0
        valid_loss = float(row.get(val_col, 0.0)) if val_col else 0.0
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(e, train_loss, valid_loss))

# Usage: change the path below to your run folder if needed
print_epoch_losses('model_outputsof_1008_images/yolov8s')
# Out:
# Epoch: 1 	Training Loss: 1.362260 	Validation Loss: 1.058390
# Epoch: 2 	Training Loss: 0.972630 	Validation Loss: 1.190910
# Epoch: 3 	Training Loss: 0.967250 	Validation Loss: 0.927180
# Epoch: 4 	Training Loss: 0.941720 	Validation Loss: 0.871060
# Epoch: 5 	Training Loss: 0.991620 	Validation Loss: 1.218400
# Epoch: 6 	Training Loss: 0.943630 	Validation Loss: 0.819550
# Epoch: 7 	Training Loss: 0.917890 	Validation Loss: 0.880010
# Epoch: 8 	Training Loss: 0.901480 	Validation Loss: 0.828700
# Epoch: 9 	Training Loss: 0.860410 	Validation Loss: 0.808240
# Epoch: 10 	Training Loss: 0.874760 	Validation Loss: 0.821250
# Epoch: 11 	Training Loss: 0.833800 	Validation Loss: 0.776390
# Epoch: 12 	Training Loss: 0.858580 	Validation Loss: 0.878090
# Epoch: 13 	Training Loss: 0.849690 	Validation Loss: 0.800130
# Epoch: 14 	Training Loss: 0.805140 	Validation Loss: 0.829010
# Epoch: 15 	Training Loss: 0.836230 	Validation Loss: 0.776560
# ...

# %%
# Plot training and validation loss vs epoch from Ultralytics metrics CSV
import os, glob, csv
import matplotlib.pyplot as plt


def plot_epoch_losses(run_dir, show=True, save_path=None):
    run_dir = os.path.normpath(run_dir)
    candidates = [os.path.join(run_dir, 'metrics.csv'), os.path.join(run_dir, 'results.csv')] + glob.glob(os.path.join(run_dir, '*.csv'))
    csv_path = next((p for p in candidates if os.path.exists(p)), None)
    if not csv_path:
        print(f'No CSV metrics found in {run_dir}')
        return
    epochs, train_losses, val_losses = [], [], []
    with open(csv_path, newline='') as f:
        reader = csv.DictReader(f)
        hdrs = reader.fieldnames or []
        epoch_col = next((h for h in hdrs if h.lower() in ('epoch', 'ep')), None)
        train_col = next((h for h in hdrs if 'train' in h.lower() and 'loss' in h.lower()), None) or next((h for h in hdrs if h.lower() == 'loss'), None)
        val_col = next((h for h in hdrs if ('val' in h.lower() or 'valid' in h.lower()) and 'loss' in h.lower()), None) or next((h for h in hdrs if 'val' in h.lower()), None)
        for i, row in enumerate(reader, start=1):
            e = row.get(epoch_col) if epoch_col else i
            try:
                e = int(float(e))
            except Exception:
                e = i
            epochs.append(e)
            train_losses.append(float(row.get(train_col, 0.0)) if train_col else 0.0)
            val_losses.append(float(row.get(val_col, 0.0)) if val_col else 0.0)

    plt.figure(figsize=(8,5))
    plt.plot(epochs, train_losses, label='Train Loss', marker='o')
    plt.plot(epochs, val_losses, label='Val Loss', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
        print(f'Plot saved to {save_path}')
    if show:
        plt.show()


# Usage: change run_dir if needed
plot_epoch_losses('model_outputsof_1008_images/yolov8s')

# %% [markdown]
# The training loss consistently decreases, indicating that the model is effectively learning the patterns in the training data and improving its performance on that data. The validation loss also decreases initially, but it fluctuates significantly and is consistently higher than the training loss after the first few epochs
#
# The gap between the training loss and validation loss, known as the "generalization gap," is a key indicator of model performance. The fact that the training loss continues to decrease while the validation loss is consistently higher and fluctuates indicates that the model may be overfitting
#
# Overfitting occurs when a model learns the training data too well, including noise and specific details, and loses its ability to generalize to new, unseen data. While a small generalization gap is normal, a large and increasing gap suggests that the model is "memorizing" the training data rather than learning general features.
# The validation loss has a noisy or erratic pattern, which could be a sign of issues like a high learning rate or noisy data. The training loss, however, is much smoother and more consistent
#
# Areas for Improvement
# To address the potential overfitting and improve the model's performance on unseen data, the following improvements could be necessary:
# Regularization: The model could be simplified or regularized to reduce its complexity. Techniques such as adding dropout layers or using L2 normalization can help prevent the model from becoming too reliant on the training data.
# Early Stopping: Since the validation loss stops improving and fluctuates after a certain point, a technique called "early stopping" could be used to halt the training process before the model begins to overfit. This would involve stopping training when the validation loss stops decreasing for a specified number of epochs.
# Data Augmentation: Increasing the amount of training data or using data augmentation techniques can help the model learn more robust patterns and improve its ability to generalize.
# Learning Rate Adjustment: An erratic or unstable learning curve can be caused by a high learning rate. Reducing the learning rate or using an adaptive learning rate scheduler might lead to a smoother and more stable training process

# %%
# Concise parser: prints per-epoch train/val losses from Ultralytics metrics CSV for YOLOv8m
import os, glob, csv


def print_epoch_losses(run_dir):
    run_dir = os.path.normpath(run_dir)
    candidates = [os.path.join(run_dir, 'metrics.csv'), os.path.join(run_dir, 'results.csv')] + glob.glob(os.path.join(run_dir, '*.csv'))
    csv_path = next((p for p in candidates if os.path.exists(p)), None)
    if not csv_path:
        print(f'No CSV metrics found in {run_dir}')
        return
    with open(csv_path, newline='') as f:
        reader = csv.DictReader(f)
        rows = list(reader)
        hdrs = reader.fieldnames or []
    if not rows:
        print(f'Found CSV at {csv_path} but it has no rows')
        return
    # common column name heuristics (kept minimal)
    epoch_col = next((h for h in hdrs if h.lower() in ('epoch', 'ep')), None)
    train_col = next((h for h in hdrs if 'train' in h.lower() and 'loss' in h.lower()), None) or next((h for h in hdrs if h.lower() == 'loss'), None)
    val_col = next((h for h in hdrs if ('val' in h.lower() or 'valid' in h.lower()) and 'loss' in h.lower()), None) or next((h for h in hdrs if 'val' in h.lower()), None)

    for i, row in enumerate(rows, start=1):
        e = row.get(epoch_col) if epoch_col else i
        try:
            e = int(float(e))
        except Exception:
            e = i
        train_loss = float(row.get(train_col, 0.0)) if train_col else 0.0
        valid_loss = float(row.get(val_col, 0.0)) if val_col else 0.0
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(e, train_loss, valid_loss))

# Usage: change the path below to your run folder if needed
print_epoch_losses('model_outputsof_1008_images/yolov8m')
# Out:
# Epoch: 1 	Training Loss: 1.276700 	Validation Loss: 0.962920
# Epoch: 2 	Training Loss: 0.977640 	Validation Loss: 0.985450
# Epoch: 3 	Training Loss: 1.004560 	Validation Loss: 1.239440
# Epoch: 4 	Training Loss: 1.035250 	Validation Loss: nan
# Epoch: 5 	Training Loss: 1.001910 	Validation Loss: nan
# Epoch: 6 	Training Loss: 0.904220 	Validation Loss: 3.911930
# Epoch: 7 	Training Loss: 0.920160 	Validation Loss: 1.124340
# Epoch: 8 	Training Loss: 0.895660 	Validation Loss: 0.997450
# Epoch: 9 	Training Loss: 0.863130 	Validation Loss: 0.881500
# Epoch: 10 	Training Loss: 0.856750 	Validation Loss: 1.031840
# Epoch: 11 	Training Loss: 0.873350 	Validation Loss: 0.948990
# Epoch: 12 	Training Loss: 0.865770 	Validation Loss: 0.867030
# Epoch: 13 	Training Loss: 0.862540 	Validation Loss: 0.847880
# Epoch: 14 	Training Loss: 0.844210 	Validation Loss: 0.789620
# Epoch: 15 	Training Loss: 0.829840 	Validation Loss: 0.792760
# ...

# %%
# Plot training and validation loss vs epoch from Ultralytics metrics CSV
import os, glob, csv
import matplotlib.pyplot as plt


def plot_epoch_losses(run_dir, show=True, save_path=None):
    run_dir = os.path.normpath(run_dir)
    candidates = [os.path.join(run_dir, 'metrics.csv'), os.path.join(run_dir, 'results.csv')] + glob.glob(os.path.join(run_dir, '*.csv'))
    csv_path = next((p for p in candidates if os.path.exists(p)), None)
    if not csv_path:
        print(f'No CSV metrics found in {run_dir}')
        return
    epochs, train_losses, val_losses = [], [], []
    with open(csv_path, newline='') as f:
        reader = csv.DictReader(f)
        hdrs = reader.fieldnames or []
        epoch_col = next((h for h in hdrs if h.lower() in ('epoch', 'ep')), None)
        train_col = next((h for h in hdrs if 'train' in h.lower() and 'loss' in h.lower()), None) or next((h for h in hdrs if h.lower() == 'loss'), None)
        val_col = next((h for h in hdrs if ('val' in h.lower() or 'valid' in h.lower()) and 'loss' in h.lower()), None) or next((h for h in hdrs if 'val' in h.lower()), None)
        for i, row in enumerate(reader, start=1):
            e = row.get(epoch_col) if epoch_col else i
            try:
                e = int(float(e))
            except Exception:
                e = i
            epochs.append(e)
            train_losses.append(float(row.get(train_col, 0.0)) if train_col else 0.0)
            val_losses.append(float(row.get(val_col, 0.0)) if val_col else 0.0)

    plt.figure(figsize=(8,5))
    plt.plot(epochs, train_losses, label='Train Loss', marker='o')
    plt.plot(epochs, val_losses, label='Val Loss', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
        print(f'Plot saved to {save_path}')
    if show:
        plt.show()


# Usage: change run_dir if needed
plot_epoch_losses('model_outputsof_1008_images/yolov8m')

# %% [markdown]
# The graph displays the training loss (blue line) and validation loss (orange line) over 50 epochs. Both losses initially decrease, indicating that the model is learning. The training loss becomes relatively stable and low, while the validation loss also decreases and stabilizes, but with noticeable fluctuations.
# Interpretation of Performance
# This model shows signs of having a more stable and better-generalized performance compared to the previous model. The training and validation loss curves follow a similar downward trend and eventually stabilize around a similar value. This indicates that the model is not overfitting and is learning to generalize to unseen data effectively. The final loss values for both training and validation are close, which is a good sign of a well-fitted model.
# The initial spike in the validation loss (around epoch 5) could be due to a number of factors, such as a high learning rate or an initial instability in the training process. However, the model recovers quickly, and both curves continue to decrease in sync.
# The validation loss has some minor fluctuations throughout the training, which can be normal. This could be a result of a weighted loss function, which can be used for imbalanced datasets, or due to random sampling of the validation set.
# Areas for Improvement
# The model has a relatively good fit, but there are still potential areas for improvement, especially if a lower final loss is desired:
# Tuning Hyperparameters: The learning rate could be adjusted to potentially achieve a smoother loss curve and a slightly lower final loss.
# Early Stopping: Although the model's performance seems to have stabilized, implementing an early stopping strategy would prevent the model from continuing to train unnecessarily, saving computational resources.
# Cross-Validation: To ensure the model's robustness and to confirm that the split of the data is not introducing any bias, techniques like k-fold cross-validation could be used. This would help to get a more reliable average loss for the model

# %%
# Plot training and validation loss vs epoch from Ultralytics metrics CSV
import os, glob, csv
import matplotlib.pyplot as plt


def plot_epoch_losses(run_dir, show=True, save_path=None):
    run_dir = os.path.normpath(run_dir)
    candidates = [os.path.join(run_dir, 'metrics.csv'), os.path.join(run_dir, 'results.csv')] + glob.glob(os.path.join(run_dir, '*.csv'))
    csv_path = next((p for p in candidates if os.path.exists(p)), None)
    if not csv_path:
        print(f'No CSV metrics found in {run_dir}')
        return
    epochs, train_losses, val_losses = [], [], []
    with open(csv_path, newline='') as f:
        reader = csv.DictReader(f)
        hdrs = reader.fieldnames or []
        epoch_col = next((h for h in hdrs if h.lower() in ('epoch', 'ep')), None)
        train_col = next((h for h in hdrs if 'train' in h.lower() and 'loss' in h.lower()), None) or next((h for h in hdrs if h.lower() == 'loss'), None)
        val_col = next((h for h in hdrs if ('val' in h.lower() or 'valid' in h.lower()) and 'loss' in h.lower()), None) or next((h for h in hdrs if 'val' in h.lower()), None)
        for i, row in enumerate(reader, start=1):
            e = row.get(epoch_col) if epoch_col else i
            try:
                e = int(float(e))
            except Exception:
                e = i
            epochs.append(e)
            train_losses.append(float(row.get(train_col, 0.0)) if train_col else 0.0)
            val_losses.append(float(row.get(val_col, 0.0)) if val_col else 0.0)

    plt.figure(figsize=(8,5))
    plt.plot(epochs, train_losses, label='Train Loss', marker='o')
    plt.plot(epochs, val_losses, label='Val Loss', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
        print(f'Plot saved to {save_path}')
    if show:
        plt.show()


# Usage: change run_dir if needed
plot_epoch_losses('runs/detect/train4')

# %%
# Checking if the best model is working fine on some random images
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/test/images"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('bd76.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
results = model.predict(source=image_paths, conf=0.5, iou = 0.3)

for i, result in enumerate(results):
    # Get image with boxes
    img_with_boxes = result.plot()
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (40, 40),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            1,        # Font scale
            (0, 0, 250), # Color (red)
            2)  
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
    plt.show()
# Out:
# 0: 640x640 13 stinkbugs, 82.2ms
# Speed: 5.7ms preprocess, 82.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
# AdltStnkBug_332_5500_jpg.rf.78f1dfb1127de8f4d463787e8403bd76.jpg: 13 Stinkbug detected

# %%
# Checking if the best model is working fine on some random images
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/test/images"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('bd76.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
results = model.predict(source=image_paths, conf=0.8)

for i, result in enumerate(results):
    # Get image with boxes
    img_with_boxes = result.plot()
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (40, 40),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            1,        # Font scale
            (0, 0, 250), # Color (red)
            2)  
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
    plt.show()
# Out:
# 0: 640x640 11 stinkbugs, 68.6ms
# Speed: 5.0ms preprocess, 68.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# AdltStnkBug_332_5500_jpg.rf.78f1dfb1127de8f4d463787e8403bd76.jpg: 11 Stinkbug detected

# %%
# Checking if the best model is working fine on some random images
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/test/images"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('bd76.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
# model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
model = YOLO('./yolov8m_cbam_asff_finetuned.pt')
results = model.predict(source=image_paths, conf=0.5)

for i, result in enumerate(results):
    # Get image with boxes
    img_with_boxes = result.plot()
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (40, 40),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            1,        # Font scale
            (0, 0, 250), # Color (red)
            2)  
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
    plt.show()
# Out:
# 0: 640x640 13 stinkbugs, 7.8ms
# Speed: 9.7ms preprocess, 7.8ms inference, 194.4ms postprocess per image at shape (1, 3, 640, 640)
# AdltStnkBug_332_5500_jpg.rf.78f1dfb1127de8f4d463787e8403bd76.jpg: 13 Stinkbug detected

# %%
# Checking if the best model is working fine on some random images
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/forpaper/3500"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
# model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
model = YOLO('./yolov8m_cbam_asff_finetuned.pt')
results = model.predict(source=image_paths, conf=0.5)
print(results)
# Out:
# 0: 448x640 15 stinkbugs, 35.7ms
# 1: 448x640 13 stinkbugs, 35.7ms
# 2: 448x640 13 stinkbugs, 35.7ms
# 3: 448x640 13 stinkbugs, 35.7ms
# 4: 448x640 13 stinkbugs, 35.7ms
# 5: 448x640 13 stinkbugs, 35.7ms
# Speed: 2.8ms preprocess, 35.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'stinkbug'}
# obb: None
# orig_img: array([[[162, 186, 208],
#         [163, 187, 209],
#         [163, 186, 208],
#         ...,
#         [159, 183, 205],
#         [160, 184, 208],
#         [162, 186, 210]],
#
#        [[163, 186, 208],
#         [164, 187, 209],
#         [164, 187, 209],
#         ...,
#         [159, 183, 207],
#         [159, 183, 207],
#         [159, 183, 207]],
#
#        [[164, 187, 209],
#         [164, 187, 209],
#         [165, 188, 210],
#         ...,
#         [160, 184, 208],
# ...

# %%
# getting images for paper


# Checking if the best model is working fine on some random images
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/forpaper/4500"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
# model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
model = YOLO('./yolov8m_cbam_asff_finetuned.pt')
results = model.predict(source=image_paths, conf=0.5)

for i, result in enumerate(results):
    # Get image with boxes
    img_with_boxes = result.plot(labels=False)
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (600, 600),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            10,        # Font scale
            (0, 0, 250), # Color (red)
            10)  
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

    # Plot
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis("off")
#     plt.title(f"Image {i+1}: {os.path.basename(image_paths[i])}")
    plt.show()
# Out:
# 0: 448x640 15 stinkbugs, 34.7ms
# 1: 448x640 13 stinkbugs, 34.7ms
# 2: 448x640 13 stinkbugs, 34.7ms
# 3: 448x640 13 stinkbugs, 34.7ms
# 4: 448x640 14 stinkbugs, 34.7ms
# 5: 448x640 13 stinkbugs, 34.7ms
# Speed: 2.9ms preprocess, 34.7ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# AdltStnkBug_319_4500.jpg: 15 Stinkbug detected
# AdltStnkBug_330_4500.jpg: 13 Stinkbug detected
# AdltStnkBug_332_4500.jpg: 13 Stinkbug detected
# AdltStnkBug_333_4500.jpg: 13 Stinkbug detected
# AdltStnkBug_334_4500.jpg: 14 Stinkbug detected
# AdltStnkBug_336_4500.jpg: 13 Stinkbug detected

# %%
processed_images = []
for i, result in enumerate(results):
    img_with_boxes = result.plot(labels=False, conf=False)
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (600, 600),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            10,        # Font scale
            (0, 0, 0), # Color (red)
            30) 
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB and add to list
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
    processed_images.append(img_rgb)

# --- Plotting the grid ---

ROWS = 2
COLS = 3
# Limit the number of images displayed to the grid size
images_to_display = processed_images[:ROWS * COLS]
num_images = len(images_to_display)

if num_images > 0:
    # Create the figure and subplots
    fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS * 4, ROWS * 4))
    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    for j, img in enumerate(images_to_display):
        ax = axes[j]
        ax.imshow(img)
        ax.axis("off")

    plt.subplots_adjust(hspace=0, wspace=5) 
    for k in range(j + 1, ROWS * COLS):
        fig.delaxes(axes[k])

    plt.tight_layout()
    plt.show()
else:
    print("No images processed to display.")
# Out:
# AdltStnkBug_319_3500.jpg: 15 Stinkbug detected
# AdltStnkBug_330_3500.jpg: 13 Stinkbug detected
# AdltStnkBug_332_3500.jpg: 13 Stinkbug detected
# AdltStnkBug_333_3500.jpg: 13 Stinkbug detected
# AdltStnkBug_334_3500.jpg: 13 Stinkbug detected
# AdltStnkBug_336_3500.jpg: 13 Stinkbug detected

# %%
# for 4500
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/forpaper/4500"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
# model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
model = YOLO('./yolov8m_cbam_asff_finetuned.pt')
results = model.predict(source=image_paths, conf=0.5)

processed_images = []
for i, result in enumerate(results):
    img_with_boxes = result.plot(labels=False, conf=False)
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (600, 600),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            10,        # Font scale
            (0, 0, 0), # Color (red)
            30) 
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB and add to list
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
    processed_images.append(img_rgb)

# --- Plotting the grid ---

ROWS = 2
COLS = 3
# Limit the number of images displayed to the grid size
images_to_display = processed_images[:ROWS * COLS]
num_images = len(images_to_display)

if num_images > 0:
    # Create the figure and subplots
    fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS * 4, ROWS * 4))
    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    for j, img in enumerate(images_to_display):
        ax = axes[j]
        ax.imshow(img)
        ax.axis("off")

    plt.subplots_adjust(hspace=0, wspace=5) 
    for k in range(j + 1, ROWS * COLS):
        fig.delaxes(axes[k])

    plt.tight_layout()
    plt.show()
else:
    print("No images processed to display.")
# Out:
# 0: 448x640 15 stinkbugs, 28.2ms
# 1: 448x640 13 stinkbugs, 28.2ms
# 2: 448x640 13 stinkbugs, 28.2ms
# 3: 448x640 13 stinkbugs, 28.2ms
# 4: 448x640 14 stinkbugs, 28.2ms
# 5: 448x640 13 stinkbugs, 28.2ms
# Speed: 5.9ms preprocess, 28.2ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# AdltStnkBug_319_4500.jpg: 15 Stinkbug detected
# AdltStnkBug_330_4500.jpg: 13 Stinkbug detected
# AdltStnkBug_332_4500.jpg: 13 Stinkbug detected
# AdltStnkBug_333_4500.jpg: 13 Stinkbug detected
# AdltStnkBug_334_4500.jpg: 14 Stinkbug detected
# AdltStnkBug_336_4500.jpg: 13 Stinkbug detected

# %%
#for 5500
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/forpaper/5500"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
# model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
model = YOLO('./yolov8m_cbam_asff_finetuned.pt')
results = model.predict(source=image_paths, conf=0.5)

processed_images = []
for i, result in enumerate(results):
    img_with_boxes = result.plot(labels=False, conf=False)
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (600, 600),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            10,        # Font scale
            (0, 0, 0), # Color (red)
            30) 
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB and add to list
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
    processed_images.append(img_rgb)

# --- Plotting the grid ---

ROWS = 2
COLS = 3
# Limit the number of images displayed to the grid size
images_to_display = processed_images[:ROWS * COLS]
num_images = len(images_to_display)

if num_images > 0:
    # Create the figure and subplots
    fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS * 4, ROWS * 4))
    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    for j, img in enumerate(images_to_display):
        ax = axes[j]
        ax.imshow(img)
        ax.axis("off")

    plt.subplots_adjust(hspace=0, wspace=5) 
    for k in range(j + 1, ROWS * COLS):
        fig.delaxes(axes[k])

    plt.tight_layout()
    plt.show()
else:
    print("No images processed to display.")
# Out:
# 0: 448x640 15 stinkbugs, 30.9ms
# 1: 448x640 13 stinkbugs, 30.9ms
# 2: 448x640 13 stinkbugs, 30.9ms
# 3: 448x640 13 stinkbugs, 30.9ms
# 4: 448x640 13 stinkbugs, 30.9ms
# 5: 448x640 13 stinkbugs, 30.9ms
# Speed: 2.5ms preprocess, 30.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# AdltStnkBug_319_5500.jpg: 15 Stinkbug detected
# AdltStnkBug_330_5500.jpg: 13 Stinkbug detected
# AdltStnkBug_332_5500.jpg: 13 Stinkbug detected
# AdltStnkBug_333_5500.jpg: 13 Stinkbug detected
# AdltStnkBug_334_5500.jpg: 13 Stinkbug detected
# AdltStnkBug_336_5500.jpg: 13 Stinkbug detected

# %%
# for 4500
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2, os

image_folder = "./stinkbug_image_data_third_file/without_Lightings"
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
# model = YOLO('./saved_models/best.pt')
# model = YOLO('./saved_models_of_1008_images/yolov8m_best.pt')
model = YOLO('./yolov8m_cbam_asff_finetuned.pt')
results = model.predict(source=image_paths, conf=0.5)

processed_images = []
for i, result in enumerate(results):
    img_with_boxes = result.plot(labels=False, conf=False)
        
    num_objects = len(result.boxes)
    cv2.putText(img_with_boxes,
            f"Count: {num_objects}",
            (600, 600),  # Position (x, y)
            cv2.FONT_HERSHEY_SIMPLEX,
            10,        # Font scale
            (0, 0, 0), # Color (red)
            30) 
    print(f"{os.path.basename(image_paths[i])}: {num_objects} Stinkbug detected")

    # Convert BGR to RGB and add to list
    img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
    processed_images.append(img_rgb)

# --- Plotting the grid ---

ROWS = 2
COLS = 3
# Limit the number of images displayed to the grid size
images_to_display = processed_images[:ROWS * COLS]
num_images = len(images_to_display)

if num_images > 0:
    # Create the figure and subplots
    fig, axes = plt.subplots(ROWS, COLS, figsize=(COLS * 4, ROWS * 4))
    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    for j, img in enumerate(images_to_display):
        ax = axes[j]
        ax.imshow(img)
        ax.axis("off")

    plt.subplots_adjust(hspace=0, wspace=5) 
    for k in range(j + 1, ROWS * COLS):
        fig.delaxes(axes[k])

    plt.tight_layout()
    plt.show()
else:
    print("No images processed to display.")
# Out:
# 0: 480x640 2 stinkbugs, 22.4ms
# 1: 480x640 5 stinkbugs, 22.4ms
# 2: 480x640 4 stinkbugs, 22.4ms
# 3: 480x640 3 stinkbugs, 22.4ms
# 4: 480x640 4 stinkbugs, 22.4ms
# Speed: 3.2ms preprocess, 22.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# IMG_6301.jpeg: 2 Stinkbug detected
# IMG_6320.jpeg: 5 Stinkbug detected
# IMG_6323.jpeg: 4 Stinkbug detected
# IMG_6324.jpeg: 3 Stinkbug detected
# IMG_6327.jpeg: 4 Stinkbug detected

# %%
# creating confusion matrix plots for test and val splits

import os
from pathlib import Path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, confusion_matrix, ConfusionMatrixDisplay
from tqdm.auto import tqdm
import matplotlib.patches as patches

# try import ultralytics
try:
    from ultralytics import YOLO
except Exception as e:
    raise RuntimeError("ultralytics is required for this cell. Install with: pip install ultralytics")

ROOT = Path('.')
models_dir = ROOT / 'improved_yolov8m_model'
data_root = ROOT / 'stinkbug_image_data_third_file'
output_base = ROOT / 'confusion_graphs'

# configuration
IOU_THRESH = 0.5
CONF_THRESH = 0.25
IMAGE_EXTS = ('.jpg', '.jpeg', '.png')

# helpers

def xywh_to_xyxy(xywh, img_w, img_h):
    x_c, y_c, w, h = xywh
    x1 = (x_c - w / 2.0) * img_w
    y1 = (y_c - h / 2.0) * img_h
    x2 = (x_c + w / 2.0) * img_w
    y2 = (y_c + h / 2.0) * img_h
    return [float(x1), float(y1), float(x2), float(y2)]


def iou(boxA, boxB):
    # boxes: [x1,y1,x2,y2]
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interW = max(0, xB - xA)
    interH = max(0, yB - yA)
    interArea = interW * interH
    boxAArea = max(0, boxA[2] - boxA[0]) * max(0, boxA[3] - boxA[1])
    boxBArea = max(0, boxB[2] - boxB[0]) * max(0, boxB[3] - boxB[1])
    denom = boxAArea + boxBArea - interArea
    if denom <= 0:
        return 0.0
    return interArea / denom


def read_gt_labels(label_path, img_w, img_h):
    boxes = []
    if not label_path.exists():
        return boxes
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls = int(parts[0])
            xywh = list(map(float, parts[1:5]))
            boxes.append({'cls': cls, 'box': xywh_to_xyxy(xywh, img_w, img_h), 'matched': False})
    return boxes


def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)


def plot_and_save_confusion(cm_counts, out_dir: Path, model_name: str, split: str):
    """Custom confusion plotting: diagonal cells filled blue with white text, off-diagonals white with black text.
    Rows are PREDICTED classes, columns are ACTUAL classes (this is the detection convention used here).
    Saved figures will have:
      - Y-axis: label 'Predicted' (vertical), tick labels vertical
      - X-axis: label 'Actual' (horizontal), tick labels horizontal
      - Colorbar label (if shown) vertical
    This variant shows ONLY raw counts (no percentage annotations).
    """
    ensure_dir(out_dir)

    # Explicit mapping for this binary problem (predicted row, actual column)
    # row 0 = predicted: target, row 1 = predicted: background
    # col 0 = actual: target, col 1 = actual: background
    # Replace with your class names as needed
    pred_names = ['prediction: Piezodorus guildinii', 'prediction: background']
    actual_names = ['actual: Piezodorus guildinii', 'actual: background']

    # --- Raw counts panel ---
    fig, ax = plt.subplots(figsize=(6,5), dpi=300)
    ax.set_xlim(0,2); ax.set_ylim(0,2)
    ax.invert_yaxis()

    # Draw 2x2 cells with diagonal blue
    diag_color = '#1f77b4'  # blue
    off_color = '#ffffff'   # white
    edge_color = 'black'

    for i in range(2):
        for j in range(2):
            face = diag_color if i == j else off_color
            rect = patches.Rectangle((j, i), 1, 1, facecolor=face, edgecolor=edge_color, linewidth=2)
            ax.add_patch(rect)
            # annotation: count
            try:
                count = int(cm_counts[i, j])
            except Exception:
                count = 0
            txt_color = 'white' if i == j else 'black'
            ax.text(j + 0.5, i + 0.5, f"{count}", ha='center', va='center', color=txt_color, fontsize=28, fontweight='bold')

    # Set ticks: columns are ACTUAL, rows are PREDICTED
    ax.set_xticks([0.5, 1.5])
    # x tick text horizontally (rotation=0)
    ax.set_xticklabels([n.replace('actual: ', '') for n in actual_names], fontsize=14, rotation=0, ha='center', va='top')
    ax.set_yticks([0.5, 1.5])
    # y tick text vertically (rotation=90)
    ax.set_yticklabels([n.replace('prediction: ', '') for n in pred_names], fontsize=14, rotation=90, ha='center', va='center')

    # Axis labels with requested orientations
    ax.set_xlabel('Actual', fontsize=14, rotation=0, labelpad=12)
    ax.set_ylabel('Predicted', fontsize=14, rotation=90, labelpad=12)

    ax.set_title(f'Confusion matrix', fontsize=16)
    plt.tight_layout()
    fig_path_png = out_dir / 'confusion_matrix_counts.png'
    fig_path_pdf = out_dir / 'confusion_matrix_counts.pdf'
    fig.savefig(str(fig_path_png))
    fig.savefig(str(fig_path_pdf))
    plt.close(fig)

    # --- Second panel: counts-only (larger text) ---
    fig, ax = plt.subplots(figsize=(6,5), dpi=300)
    ax.set_xlim(0,2); ax.set_ylim(0,2)
    ax.invert_yaxis()

    for i in range(2):
        for j in range(2):
            face = diag_color if i == j else off_color
            rect = patches.Rectangle((j, i), 1, 1, facecolor=face, edgecolor=edge_color, linewidth=2)
            ax.add_patch(rect)
            try:
                count = int(cm_counts[i, j])
            except Exception:
                count = 0
            txt_color = 'white' if i == j else 'black'
            # annotate count
            ax.text(j + 0.5, i + 0.5, f"{count}", ha='center', va='center', color=txt_color, fontsize=32, fontweight='bold')

    ax.set_xticks([0.5, 1.5])
    ax.set_xticklabels([n.replace('actual: ', '') for n in actual_names], fontsize=14, rotation=0, ha='center', va='top')
    ax.set_yticks([0.5, 1.5])
    ax.set_yticklabels([n.replace('prediction: ', '') for n in pred_names], fontsize=14, rotation=90, ha='center', va='center')

    ax.set_xlabel('Actual', fontsize=14, rotation=0, labelpad=12)
    ax.set_ylabel('Predicted', fontsize=14, rotation=90, labelpad=12)

    ax.set_title(f'Confusion matrix (counts) ({model_name} - {split})', fontsize=16)
    plt.tight_layout()
    fig_path_png = out_dir / 'confusion_matrix_normalized_row_annotated.png'
    fig_path_pdf = out_dir / 'confusion_matrix_normalized_row_annotated.pdf'
    fig.savefig(str(fig_path_png))
    fig.savefig(str(fig_path_pdf))
    plt.close(fig)


def evaluate_model_on_split(model_path: Path, split: str, max_images=None):
    # split: 'test' or 'valid' (data uses 'val' naming in data.yaml; folder is 'valid' in this project)
    split_folder = 'test' if split == 'test' else 'valid'
    imgs_dir = data_root / split_folder / 'images'
    labels_dir = data_root / split_folder / 'labels'

    if not imgs_dir.exists():
        print(f"Images directory for split '{split}' not found: {imgs_dir}")
        return

    model = YOLO(str(model_path))
    images = sorted([p for p in imgs_dir.iterdir() if p.suffix.lower() in IMAGE_EXTS])
    if max_images:
        images = images[:max_images]

    all_confidences = []
    all_labels = []
    TP = FP = FN = 0
    detection_counts = []

    for img_p in tqdm(images, desc=f"{model_path.name} - {split}"):
        img = Image.open(img_p)
        img_w, img_h = img.size
        label_file = labels_dir / (img_p.stem + '.txt')
        gt_boxes = read_gt_labels(label_file, img_w, img_h)

        # run inference - get predictions as boxes with confidences
        results = model.predict(source=str(img_p), conf=CONF_THRESH, imgsz=640, verbose=False)
        res = results[0]
        preds = []
        if hasattr(res, 'boxes') and res.boxes is not None:
            for box in res.boxes:
                # box.xyxy, box.conf, box.cls
                xyxy = box.xyxy.cpu().numpy().tolist() if hasattr(box.xyxy, 'cpu') else box.xyxy.tolist()
                if isinstance(xyxy, list) and len(xyxy) == 1 and isinstance(xyxy[0], (list, tuple)):
                    xyxy = xyxy[0]
                if not (isinstance(xyxy, (list, tuple)) and len(xyxy) == 4):
                    continue
                xyxy = [float(x) for x in xyxy]
                conf = float(box.conf.cpu().numpy()) if hasattr(box.conf, 'cpu') else float(box.conf)
                cls = int(box.cls.cpu().numpy()) if hasattr(box.cls, 'cpu') else int(box.cls)
                preds.append({'cls': cls, 'box': xyxy, 'conf': conf})

        preds = sorted(preds, key=lambda x: x['conf'], reverse=True)
        detection_counts.append(len(preds))

        for p in preds:
            matched = False
            for gt in gt_boxes:
                if gt['matched']:
                    continue
                if gt['cls'] != p['cls']:
                    continue
                if iou(p['box'], gt['box']) >= IOU_THRESH:
                    TP += 1
                    gt['matched'] = True
                    matched = True
                    all_confidences.append(p['conf'])
                    all_labels.append(1)
                    break
            if not matched:
                FP += 1
                all_confidences.append(p['conf'])
                all_labels.append(0)

        for gt in gt_boxes:
            if not gt['matched']:
                FN += 1

    # confusion matrix: [[TP, FN],[FP, TN]] ; TN set to 0 in detection context
    cm = np.array([[TP, FN], [FP, 0]])

    # output dir
    out_dir = output_base / model_path.stem / split
    ensure_dir(out_dir)

    # Save improved confusion matrices using our custom helper (counts-only)
    try:
        plot_and_save_confusion(cm, out_dir, model_path.stem, split)
    except Exception as e:
        print('Failed to plot with custom helper, falling back to matplotlib-only plots:', e)
        plt.figure(figsize=(5,4))
        plt.imshow(cm, cmap='Blues')
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, int(cm[i, j]), ha='center', va='center', color='black')
        # make y-axis tick labels vertical in fallback as well
        ax = plt.gca()
        ax.set_xticks([0, 1])
        ax.set_xticklabels(['actual: Piezodorus guildinii', 'actual: background'], rotation=0)
        ax.set_yticks([0, 1])
        ax.set_yticklabels(['prediction: Piezodorus guildinii', 'prediction: background'], rotation=90, ha='center', va='center')
        plt.xlabel('Actual')
        plt.ylabel('Predicted')
        plt.title(f'Confusion matrix')
        plt.tight_layout()
        plt.savefig(out_dir / 'confusion_matrix_counts.png')
        plt.close()

    # PR curve
    if len(all_confidences) > 0:
        precisions, recalls, thresholds = precision_recall_curve(all_labels, all_confidences)
        plt.figure()
        plt.plot(recalls, precisions, marker='.')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title(f'Precision-Recall curve ({model_path.stem} - {split})')
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(out_dir / 'pr_curve.png')
        plt.close()

        thr_plot = np.concatenate(([0.0], thresholds))
        prec_plot = precisions
        rec_plot = recalls
        plt.figure()
        plt.plot(thr_plot, prec_plot, label='Precision')
        plt.plot(thr_plot, rec_plot, label='Recall')
        plt.xlabel('Confidence threshold (approx)')
        plt.ylabel('Score')
        plt.title(f'Precision/Recall vs threshold ({model_path.stem} - {split})')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(out_dir / 'precision_recall_vs_threshold.png')
        plt.close()

    # detection count histogram
    plt.figure()
    plt.hist(detection_counts, bins=range(0, max(detection_counts) + 2 if detection_counts else 2), color='tab:blue', alpha=0.8)
    plt.xlabel('Number of detections (per image)')
    plt.ylabel('Image count')
    plt.title(f'Detection counts histogram ({model_path.stem} - {split})')
    plt.tight_layout()
    plt.savefig(out_dir / 'detection_counts_histogram.png')
    plt.close()

    # write summary
    total_images = len(images)
    precision_approx = TP / (TP + FP) if (TP + FP) > 0 else 0.0
    recall_approx = TP / (TP + FN) if (TP + FN) > 0 else 0.0
    with open(out_dir / 'summary.txt', 'w') as f:
        f.write(f'Model: {model_path.name}\n')
        f.write(f'Split: {split}\n')
        f.write(f'Images evaluated: {total_images}\n')
        f.write(f'TP: {TP}\n')
        f.write(f'FP: {FP}\n')
        f.write(f'FN: {FN}\n')
        f.write(f'Precision (approx): {precision_approx:.4f}\n')
        f.write(f'Recall (approx): {recall_approx:.4f}\n')

    print(f'Evaluation outputs saved to: {out_dir} (images: {total_images})')


# Main orchestration: iterate models and splits
model_files = sorted([p for p in models_dir.iterdir() if p.suffix == '.pt'])
if not model_files:
    raise RuntimeError(f'No .pt models found in {models_dir}')

splits = ['val', 'test']  # user asked for both validation and test; our folders are 'valid' and 'test'
# map 'val' to 'valid' internally in evaluate function

for m in model_files:
    for s in splits:
        evaluate_model_on_split(m, s)

print('\nAll evaluations finished. Check the evaluation_outputs_of_1008 folder for results.')
# Out:
# yolov8m_cbam_asff_finetuned.pt - val:   0%|          | 0/151 [00:00<?, ?it/s]C:\Users\SauravUpadhyaya\AppData\Local\Temp\ipykernel_20548\552809760.py:210: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   conf = float(box.conf.cpu().numpy()) if hasattr(box.conf, 'cpu') else float(box.conf)
# C:\Users\SauravUpadhyaya\AppData\Local\Temp\ipykernel_20548\552809760.py:211: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cls = int(box.cls.cpu().numpy()) if hasattr(box.cls, 'cpu') else int(box.cls)
# yolov8m_cbam_asff_finetuned.pt - val: 100%|██████████| 151/151 [00:09<00:00, 16.04it/s]
# ...

# %%
import os
import csv
from ultralytics import YOLO
import cv2

ROOT = Path('.')
# model_dir = "saved_models_of_1008_images"          
# test_images_dir = "./stinkbug_image_data_third_file/test/images"    
# output_root = "./confusion_graphs"  
# metrics_csv = "object_counts.csv"   


model_dir = ROOT / 'improved_yolov8m_model'
test_images_dir = ROOT / 'stinkbug_image_data_third_file/test/images'
output_root = ROOT / 'confusion_graphs'
metrics_csv = ROOT / "object_counts.csv"   




os.makedirs(output_root, exist_ok=True)

# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Save visualization
            result_img = results[0].plot() 

            # Create output dir for this model
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            # Save image
            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f"Saved: {save_path} | Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n All done! Object counts saved to: {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg: 640x640 10 stinkbugs, 8.0ms
# Speed: 4.2ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Saved: confusion_graphs\yolov8m_cbam_asff_finetuned.pt\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg | Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_4500_jpg.rf.5f87dbb22f549c29f663fba864123ea7.jpg: 640x640 10 stinkbugs, 7.8ms
# Speed: 3.6ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Saved: confusion_graphs\yolov8m_cbam_asff_finetuned.pt\AdltStnkBug_003_4500_jpg.rf.5f87dbb22f549c29f663fba864123ea7.jpg | Count: 10 objects
#
# ...

# %%
import os
import csv
from ultralytics import YOLO
import cv2


# Collect all model files
model_files = [f for f in os.listdir(model_dir) if f.endswith(".pt")]
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

# Open CSV to log object counts
with open(metrics_csv, mode="w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    header = ["image"] + [model_file.replace("_best.pt", "") for model_file in model_files]
    writer.writerow(header)

    for image_file in image_files:
        image_path = os.path.join(test_images_dir, image_file)
        row = [image_file]

        for model_file in model_files:
            model_name = model_file.replace("_best.pt", "")
            model_path = os.path.join(model_dir, model_file)
            model = YOLO(model_path)

            # Predict
            results = model.predict(source=image_path, conf=0.25, save=False, imgsz=640)

            # Count number of detections
            preds = results[0].boxes
            num_objects = len(preds)
            row.append(num_objects)

            # Visualized result
            result_img = results[0].plot()  # image with boxes

            # Draw model name and object count on top-left corner
            cv2.putText(
                result_img,
                f"{model_name}: {num_objects} objects",
                org=(10, 40),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=1.0,
                color=(0, 255, 0),
                thickness=2,
                lineType=cv2.LINE_AA
            )

            # Save the image
            model_output_dir = os.path.join(output_root, model_name)
            os.makedirs(model_output_dir, exist_ok=True)

            save_path = os.path.join(model_output_dir, image_file)
            cv2.imwrite(save_path, result_img)

            print(f" Saved: {save_path} | Count: {num_objects} objects")

        writer.writerow(row)

print(f"\n Done! Visuals saved in {output_root}/ and counts in {metrics_csv}")
# Out:
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg: 640x640 10 stinkbugs, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#  Saved: confusion_graphs\yolov8m_cbam_asff_finetuned.pt\AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1b6d9d1ca4691d2.jpg | Count: 10 objects
#
# image 1/1 c:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\images\AdltStnkBug_003_4500_jpg.rf.5f87dbb22f549c29f663fba864123ea7.jpg: 640x640 10 stinkbugs, 8.7ms
# Speed: 4.2ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#  Saved: confusion_graphs\yolov8m_cbam_asff_finetuned.pt\AdltStnkBug_003_4500_jpg.rf.5f87dbb22f549c29f663fba864123ea7.jpg | Count: 10 objects
#
# ...

# %%
def get_counts_from_labels(labels_dir, csv_output_path):
    import os
    import csv

    counts = {}
    for label_file in os.listdir(labels_dir):
        if label_file.endswith(".txt"):
            with open(os.path.join(labels_dir, label_file)) as f:
                counts[label_file.replace('.txt', '.jpg')] = len(f.readlines())
    
    with open(csv_output_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['image', 'true_count'])
        for img, count in counts.items():
            writer.writerow([img, count])
    
    print(f"Saved ground truth counts to {csv_output_path}")

# Usage:
get_counts_from_labels("./stinkbug_image_data_third_file/train/labels", "train_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data_third_file/valid/labels", "val_ground_truth_counts.csv")
get_counts_from_labels("./stinkbug_image_data_third_file/test/labels", "test_ground_truth_counts.csv")
# Out:
# Saved ground truth counts to train_ground_truth_counts.csv
# Saved ground truth counts to val_ground_truth_counts.csv
# Saved ground truth counts to test_ground_truth_counts.csv

# %%
import pandas as pd

# Load ground truth counts CSV
gt_counts = pd.read_csv("test_ground_truth_counts.csv")  

# Load predicted counts CSV
pred_counts = pd.read_csv("object_counts.csv")  
df = pd.merge(gt_counts, pred_counts, on="image")

# %%
df
# Out:
#                                                  image  true_count  \
# 0    AdltStnkBug_003_3500_jpg.rf.24ff33d77ead58c7e1...          10
# 1    AdltStnkBug_003_4500_jpg.rf.5f87dbb22f549c29f6...          10
# 2    AdltStnkBug_006_5500_jpg.rf.c2c34bdc5e17b0ae98...           7
# 3    AdltStnkBug_013_5500_jpg.rf.487e22e297360b9540...           7
# 4    AdltStnkBug_016_4500_jpg.rf.6b13e707920e40450e...          10
# ..                                                 ...         ...
# 146  AdltStnkBug_325_4500_jpg.rf.5e83d82b625e488a74...          15
# 147  AdltStnkBug_329_5500_jpg.rf.69d6715f62dfcabb27...          14
# 148  AdltStnkBug_332_5500_jpg.rf.78f1dfb1127de8f4d4...          13
# 149  AdltStnkBug_334_3500_jpg.rf.88d4b32883c6575e1e...          12
# 150  AdltStnkBug_336_5500_jpg.rf.d6151419b895b22298...          13
#
#      yolov8m_cbam_asff_finetuned.pt
# 0                                10
# 1                                10
# 2                                 7
# ...

# %%
import numpy as np

def calculate_metrics(true_counts, pred_counts):
    N = len(true_counts)
    min_vals = np.minimum(true_counts, pred_counts)
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.sum(min_vals / max_vals) / N

    detection_rate = np.sum(pred_counts >= true_counts) / N
    failed_detection_rate = 1 - detection_rate

    return aca, detection_rate, failed_detection_rate

results = []
for model in pred_counts.columns[1:]: 
    aca, dr, fdr = calculate_metrics(df['true_count'], df[model])
    results.append({
        'model': model,
        'Average Counting Accuracy': aca,
        'Detection Rate': dr,
        'Failed Detection Rate': fdr
    })

metrics_df = pd.DataFrame(results)
print(metrics_df)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
# Out:
#                             model  Average Counting Accuracy  Detection Rate  \
# 0  yolov8m_cbam_asff_finetuned.pt                   0.994069        0.993377
#
#    Failed Detection Rate
# 0               0.006623

# %%
import pandas as pd
import os
from ultralytics import YOLO  
from pathlib import Path 

#model_paths = [f"./saved_models/{f}".replace("\\", "/") for f in os.listdir("saved_models") if f.endswith(".pt")]
ROOT = Path('.')
# model_dir = "saved_models_of_1008_images"          
# test_images_dir = "./stinkbug_image_data_third_file/test/images"    
# output_root = "./confusion_graphs"  
# metrics_csv = "object_counts.csv"   

yaml_file_path = os.path.join(os.getcwd(), 'stinkbug_data.yaml')

model_folder = ROOT / 'improved_yolov8m_model'


for f in os.listdir(model_folder):
    print("best model name :",f)
    print("model path: ", os.path.join(model_folder, f))



model_paths = [os.path.join(model_folder, f) for f in os.listdir(model_folder) if f.endswith(".pt")]
# Folder to save evaluation results
val_output_folder = "val_outputs"

# Store results
results_list = []

for model_path in model_paths:
    print(f"Evaluating model: {model_path}")
    model = YOLO(model_path)

    # Run validation on the test split
    results = model.val(data=yaml_file_path, project=val_output_folder, split="test", name='metrics')


    # Extract metrics
    metrics = results.results_dict  # returns a dict with metrics

    results_list.append({
        "Model": os.path.basename(model_path),
        "mAP50": results.results_dict['metrics/mAP50(B)'],
        "mAP50-95": results.results_dict['metrics/mAP50-95(B)'],
        "Precision": results.results_dict['metrics/precision(B)'],
        "Recall": results.results_dict['metrics/recall(B)'],
    })

# Create DataFrame
df = pd.DataFrame(results_list)

# Show results
print("\nEvaluation Results DataFrame:")
print(df)
# Out:
# best model name : confusion_graphs
# model path:  improved_yolov8m_model\confusion_graphs
# best model name : yolov8m_cbam_asff_finetuned.pt
# model path:  improved_yolov8m_model\yolov8m_cbam_asff_finetuned.pt
# Evaluating model: improved_yolov8m_model\yolov8m_cbam_asff_finetuned.pt
# Ultralytics 8.3.179  Python-3.12.8 torch-2.7.1+cu128 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20474MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 636.9116.4 MB/s, size: 411.9 KB)
# val: Scanning C:\Users\SauravUpadhyaya\Desktop\Stinkbug-Project-Github\Stinkbug-Project\stinkbug_image_data_third_file\test\labels.cache... 151 images, 0 backgrounds, 0 corrupt: 100%|██████████| 151/151 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.24it/s]
# ...

# %%
import pandas as pd
import numpy as np

def calculate_counting_metrics(true_counts, pred_counts):
    """Compute ACA, MAE, DR, and FDR between predicted and true counts."""
    true_counts = np.array(true_counts)
    pred_counts = np.array(pred_counts)

    # Avoid divide by zero
    max_vals = np.maximum(true_counts, pred_counts)
    aca = np.mean(np.where(max_vals == 0, 1, np.minimum(true_counts, pred_counts) / max_vals))
    mae = np.mean(np.abs(true_counts - pred_counts))
    dr = np.mean(pred_counts >= true_counts)
    fdr = 1 - dr

    return round(aca, 3), round(mae, 3), round(dr, 3), round(fdr, 3)

# === Load your data ===

ground_truth_csv = "test_ground_truth_counts.csv"   # columns: image,true_count
predictions_csv = "object_counts.csv"            # columns: image, yolov8n, yolov8s, ...

# Load
gt_df = pd.read_csv(ground_truth_csv)
pred_df = pd.read_csv(predictions_csv)

# Merge on image
df = pd.merge(gt_df, pred_df, on="image")

# === Evaluate models ===

metrics = []
for model in pred_df.columns[1:]: 
    aca, mae, dr, fdr = calculate_counting_metrics(df["true_count"], df[model])
    metrics.append({
        "Model": model,
        "Average Counting Accuracy": aca,
        "Mean Absolute Error": mae,
        "Detection Rate": dr,
        "Failed Detection Rate": fdr
    })

metrics_df = pd.DataFrame(metrics)
metrics_df.to_csv("model_counting_metrics.csv", index=False)
print(metrics_df)
# Out:
#                             Model  Average Counting Accuracy  \
# 0  yolov8m_cbam_asff_finetuned.pt                      0.994
#
#    Mean Absolute Error  Detection Rate  Failed Detection Rate
# 0                 0.06           0.993                  0.007

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from textwrap import wrap

ROOT = Path('.')
eval_base = ROOT / 'confusion_graphs'
# ensure_dir = lambda p: p.mkdir(parents=True, exist_ok=True)
# ensure_dir(eval_base)

metrics_requested = [
    'train/cls_loss', 'train/box_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)',
    'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)'
]

# Helper to find a CSV that contains any of these metrics
candidate_files = list(ROOT.rglob('runs/detect/train4/results.csv')) + list(ROOT.rglob('metrics.csv')) + list(ROOT.rglob('*.csv'))
selected_file = None
selected_df = None
for f in candidate_files:
    try:
        df = pd.read_csv(f)
    except Exception:
        continue
    cols = set(df.columns.astype(str))
    # check if any of the requested metrics (or their stripped variants) appear
    def col_matches(metric, columns):
        candidates = [metric, metric.replace('/', '_'), metric.replace('/', ''), metric.replace('(B)',''), metric.replace('(B)','').replace('/','_')]
        candidates += [c for c in columns if metric in c]
        for c in candidates:
            if c in columns:
                return c
        # match ignoring case and punctuation
        for c in columns:
            simple_c = ''.join(ch for ch in c.lower() if ch.isalnum())
            simple_m = ''.join(ch for ch in metric.lower() if ch.isalnum())
            if simple_m in simple_c or simple_c in simple_m:
                return c
        return None
    # if df contains at least 3 of requested metrics, pick it
    match_count = 0
    for m in metrics_requested:
        if col_matches(m, cols):
            match_count += 1
    if match_count >= 3:
        selected_file = f
        selected_df = df
        break

if selected_df is None:
    print('No suitable results CSV found automatically. Candidate files searched:', len(candidate_files))
    print('You can provide a training `results.csv` (Ultralytics) or a CSV with the requested metric columns.')
else:
    print('Using metrics CSV:', selected_file)
    df = selected_df.copy()
    # If epoch-like column present, try to use it as x
    if 'epoch' in df.columns:
        x = df['epoch']
    elif 'epochs' in df.columns:
        x = df['epochs']
    else:
        x = np.arange(len(df))

    # find best matching column name for each requested metric
    found_cols = {}
    cols = list(df.columns.astype(str))
    for m in metrics_requested:
        # try exact match first
        if m in cols:
            found_cols[m] = m
            continue
        # try a few cleaned variants
        variants = [m.replace('/','_'), m.replace('/',''), m.replace('(B)',''), m.replace('(B)','').replace('/','_')]
        matched = None
        for v in variants:
            if v in cols:
                matched = v
                break
        if matched is None:
            # fuzzy match
            simple_m = ''.join(ch for ch in m.lower() if ch.isalnum())
            for c in cols:
                simple_c = ''.join(ch for ch in c.lower() if ch.isalnum())
                if simple_m == simple_c or simple_m in simple_c or simple_c in simple_m:
                    matched = c
                    break
        if matched:
            found_cols[m] = matched
        else:
            found_cols[m] = None

    # Prepare plot grid
    fig, axes = plt.subplots(2, 5, figsize=(20, 8), dpi=150)
    axes = axes.flatten()
    for i, metric in enumerate(metrics_requested):
        ax = axes[i]
        col = found_cols.get(metric)
        title = metric
        if col is None:
            ax.text(0.5, 0.5, 'MISSING\n' + '\n'.join(wrap(metric, 20)), ha='center', va='center', fontsize=18, color='black', fontweight='bold')
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_title(title)
            continue
        y = df[col].astype(float)
        ax.plot(x, y, marker='o', linewidth=1)
        ax.set_title(title, fontsize=20, fontweight='bold', color='black')
        ax.grid(True, linestyle='--', alpha=0.4)
        # label final value on the right
        # ax.text(0.99, -0.2, f'last={y.iloc[-1]:.4f}', ha='right', va='bottom', transform=ax.transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.7, edgecolor='none'))
        ax.tick_params(axis='both', labelsize=18, color='black', labelcolor='black', width=1)

        for label in ax.get_xticklabels() + ax.get_yticklabels():
            label.set_fontweight('bold') 
    plt.tight_layout()
    out_png = eval_base / 'metrics_2x5.png'
    out_pdf = eval_base / 'metrics_2x5.pdf'
    fig.savefig(out_png, bbox_inches='tight')
    fig.savefig(out_pdf, bbox_inches='tight')
    plt.show()
    print('Saved metrics panel to:', out_png, out_pdf)

    # Print mapping of requested -> found column names
    print('\nRequested -> found column mapping:')
    for k,v in found_cols.items():
        print(f'{k} -> {v}')

    # Save the mapping for reference
    mapping_file = eval_base / 'metrics_column_mapping.txt'
    with open(mapping_file, 'w') as f:
        for k,v in found_cols.items():
            f.write(f'{k} -> {v}\n')
    print('Saved mapping to', mapping_file)
# Out:
# Using metrics CSV: runs\detect\train4\results.csv
# Saved metrics panel to: confusion_graphs\metrics_2x5.png confusion_graphs\metrics_2x5.pdf
#
# Requested -> found column mapping:
# train/cls_loss -> train/cls_loss
# train/box_loss -> train/box_loss
# train/dfl_loss -> train/dfl_loss
# metrics/precision(B) -> metrics/precision(B)
# metrics/recall(B) -> metrics/recall(B)
# val/box_loss -> val/box_loss
# val/cls_loss -> val/cls_loss
# val/dfl_loss -> val/dfl_loss
# metrics/mAP50(B) -> metrics/mAP50(B)
# metrics/mAP50-95(B) -> metrics/mAP50-95(B)
# Saved mapping to confusion_graphs\metrics_column_mapping.txt

# %%
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: C:\Users\SauravUpadhyaya\desktop\stinkbug-project-desktop\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

ROOT = Path('.')
OUT_BASE = ROOT / 'confusion_graphs'
FIG_DIR = OUT_BASE / 'figures'
POSTER_DIR = OUT_BASE / 'poster'
FIG_DIR.mkdir(parents=True, exist_ok=True)
POSTER_DIR.mkdir(parents=True, exist_ok=True)

# Helper: load counts CSVs
def load_counts_table(path):
    if not path.exists():
        return None
    df = pd.read_csv(path)
    # try to find a column that looks like image id
    keys = [c for c in df.columns if 'image' in c.lower() or 'file' in c.lower() or 'name' in c.lower()]
    if not keys:
        # use first column as index-like
        df = df.set_index(df.columns[0])
    else:
        df = df.set_index(keys[0])
    return df

# load ground-truth and object_counts
gt_path = ROOT / 'test_ground_truth_counts.csv'
obj_path = ROOT / 'object_counts.csv'
final_metrics = OUT_BASE / 'final_metrics_table.csv'

gt_df = load_counts_table(gt_path)
obj_df = load_counts_table(obj_path)
final_df = pd.read_csv(final_metrics) if final_metrics.exists() else None

if gt_df is None:
    print('Warning: test_ground_truth_counts.csv not found; trying val/test summaries instead')

# If object_counts present, infer model columns
model_cols = []
if obj_df is not None:
    model_cols = [c for c in obj_df.columns]
    # remove any index-like label column name if present

# Match by index (image/file)
def align_model_with_gt(obj_df, gt_df):
    if obj_df is None or gt_df is None:
        return None
    # align indices by filename stem if necessary
    left_idx = obj_df.index.astype(str)
    right_idx = gt_df.index.astype(str)
    common = left_idx.intersection(right_idx)
    if len(common) == 0:
        # try matching by stem (remove extension)
        left_stem = left_idx.map(lambda s: Path(s).stem)
        right_stem = right_idx.map(lambda s: Path(s).stem)
        map_left = {Path(s).stem: s for s in obj_df.index.astype(str)}
        rows = []
        for r in gt_df.index.astype(str):
            st = Path(r).stem
            if st in map_left:
                rows.append((map_left[st], r))
        if not rows:
            return None
        left_sel = [r[0] for r in rows]
        right_sel = [r[1] for r in rows]
        left = obj_df.loc[left_sel]
        right = gt_df.loc[right_sel]
        left.index = right.index
        return left, right
    else:
        left = obj_df.loc[common]
        right = gt_df.loc[common]
        return left, right

aligned = align_model_with_gt(obj_df, gt_df)

# plotting helpers
def save_scatter_and_stats(preds, gt, model_name, out_png, out_pdf):
    pred = preds.values.astype(float)
    gtv = gt.values.astype(float)
    mae = np.mean(np.abs(pred - gtv))
    rmse = math.sqrt(np.mean((pred - gtv)**2))
    corr = np.corrcoef(pred.flatten(), gtv.flatten())[0,1] if len(pred.flatten())>1 else float('nan')

    plt.figure(figsize=(6,5))
    plt.scatter(gtv, pred, alpha=0.6, edgecolor='k', linewidth=0.2)
    mx = max(gtv.max(), pred.max()) if (len(gtv)>0 and len(pred)>0) else 1
    plt.plot([0, mx], [0, mx], 'r--', label='y=x')
    plt.xlabel('Ground truth count')
    plt.ylabel('Predicted count')
    plt.title(f'{model_name}: Pred vs GT\nMAE={mae:.3f}, RMSE={rmse:.3f}, r={corr:.3f}')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(out_png, dpi=300)
    plt.savefig(out_pdf)
    plt.close()
    return mae, rmse, corr


def save_bland_altman(preds, gt, model_name, out_png, out_pdf):
    pred = preds.values.astype(float).flatten()
    gt = gt.values.astype(float).flatten()
    mean_vals = (pred + gt) / 2.0
    diffs = pred - gt
    mean_diff = diffs.mean()
    sd = diffs.std()
    loa_upper = mean_diff + 1.96 * sd
    loa_lower = mean_diff - 1.96 * sd

    plt.figure(figsize=(6,5))
    plt.scatter(mean_vals, diffs, alpha=0.6, edgecolor='k', linewidth=0.2)
    plt.axhline(mean_diff, color='red', linestyle='-')
    plt.axhline(loa_upper, color='gray', linestyle='--')
    plt.axhline(loa_lower, color='gray', linestyle='--')
    plt.xlabel('(Pred + GT)/2')
    plt.ylabel('Pred - GT')
    plt.title(f'Bland-Altman: {model_name}\nmean={mean_diff:.3f}, sd={sd:.3f}')
    plt.tight_layout()
    plt.savefig(out_png, dpi=300)
    plt.savefig(out_pdf)
    plt.close()
    return mean_diff, sd


def save_abs_err_hist(preds, gt, model_name, out_png, out_pdf):
    pred = preds.values.astype(float).flatten()
    gt = gt.values.astype(float).flatten()
    errs = np.abs(pred - gt)
    plt.figure(figsize=(6,4))
    plt.hist(errs, bins=range(0, int(max(errs.max(),1))+2), color='tab:blue', alpha=0.8)
    plt.xlabel('Absolute error |pred - gt|')
    plt.ylabel('Image count')
    plt.title(f'Absolute error histogram: {model_name}\nMAE={errs.mean():.3f}')
    plt.tight_layout()
    plt.savefig(out_png, dpi=300)
    plt.savefig(out_pdf)
    plt.close()
    return errs.mean()


def save_cum_error_by_true_count(preds, gt, model_name, out_png, out_pdf):
    pred = preds.values.astype(float).flatten()
    gt = gt.values.astype(float).flatten()
    df = pd.DataFrame({'gt': gt, 'pred': pred})
    df['abs_err'] = np.abs(df['pred'] - df['gt'])
    bins = sorted(df['gt'].unique())
    if len(bins) > 20:
        bins = np.arange(0, int(df['gt'].max())+2, max(1,int(df['gt'].max()/10)))
    grouped = df.groupby(pd.cut(df['gt'], bins, include_lowest=True))['abs_err'].mean()
    plt.figure(figsize=(6,4))
    grouped.plot(kind='bar', color='tab:orange')
    plt.xlabel('True count (binned)')
    plt.ylabel('Mean absolute error')
    plt.title(f'MAE by true-count bin: {model_name}')
    plt.tight_layout()
    plt.savefig(out_png, dpi=300)
    plt.savefig(out_pdf)
    plt.close()
    return grouped

# Main generation using object_counts and gt
generated = []
if aligned is None:
    print('Could not align object_counts.csv with test_ground_truth_counts.csv; try running align diagnostics or provide matching filenames.')
else:
    left, right = aligned
    # right is gt, left is predictions table with model columns
    for col in left.columns:
        preds = left[col]
        gt_series = right.iloc[:,0]
        model_name = col
        out_prefix = FIG_DIR / f'{model_name}_test'
        out_png = out_prefix.with_suffix('.png')
        out_pdf = out_prefix.with_suffix('.pdf')
        mae, rmse, corr = save_scatter_and_stats(preds, gt_series, model_name, str(out_png), str(out_pdf))
        save_bland_altman(preds, gt_series, model_name, str(out_prefix)+'_bland_altman.png', str(out_prefix)+'_bland_altman.pdf')
        save_abs_err_hist(preds, gt_series, model_name, str(out_prefix)+'_abs_hist.png', str(out_prefix)+'_abs_hist.pdf')
        save_cum_error_by_true_count(preds, gt_series, model_name, str(out_prefix)+'_mae_by_true.png', str(out_prefix)+'_mae_by_true.pdf')
        generated.append(model_name)

# Re-generate confusion matrices (vector PDFs) from summary.txt files
# For each model folder under evaluation_outputs_of_1008, look for val/test/summary.txt
import re
for mdir in sorted(OUT_BASE.iterdir()):
    if not mdir.is_dir():
        continue
    for split in ['val','test']:
        sdir = mdir / split
        sfile = sdir / 'summary.txt'
        if not sfile.exists():
            continue
        txt = sfile.read_text()
        tp = int(re.search(r'TP:\s*(\d+)', txt).group(1)) if re.search(r'TP:\s*(\d+)', txt) else 0
        fp = int(re.search(r'FP:\s*(\d+)', txt).group(1)) if re.search(r'FP:\s*(\d+)', txt) else 0
        fn = int(re.search(r'FN:\s*(\d+)', txt).group(1)) if re.search(r'FN:\s*(\d+)', txt) else 0
        cm = np.array([[tp, fn],[fp, 0]])
        # reuse existing helper if available
        try:
            plot_and_save_confusion(cm, sdir, mdir.name, split)
        except Exception:
            # fallback: draw simple vector PDF via matplotlib
            fig, ax = plt.subplots(figsize=(6,5))
            im = ax.imshow(cm, cmap='Blues')
            for i in range(cm.shape[0]):
                for j in range(cm.shape[1]):
                    ax.text(j, i, int(cm[i,j]), ha='center', va='center', color='black', fontsize=18)
            ax.set_xticks([0,1]); ax.set_yticks([0,1])
            ax.set_xticklabels(['actual: target','actual: background'], rotation=0)
            ax.set_yticklabels(['pred: target','pred: background'], rotation=90)
            fig.savefig(sdir / 'confusion_matrix_counts_regen.pdf', bbox_inches='tight')
            fig.savefig(sdir / 'confusion_matrix_counts_regen.png', dpi=300)
            plt.close(fig)

print('\nGenerated figures for models:', generated)
print('Figures saved to', FIG_DIR)



print('\nDone. Produced figures and poster where possible. Check the evaluation_outputs_of_1008 folder.')
# Out:
# C:\Users\SauravUpadhyaya\AppData\Local\Temp\ipykernel_8672\223861673.py:153: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(pd.cut(df['gt'], bins, include_lowest=True))['abs_err'].mean()
# Generated figures for models: ['yolov8m_cbam_asff_finetuned.pt']
# Figures saved to confusion_graphs\figures
#
# Done. Produced figures and poster where possible. Check the evaluation_outputs_of_1008 folder.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib

ROOT = Path('.')
OUT = ROOT / 'confusion_graphs' / 'figures'
OUT.mkdir(parents=True, exist_ok=True)

obj_path = ROOT / 'object_counts.csv'
gt_path = ROOT / 'test_ground_truth_counts.csv'

# load with flexible parsing
def load_indexed_csv(p):
    if not p.exists():
        return None
    df = pd.read_csv(p, index_col=0)
    # if index looks numeric sequential, try to keep as-is
    return df

obj_df = load_indexed_csv(obj_path)
gt_df = load_indexed_csv(gt_path)

if obj_df is None and gt_df is None:
    print('No object_counts.csv or test_ground_truth_counts.csv found in project root. Aborting pseudo-grid creation.')
else:
    # pick a set of counts to plot. Prefer obj_df (model columns). If absent, use gt_df.
    if obj_df is not None:
        data_df = obj_df.copy()
        source = 'predictions'
    else:
        data_df = gt_df.copy()
        source = 'ground_truth'

    # Normalize index labels to string
    data_df.index = data_df.index.astype(str)

    # Choose columns to visualize
    cols = list(data_df.columns) if data_df.shape[1] > 1 else [data_df.columns[0]]

    # Build ordering: try to use gt_df order if available
    if gt_df is not None:
        # try to align by stem
        common = [i for i in data_df.index if i in gt_df.index]
        if len(common) >= len(data_df) * 0.5:
            data_df = data_df.loc[common]
        else:
            # attempt matching by stem
            data_index_by_stem = {Path(i).stem: i for i in data_df.index}
            matches = []
            for r in gt_df.index.astype(str):
                st = Path(r).stem
                if st in data_index_by_stem:
                    matches.append(data_index_by_stem[st])
            if matches:
                data_df = data_df.loc[matches]

    N = len(data_df)
    cols_grid = math.ceil(math.sqrt(N)) if N>0 else 1
    rows_grid = math.ceil(N / cols_grid) if N>0 else 1

    # function to create grid array from a series
    def series_to_grid(s, rows, cols):
        arr = np.full((rows, cols), np.nan)
        names = np.full((rows, cols), '', dtype=object)
        for idx, (k,v) in enumerate(s.items()):
            r = idx // cols
            c = idx % cols
            arr[r,c] = v
            names[r,c] = k
        return arr, names

    # plotting loop
    for col in cols:
        series = data_df[col] if col in data_df.columns else data_df.iloc[:,0]
        arr, names = series_to_grid(series, rows_grid, cols_grid)

        # Heatmap (counts)
        plt.figure(figsize=(cols_grid*0.6 + 1, rows_grid*0.6 + 1))
        cmap = plt.get_cmap('YlOrRd')
        # mask NaNs for better colorbar
        masked = np.ma.masked_invalid(arr.astype(float))
        im = plt.imshow(masked, cmap=cmap, interpolation='nearest')
        plt.colorbar(im, fraction=0.046, pad=0.04, label='count')
        # annotate counts
        for (i,j), val in np.ndenumerate(arr):
            if not np.isnan(val):
                plt.text(j, i, f'{int(val)}', ha='center', va='center', fontsize=8)
        plt.xticks([])
        plt.yticks([])
        # plt.title(f'heatmap: {col} ({source})')
        heat_png = OUT / f'pseudo_grid_{col}.png'
        heat_pdf = OUT / f'pseudo_grid_{col}.pdf'
        plt.tight_layout()
        plt.savefig(heat_png, dpi=300)
        plt.savefig(heat_pdf)
        plt.close()

        # Bubble map (circle size ~ count)
        plt.figure(figsize=(cols_grid*0.6 + 1, rows_grid*0.6 + 1))
        fig, ax = plt.subplots()
        xs = []
        ys = []
        sizes = []
        labels = []
        for (i,j), val in np.ndenumerate(arr):
            if not np.isnan(val):
                xs.append(j)
                ys.append(rows_grid - 1 - i)  # flip y for plotting so first item is top-left
                sizes.append(max(8, val*8))
                labels.append(names[i,j])
        sc = ax.scatter(xs, ys, s=sizes, c=sizes, cmap='Reds', alpha=0.7, edgecolors='k')
        for x,y,l in zip(xs,ys,labels):
            ax.text(x, y, Path(l).stem, fontsize=6, ha='center', va='center')
        ax.set_xlim(-0.5, cols_grid-0.5)
        ax.set_ylim(-0.5, rows_grid-0.5)
        ax.axis('off')
        plt.title(f'Pseudo-grid bubble map: {col} ({source})')
        bubble_png = OUT / f'pseudo_bubble_{col}.png'
        bubble_pdf = OUT / f'pseudo_bubble_{col}.pdf'
        plt.tight_layout()
        plt.savefig(bubble_png, dpi=300)
        plt.savefig(bubble_pdf)
        plt.close()

    print('Pseudo-grid visualizations created for columns:', cols)
    print('Saved figures to', OUT)

    # write mapping file
    mapping = []
    for idx,(k,v) in enumerate(series.items()):
        r = idx // cols_grid
        c = idx % cols_grid
        mapping.append({'image': k, 'grid_row': int(r), 'grid_col': int(c), 'count': int(v)})
    mp_df = pd.DataFrame(mapping)
    mp_df.to_csv(OUT / 'pseudo_grid_mapping.csv', index=False)
    print('Mapping saved to', OUT / 'pseudo_grid_mapping.csv')
# Out:
# Pseudo-grid visualizations created for columns: ['yolov8m_cbam_asff_finetuned.pt']
# Saved figures to confusion_graphs\figures
# Mapping saved to confusion_graphs\figures\pseudo_grid_mapping.csv
